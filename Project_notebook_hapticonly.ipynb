# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pathlib import Path
import matplotlib.pyplot as plt
import glob
import re
import warnings
from datetime import datetime
import os
import csv
import io                   # [추가] model.summary()를 캡처하기 위해
from contextlib import redirect_stdout
import csv

# %%
def trim_and_flatten_data(haptic_df):
    # Haptic: 4, 5th columns (index 3, 4)
    # Robot: 9, 10, 11th columns (index 8, 9, 10)
    haptic_data = haptic_df.iloc[:, [3, 4]].values
    
    # Process NaN values by replacing them with zeros
    haptic_data = np.nan_to_num(haptic_data, nan=0.0)
    return haptic_data.flatten()

# %%
def load_all_data(data_base_path):
    base_path = Path(data_base_path) / "DATA"

    all_X_data = []
    all_y_data = []

    METHOD_MAP = {'HAPTICS': 'H', 'NOhaptics': 'NH'}
    TASK_MAP = {
        5: ('pp1', 'PAP'), 6: ('pp1', 'PAP'),
        7: ('pp2', 'PAPObstructed'), 8: ('pp2', 'PAPObstructed'),
        9: ('pp3', 'Camera'), 10: ('pp3', 'Camera')
    }

    for p_id in range(1, 27): # 1~26

        participant_str = f"Participant_{p_id}"
        results_file = base_path / "Haptic Data" / participant_str / f"{participant_str}_results.csv"
        
        results_lookup = {}
        try:
            results_df = pd.read_csv(results_file)
            for _, row in results_df.iterrows():
                try:
                    condition = row['Condition']
                    subcondition = row['Subcondition']
                    trial_str = str(row['Trial'])
                    trial = int(re.search(r'^\d+', trial_str).group())
                    output_1 = pd.to_numeric(row['Sensor1 Mean'], errors='coerce')
                    output_2 = pd.to_numeric(row['Sensor2 Mean'], errors='coerce')

                    if pd.isna(output_1) or pd.isna(output_2):
                        continue
                    key = (condition, subcondition, trial)
                    results_lookup[key] = (output_1, output_2)
                except Exception:
                    continue
        except Exception as e:
            print(f"Error in reading ({results_file}): {e}")
            continue
        haptic_files_glob = glob.glob(str(base_path / "Haptic Data" / participant_str / "*.csv"))

        for hfile_path in haptic_files_glob:
            file_name = Path(hfile_path).name
            match = re.match(r'(\d+)_.*?_(HAPTICS|NOhaptics)_(\d+)\.csv', file_name)
            
            if not match:
                continue

            try:
                task_num = int(match.group(1))
                method = match.group(2)
                trial = int(match.group(3))
                
                if task_num not in TASK_MAP:
                    continue

                scenario_num, result_condition = TASK_MAP[task_num]
                method_short = METHOD_MAP[method]

                output_key = (result_condition, method, trial)
                if output_key not in results_lookup:
                    continue

                haptic_df = pd.read_csv(hfile_path)

                flat_input_vector = trim_and_flatten_data(haptic_df)

                if flat_input_vector is not None:
                    output_1, output_2 = results_lookup[output_key]
                    output_vector = np.array([output_1, output_2])
                    all_X_data.append(flat_input_vector)
                    all_y_data.append(output_vector)
            
                print(f" Success: participant {p_id} task {task_num}, method {method}, trial {trial}")
            except Exception as e:
                print(f"  Error: {file_name} - {e}")

    max_len = max(len(x) for x in all_X_data)
    
    X_padded = np.array([np.pad(x, (0, max_len - len(x)), 'constant') for x in all_X_data])
    y_array = np.array(all_y_data)

    return X_padded, y_array

# %%
def split_data(X, y, test_size=0.2, dev_size=0.125, random_state=42):
    """
    데이터를 훈련, 개발, 테스트 세트로 분리합니다. (기본 70:10:20)
    """
    if X.shape[0] == 0:
        print("오류: 분리할 데이터가 없습니다.")
        return (np.array([]),)*6

    # 1차 분리: 훈련+개발 (80%) / 테스트 (20%)
    X_train_dev, X_test, y_train_dev, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    # 2차 분리: 훈련 (70%) / 개발 (10%)
    X_train, X_dev, y_train, y_dev = train_test_split(
        X_train_dev, y_train_dev, test_size=dev_size, random_state=random_state
    )

    print(f"데이터 분리 완료:")
    print(f"  훈련 (Train)  : {X_train.shape}, {y_train.shape}")
    print(f"  개발 (Dev)    : {X_dev.shape}, {y_dev.shape}")
    print(f"  테스트 (Test) : {X_test.shape}, {y_test.shape}")

    return X_train, X_dev, X_test, y_train, y_dev, y_test

# %%
def get_regularizer(config):
    reg_type = config.get('regularizer_type', None)
    l1_val = config.get('l1', 0.01)
    l2_val = config.get('l2', 0.01)

    if reg_type == 'l1': return regularizers.l1(l1_val)
    elif reg_type == 'l2': return regularizers.l2(l2_val)
    elif reg_type == 'l1_l2': return regularizers.l1_l2(l1=l1_val, l2=l2_val)
    else: return None

# %%
def build_model(input_shape, model_config):
    model = Sequential(name="Modular_DNN_Model")
    model.add(InputLayer(input_shape=input_shape))

    hidden_layers = model_config.get('hidden_layers', [64, 32])
    activation = model_config.get('activation', 'relu')
    reg_obj = get_regularizer(model_config)

    for units in hidden_layers:
        model.add(Dense(units, activation=activation, kernel_regularizer=reg_obj))
        if model_config.get('use_batch_norm', False):
            model.add(BatchNormalization())
        if model_config.get('dropout_rate', 0.0) > 0:
            model.add(Dropout(model_config['dropout_rate']))

    model.add(Dense(2, name='output')) # 2개 값 예측 (회귀)

    print("모델 구성 완료:")
    model.summary()
    return model

# %%
def compile_and_train_model(model, X_train, y_train, X_val, y_val, train_config):
    loss_function = train_config.get('loss', 'mean_squared_error')
    learning_rate = train_config.get('learning_rate', 0.001)
    optimizer = Adam(learning_rate=learning_rate)
    metrics_list = train_config.get('metrics', ['mean_absolute_error'])

    model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics_list)

    callbacks_list = []
    patience = train_config.get('early_stopping_patience', None)
    
    if patience and patience > 0:
        early_stop = EarlyStopping(
            monitor='val_loss', 
            patience=patience,  
            verbose=1,          
            restore_best_weights=True
        )
        callbacks_list.append(early_stop)

    print("\n--- 모델 훈련 시작 ---")
    history = model.fit(
        X_train,
        y_train,
        epochs=train_config.get('epochs', 50),
        batch_size=train_config.get('batch_size', 32),
        validation_data=(X_val, y_val),
        verbose=1
    )
    print("--- 모델 훈련 완료 ---")

    return model, history

# %%
def evaluate_model(model, X_test, y_test):
    if X_test.shape[0] == 0:
        print("경고: 평가할 테스트 데이터가 없습니다.")
        return None

    print("\n--- 최종 모델 평가 (Test Set) ---")
    results = model.evaluate(X_test, y_test, verbose=1)
    metric_names = model.metrics_names
    for name, value in zip(metric_names, results):
        print(f"{name}: {value:.4f}")
    return results

# %%
def plot_training_history(history,filename=None):
    if not history:
        print("시각화할 훈련 기록(history)이 없습니다.")
        return

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    if filename is not None:
        plt.savefig(f"{filename}_loss.png")

    # Metric
    plt.figure(figsize=(12, 5))
    metric_keys = [k for k in history.history.keys() if k not in ['loss', 'val_loss', 'lr']]
    if metric_keys:
        train_metric = metric_keys[0]
        val_metric = f"val_{train_metric}"
        if val_metric in history.history:
            plt.subplot(1, 2, 2)
            plt.plot(history.history[train_metric], label=f'Train {train_metric}')
            plt.plot(history.history[val_metric], label=f'Validation {val_metric}')
            plt.title(f'Model Metric ({train_metric})')
            plt.xlabel('Epochs')
            plt.ylabel('Metric')
            plt.legend()
    plt.tight_layout()
    plt.show()
    if filename is not None:
        plt.savefig(f"{filename}_metric.png")

# %%
# --- 5. 평가 및 시각화 모듈 ---
# ... (evaluate_model, plot_training_history 함수는 여기에 있습니다) ...

def plot_predictions(y_true, y_pred,filename=None):
    """
    [수정된 함수]
    Validation set의 실제 값과 예측 값을
    하나의 산점도(scatterplot)에 오버레이하여 그립니다.
    """
    if y_true.shape[0] == 0:
        print("시각화할 검증 데이터가 없습니다.")
        return

    plt.figure(figsize=(8, 8)) # 정사각형 그래프로 변경

    # Output 1 (첫 번째 예측값) - 파란색
    plt.scatter(y_true[:, 0], y_pred[:, 0], 
                alpha=0.5, label='Output 1 Prediction (blue)')
    
    # Output 2 (두 번째 예측값) - 초록색
    plt.scatter(y_true[:, 1], y_pred[:, 1], 
                alpha=0.5, label='Output 2 Prediction (green)')

    plt.xlabel("Actual Values (True Values)")
    plt.ylabel("Predicted Values (Predictions)")
    plt.title("Prediction vs Actual (Overlay)")
    
    # y=x 선 (완벽한 예측)
    # 두 Output의 모든 값(true, pred)을 기준으로 min/max를 계산
    all_values = np.concatenate([y_true.flatten(), y_pred.flatten()])
    lims = [all_values.min() * 0.95, all_values.max() * 1.05] # 약간의 여백 추가
    
    plt.xlim(lims)
    plt.ylim(lims)
    plt.plot(lims, lims, 'r--', label='Perfect Prediction (y=x)')
    
    plt.legend() # 범례 표시
    plt.grid(True) # 그리드 추가
    if filename is not None:
        plt.savefig(f"{filename}_comparison.png")
    plt.tight_layout()
    plt.show()
    if filename is not None:
        plt.savefig(f"{filename}_pred.png")

# %%
def capture_model_summary(model):
    """Keras 모델의 .summary() 출력을 문자열로 반환합니다."""
    stream = io.StringIO()
    with redirect_stdout(stream):
        model.summary()
    return stream.getvalue()


EXPERIMENT_FIELDNAMES = [
    "timestamp", "architecture", "hidden_layers", "activation", 
    "regularizer", "dropout", "batch_norm", "learning_rate", 
    "batch_size", "n_epochs", "optimizer", "loss_function",
    "train_size", "dev_size", "final_train_loss", "final_dev_loss",
    "best_dev_loss", "best_epoch", "notes"
]

def log_experiment(log_path, model, history, model_config, train_config, X_train, X_val):
    """
    [TensorFlow/Keras 버전]
    훈련 결과를 CSV 파일에 한 줄로 기록합니다.
    """
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    
    # Keras History 객체에서 Loss 값들을 안전하게 추출
    train_losses = history.history.get('loss', [0.0])
    val_losses = history.history.get('val_loss', [0.0])
    
    # 기록할 파라미터 딕셔너리 생성
    params = {
        "timestamp": timestamp,
        "architecture": capture_model_summary(model), # 모델 구조 요약
        "hidden_layers": str(model_config.get('hidden_layers', [])), # 리스트를 문자열로
        "activation": model_config.get('activation', ''),
        "regularizer": model_config.get('regularizer_type', 'None'),
        "dropout": model_config.get('dropout_rate', 0.0),
        "batch_norm": model_config.get('use_batch_norm', False),
        "learning_rate": train_config.get('learning_rate', 0.0),
        "batch_size": train_config.get('batch_size', 0),
        "n_epochs": train_config.get('epochs', 0),
        "optimizer": model.optimizer.__class__.__name__, # 'Adam' 등
        "loss_function": train_config.get('loss', ''),
        "train_size": len(X_train), # X_train의 크기
        "dev_size": len(X_val),   # X_val의 크기
        "final_train_loss": round(train_losses[-1], 6),
        "final_dev_loss": round(val_losses[-1], 6),
        "best_dev_loss": round(min(val_losses), 6),
        "best_epoch": int(np.argmin(val_losses) + 1), # (numpy as np 필요)
    }
    
    file_exists = os.path.exists(log_path)
    with open(log_path, mode='a', newline='', encoding='utf-8') as f:
        # DictWriter가 params에 없는 키는 'N/A'로, params에 fieldnames에 없는 키는 무시하도록 설정
        writer = csv.DictWriter(f, 
                              fieldnames=EXPERIMENT_FIELDNAMES, 
                              restval='N/A', 
                              extrasaction='ignore')
        
        if not file_exists:
            writer.writeheader() # 파일이 없으면 헤더 쓰기
            
        writer.writerow(params) # 파라미터 한 줄 쓰기

# %%
def save_final_model(save_dir, model, history, train_config):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    n_epochs = train_config.get('epochs', 0)
    
    val_losses = history.history.get('val_loss', [0.0])
    final_dev_loss = val_losses[-1] # PyTorch의 avg_dev_loss 대신 final_dev_loss 사용
    
    final_name = f"final_pressureRNN_{timestamp}_epoch{n_epochs}_loss{final_dev_loss:.4f}.weights.h5"
    final_path = os.path.join(save_dir, final_name)
    
    # 3. 모델 가중치 저장
    model.save_weights(final_path)

# %%
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

DATA_BASE_PATH_ROOT = r"G:/내 드라이브/CS230 Project"
PROCESSED_DATA_FILE = "processed_haptic_data.npy"

# 모델 아키텍처 설정
MODEL_CONFIG = {
    'hidden_layers': [128, 64, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32],
    'activation': 'relu',
    'regularizer_type': 'l2',
    'l2': 0.001,
    'use_batch_norm': True,
    'dropout_rate': 0.
}

# 훈련 설정
TRAIN_CONFIG = {
    'learning_rate': 0.002,
    'epochs': 500, # 126개 샘플은 적으니 epoch를 100~200 정도로 늘려도 좋습니다.
    'batch_size': 32, # 샘플이 적으므로 배치 크기를 32보다 작게 (16) 조정
    'loss': 'mean_squared_error',
    'metrics': ['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(name='rmse')],
    'early_stopping_patience': 30
}
# ==========================

# 1. 데이터 로드 (검증된 함수 사용)
if os.path.exists(PROCESSED_DATA_FILE):
    data = np.load(PROCESSED_DATA_FILE, allow_pickle=True).item()
    X = data['X']
    y = data['y']
    
else:
    X, y = load_all_data(DATA_BASE_PATH_ROOT)
    data_to_save = {'X': X, 'y': y}
    np.save(PROCESSED_DATA_FILE, data_to_save, allow_pickle=True)

print(f"전체 데이터셋 크기: X={X.shape}, y={y.shape}")
print(f"샘플 예시 (첫 5개):")
for i in range(min(5, X.shape[0])):
    print(f" X[{i}]: {X[i][:10]}... , y[{i}]: {y[i]}")
    
# # 1-Extra. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# # 2. 데이터 분리
X_train, X_val, X_test, y_train, y_val, y_test = split_data(X_scaled, y,0.15,0.15)

# if X_train.shape[0] == 0:
#     print("데이터 분리에 실패했습니다. (샘플 부족) 프로그램을 종료합니다.")
#     return

# # 3. 모델 구축
input_shape = (X_train.shape[1],)
model = build_model(input_shape, MODEL_CONFIG)

# # 4. 모델 훈련
model, history = compile_and_train_model(
    model, X_train, y_train, X_val, y_val, TRAIN_CONFIG
)

# # 5. 모델 평가
evaluate_model(model, X_test, y_test)

# # 6. 결과 시각화
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
plot_filename = os.path.join("results", "plots", f"loss_curve_{timestamp}.png")

plot_training_history(history,filename=plot_filename)

y_pred_val = model.predict(X_val)
plot_predictions(y_val,y_pred_val)

LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# 전체 데이터셋 크기: X=(795, 9248), y=(795, 2)
# 샘플 예시 (첫 5개):
#  X[0]: [1093. 1093. 1093. 1093. 1093. 1093. 1092. 1093. 1092. 1093.]... , y[0]: [1229.37 1265.18]
#  X[1]: [1100. 1097. 1099. 1097. 1099. 1097. 1100. 1097. 1100. 1097.]... , y[1]: [1212.33 1262.6 ]
#  X[2]: [1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097.]... , y[2]: [1229.8  1261.45]
#  X[3]: [1098. 1097. 1098. 1097. 1098. 1097. 1098. 1097. 1097. 1096.]... , y[3]: [1111.96 1117.9 ]
#  X[4]: [1090. 1092. 1090. 1092. 1090. 1093. 1090. 1093. 1091. 1092.]... , y[4]: [1220.12 1238.38]
# 데이터 분리 완료:
#   훈련 (Train)  : (573, 9248), (573, 2)
#   개발 (Dev)    : (102, 9248), (102, 2)
#   테스트 (Test) : (120, 9248), (120, 2)
# c:\Users\sehui\.conda\envs\CS230\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 모델 구성 완료:
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_52          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_53          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_54          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_55          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_56          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_58          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_59          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,215,298 (4.64 MB)
#  Trainable params: 1,213,762 (4.63 MB)
#  Non-trainable params: 1,536 (6.00 KB)
# --- 모델 훈련 시작 ---
# Epoch 1/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 1408819.8750 - mean_absolute_error: 1185.6146 - rmse: 1186.9368 - val_loss: 1422009.0000 - val_mean_absolute_error: 1191.1113 - val_rmse: 1192.4797
# Epoch 2/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1408115.7500 - mean_absolute_error: 1185.3201 - rmse: 1186.6401 - val_loss: 1421225.6250 - val_mean_absolute_error: 1190.7822 - val_rmse: 1192.1512
# Epoch 3/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1407092.2500 - mean_absolute_error: 1184.8888 - rmse: 1186.2087 - val_loss: 1420116.5000 - val_mean_absolute_error: 1190.3163 - val_rmse: 1191.6860
# Epoch 4/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1405663.6250 - mean_absolute_error: 1184.2845 - rmse: 1185.6063 - val_loss: 1419402.5000 - val_mean_absolute_error: 1190.0161 - val_rmse: 1191.3865
# Epoch 5/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1403737.8750 - mean_absolute_error: 1183.4854 - rmse: 1184.7941 - val_loss: 1418065.8750 - val_mean_absolute_error: 1189.4541 - val_rmse: 1190.8253
# Epoch 6/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1401357.5000 - mean_absolute_error: 1182.4779 - rmse: 1183.7891 - val_loss: 1415555.5000 - val_mean_absolute_error: 1188.3992 - val_rmse: 1189.7708
# Epoch 7/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1398492.6250 - mean_absolute_error: 1181.2550 - rmse: 1182.5785 - val_loss: 1412096.5000 - val_mean_absolute_error: 1186.9501 - val_rmse: 1188.3163
# Epoch 8/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1395047.2500 - mean_absolute_error: 1179.8121 - rmse: 1181.1207 - val_loss: 1409312.5000 - val_mean_absolute_error: 1185.7712 - val_rmse: 1187.1442
# Epoch 9/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1391097.3750 - mean_absolute_error: 1178.1461 - rmse: 1179.4474 - val_loss: 1402218.2500 - val_mean_absolute_error: 1182.7617 - val_rmse: 1184.1525
# Epoch 10/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1386670.7500 - mean_absolute_error: 1176.2556 - rmse: 1177.5695 - val_loss: 1398870.3750 - val_mean_absolute_error: 1181.3864 - val_rmse: 1182.7382
# Epoch 11/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1381728.5000 - mean_absolute_error: 1174.1439 - rmse: 1175.4690 - val_loss: 1380408.3750 - val_mean_absolute_error: 1173.5294 - val_rmse: 1174.9073
# Epoch 12/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1376114.8750 - mean_absolute_error: 1171.8070 - rmse: 1173.0787 - val_loss: 1382988.8750 - val_mean_absolute_error: 1174.6344 - val_rmse: 1176.0050
# Epoch 13/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1370212.8750 - mean_absolute_error: 1169.2488 - rmse: 1170.5604 - val_loss: 1374343.6250 - val_mean_absolute_error: 1170.9552 - val_rmse: 1172.3236
# Epoch 14/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1363693.3750 - mean_absolute_error: 1166.4708 - rmse: 1167.7723 - val_loss: 1370890.3750 - val_mean_absolute_error: 1169.5542 - val_rmse: 1170.8497
# Epoch 15/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1356653.3750 - mean_absolute_error: 1163.4714 - rmse: 1164.7540 - val_loss: 1355118.7500 - val_mean_absolute_error: 1162.8385 - val_rmse: 1164.0951
# Epoch 16/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1349186.1250 - mean_absolute_error: 1160.2573 - rmse: 1161.5442 - val_loss: 1333492.8750 - val_mean_absolute_error: 1153.2462 - val_rmse: 1154.7690
# Epoch 17/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1341275.5000 - mean_absolute_error: 1156.8278 - rmse: 1158.1339 - val_loss: 1349446.2500 - val_mean_absolute_error: 1160.1903 - val_rmse: 1161.6561
# Epoch 18/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1332819.6250 - mean_absolute_error: 1153.1895 - rmse: 1154.4775 - val_loss: 1327531.6250 - val_mean_absolute_error: 1150.7183 - val_rmse: 1152.1851
# Epoch 19/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1324012.0000 - mean_absolute_error: 1149.3390 - rmse: 1150.6566 - val_loss: 1345291.8750 - val_mean_absolute_error: 1158.3136 - val_rmse: 1159.8667
# Epoch 20/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1314542.2500 - mean_absolute_error: 1145.2825 - rmse: 1146.5342 - val_loss: 1338690.0000 - val_mean_absolute_error: 1155.5978 - val_rmse: 1157.0171
# Epoch 21/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1304822.8750 - mean_absolute_error: 1141.0173 - rmse: 1142.2880 - val_loss: 1329307.8750 - val_mean_absolute_error: 1151.5336 - val_rmse: 1152.9556
# Epoch 22/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1294642.6250 - mean_absolute_error: 1136.5497 - rmse: 1137.8232 - val_loss: 1311828.5000 - val_mean_absolute_error: 1144.0648 - val_rmse: 1145.3502
# Epoch 23/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1283992.5000 - mean_absolute_error: 1131.8838 - rmse: 1133.1334 - val_loss: 1289249.5000 - val_mean_absolute_error: 1134.1270 - val_rmse: 1135.4507
# Epoch 24/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1272976.1250 - mean_absolute_error: 1127.0222 - rmse: 1128.2617 - val_loss: 1282055.0000 - val_mean_absolute_error: 1130.9681 - val_rmse: 1132.2781
# Epoch 25/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1261591.6250 - mean_absolute_error: 1121.9678 - rmse: 1123.2053 - val_loss: 1272458.3750 - val_mean_absolute_error: 1126.5316 - val_rmse: 1128.0323
# Epoch 26/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1249829.0000 - mean_absolute_error: 1116.7214 - rmse: 1117.9569 - val_loss: 1251854.2500 - val_mean_absolute_error: 1117.3712 - val_rmse: 1118.8623
# Epoch 27/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1237763.6250 - mean_absolute_error: 1111.2863 - rmse: 1112.5479 - val_loss: 1251866.8750 - val_mean_absolute_error: 1117.3302 - val_rmse: 1118.8679
# Epoch 28/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1225250.1250 - mean_absolute_error: 1105.6667 - rmse: 1106.9095 - val_loss: 1249557.0000 - val_mean_absolute_error: 1116.0984 - val_rmse: 1117.8352
# Epoch 29/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1212605.6250 - mean_absolute_error: 1099.8685 - rmse: 1101.1831 - val_loss: 1186450.2500 - val_mean_absolute_error: 1087.5024 - val_rmse: 1089.2424
# Epoch 30/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1199294.6250 - mean_absolute_error: 1093.8888 - rmse: 1095.1226 - val_loss: 1181403.7500 - val_mean_absolute_error: 1085.2559 - val_rmse: 1086.9233
# Epoch 31/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1185935.2500 - mean_absolute_error: 1087.7334 - rmse: 1089.0059 - val_loss: 1186041.6250 - val_mean_absolute_error: 1087.2520 - val_rmse: 1089.0548
# Epoch 32/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1172179.1250 - mean_absolute_error: 1081.4055 - rmse: 1082.6715 - val_loss: 1165687.2500 - val_mean_absolute_error: 1077.9401 - val_rmse: 1079.6693
# Epoch 33/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1158038.6250 - mean_absolute_error: 1074.9124 - rmse: 1076.1212 - val_loss: 1132339.7500 - val_mean_absolute_error: 1062.7111 - val_rmse: 1064.1139
# Epoch 34/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1143852.2500 - mean_absolute_error: 1068.2435 - rmse: 1069.5096 - val_loss: 1150065.3750 - val_mean_absolute_error: 1071.0311 - val_rmse: 1072.4103
# Epoch 35/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1129067.2500 - mean_absolute_error: 1061.4150 - rmse: 1062.5751 - val_loss: 1139719.7500 - val_mean_absolute_error: 1066.3081 - val_rmse: 1067.5759
# Epoch 36/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1114309.3750 - mean_absolute_error: 1054.4225 - rmse: 1055.6078 - val_loss: 1103494.6250 - val_mean_absolute_error: 1049.1954 - val_rmse: 1050.4728
# Epoch 37/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1099217.2500 - mean_absolute_error: 1047.2792 - rmse: 1048.4351 - val_loss: 1098117.6250 - val_mean_absolute_error: 1046.6285 - val_rmse: 1047.9103
# Epoch 38/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1083895.3750 - mean_absolute_error: 1039.9757 - rmse: 1041.1023 - val_loss: 1092999.2500 - val_mean_absolute_error: 1044.3455 - val_rmse: 1045.4653
# Epoch 39/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1068460.2500 - mean_absolute_error: 1032.5240 - rmse: 1033.6627 - val_loss: 1093467.6250 - val_mean_absolute_error: 1044.4658 - val_rmse: 1045.6892
# Epoch 40/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1053026.3750 - mean_absolute_error: 1024.9242 - rmse: 1026.1699 - val_loss: 1066867.7500 - val_mean_absolute_error: 1031.0098 - val_rmse: 1032.8921
# Epoch 41/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1037123.2500 - mean_absolute_error: 1017.1838 - rmse: 1018.3915 - val_loss: 1035863.6875 - val_mean_absolute_error: 1016.2158 - val_rmse: 1017.7730
# Epoch 42/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1021195.5000 - mean_absolute_error: 1009.2986 - rmse: 1010.5413 - val_loss: 1027047.6875 - val_mean_absolute_error: 1011.7325 - val_rmse: 1013.4327
# Epoch 43/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1004905.1250 - mean_absolute_error: 1001.2759 - rmse: 1002.4485 - val_loss: 1059194.5000 - val_mean_absolute_error: 1027.3770 - val_rmse: 1029.1709
# Epoch 44/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 988608.4375 - mean_absolute_error: 993.1270 - rmse: 994.2870 - val_loss: 1028663.0000 - val_mean_absolute_error: 1012.6696 - val_rmse: 1014.2294
# Epoch 45/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 972256.0625 - mean_absolute_error: 984.8362 - rmse: 986.0295 - val_loss: 1017904.3750 - val_mean_absolute_error: 1006.5233 - val_rmse: 1008.9115
# Epoch 46/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 955613.6875 - mean_absolute_error: 976.4261 - rmse: 977.5540 - val_loss: 979951.5000 - val_mean_absolute_error: 987.9509 - val_rmse: 989.9240
# Epoch 47/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 939248.5000 - mean_absolute_error: 967.8889 - rmse: 969.1472 - val_loss: 974362.0625 - val_mean_absolute_error: 985.7788 - val_rmse: 987.0967
# Epoch 48/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 922313.3750 - mean_absolute_error: 959.2313 - rmse: 960.3704 - val_loss: 943661.8750 - val_mean_absolute_error: 970.1181 - val_rmse: 971.4216
# Epoch 49/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 905514.5625 - mean_absolute_error: 950.4568 - rmse: 951.5842 - val_loss: 908932.3125 - val_mean_absolute_error: 952.2298 - val_rmse: 953.3784
# Epoch 50/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 888770.5000 - mean_absolute_error: 941.5647 - rmse: 942.7452 - val_loss: 904053.7500 - val_mean_absolute_error: 949.5132 - val_rmse: 950.8163
# Epoch 51/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 871783.7500 - mean_absolute_error: 932.5623 - rmse: 933.6924 - val_loss: 890935.1250 - val_mean_absolute_error: 942.6367 - val_rmse: 943.8925
# Epoch 52/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 854909.5000 - mean_absolute_error: 923.4507 - rmse: 924.6120 - val_loss: 867211.1250 - val_mean_absolute_error: 929.9752 - val_rmse: 931.2407
# Epoch 53/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 837863.0625 - mean_absolute_error: 914.2406 - rmse: 915.3475 - val_loss: 844289.4375 - val_mean_absolute_error: 917.7876 - val_rmse: 918.8511
# Epoch 54/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 820714.9375 - mean_absolute_error: 904.9272 - rmse: 905.9321 - val_loss: 837264.0000 - val_mean_absolute_error: 913.9432 - val_rmse: 915.0201
# Epoch 55/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 803987.8750 - mean_absolute_error: 895.5145 - rmse: 896.6526 - val_loss: 820105.8125 - val_mean_absolute_error: 904.4089 - val_rmse: 905.5957
# Epoch 56/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 787009.3125 - mean_absolute_error: 886.0084 - rmse: 887.1342 - val_loss: 783424.9375 - val_mean_absolute_error: 883.9442 - val_rmse: 885.1118
# Epoch 57/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 769948.6875 - mean_absolute_error: 876.4211 - rmse: 877.4660 - val_loss: 782385.8125 - val_mean_absolute_error: 883.4317 - val_rmse: 884.5245
# Epoch 58/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 753098.2500 - mean_absolute_error: 866.7408 - rmse: 867.8111 - val_loss: 758739.8125 - val_mean_absolute_error: 869.7224 - val_rmse: 871.0555
# Epoch 59/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 736158.3125 - mean_absolute_error: 856.9769 - rmse: 857.9954 - val_loss: 721712.6250 - val_mean_absolute_error: 848.0555 - val_rmse: 849.5354
# Epoch 60/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 719273.9375 - mean_absolute_error: 847.1386 - rmse: 848.0989 - val_loss: 711595.6875 - val_mean_absolute_error: 842.3450 - val_rmse: 843.5601
# Epoch 61/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 702824.3125 - mean_absolute_error: 837.2109 - rmse: 838.3448 - val_loss: 702661.5625 - val_mean_absolute_error: 836.1514 - val_rmse: 838.2478
# Epoch 62/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 686197.3750 - mean_absolute_error: 827.2198 - rmse: 828.3691 - val_loss: 706322.8750 - val_mean_absolute_error: 839.1766 - val_rmse: 840.4289
# Epoch 63/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 669473.2500 - mean_absolute_error: 817.1646 - rmse: 818.2121 - val_loss: 704513.8750 - val_mean_absolute_error: 837.9949 - val_rmse: 839.3520
# Epoch 64/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 653143.1250 - mean_absolute_error: 807.0450 - rmse: 808.1713 - val_loss: 683613.1250 - val_mean_absolute_error: 825.4940 - val_rmse: 826.8076
# Epoch 65/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 636686.0625 - mean_absolute_error: 796.8605 - rmse: 797.9247 - val_loss: 672487.0625 - val_mean_absolute_error: 818.7095 - val_rmse: 820.0518
# Epoch 66/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 620501.0000 - mean_absolute_error: 786.6243 - rmse: 787.7174 - val_loss: 649172.8750 - val_mean_absolute_error: 804.3582 - val_rmse: 805.7112
# Epoch 67/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 604425.9375 - mean_absolute_error: 776.3220 - rmse: 777.4470 - val_loss: 610769.8125 - val_mean_absolute_error: 780.3789 - val_rmse: 781.5162
# Epoch 68/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 588492.5625 - mean_absolute_error: 765.9772 - rmse: 767.1312 - val_loss: 572332.5000 - val_mean_absolute_error: 754.7320 - val_rmse: 756.5251
# Epoch 69/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 572647.4375 - mean_absolute_error: 755.5803 - rmse: 756.7332 - val_loss: 575926.1875 - val_mean_absolute_error: 757.5648 - val_rmse: 758.8965
# Epoch 70/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 556820.1875 - mean_absolute_error: 745.1413 - rmse: 746.2024 - val_loss: 572103.6250 - val_mean_absolute_error: 754.8983 - val_rmse: 756.3738
# Epoch 71/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 541551.5000 - mean_absolute_error: 734.6595 - rmse: 735.9003 - val_loss: 545033.4375 - val_mean_absolute_error: 736.6808 - val_rmse: 738.2622
# Epoch 72/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 526196.6250 - mean_absolute_error: 724.1551 - rmse: 725.3925 - val_loss: 546346.5000 - val_mean_absolute_error: 737.5552 - val_rmse: 739.1509
# Epoch 73/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 510902.4062 - mean_absolute_error: 713.6095 - rmse: 714.7728 - val_loss: 542940.6875 - val_mean_absolute_error: 734.8653 - val_rmse: 736.8435
# Epoch 74/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 495924.5625 - mean_absolute_error: 703.0412 - rmse: 704.2175 - val_loss: 521269.8125 - val_mean_absolute_error: 720.3061 - val_rmse: 721.9886
# Epoch 75/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 481112.5625 - mean_absolute_error: 692.4368 - rmse: 693.6212 - val_loss: 512229.5000 - val_mean_absolute_error: 714.0051 - val_rmse: 715.7006
# Epoch 76/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 466614.6875 - mean_absolute_error: 681.8176 - rmse: 683.0903 - val_loss: 498882.0312 - val_mean_absolute_error: 704.7816 - val_rmse: 706.3143
# Epoch 77/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 452121.7500 - mean_absolute_error: 671.1935 - rmse: 672.3983 - val_loss: 487086.5000 - val_mean_absolute_error: 696.4140 - val_rmse: 697.9142
# Epoch 78/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 437939.2188 - mean_absolute_error: 660.5504 - rmse: 661.7681 - val_loss: 472904.2812 - val_mean_absolute_error: 686.0399 - val_rmse: 687.6788
# Epoch 79/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 424172.3750 - mean_absolute_error: 649.8766 - rmse: 651.2834 - val_loss: 438833.0938 - val_mean_absolute_error: 660.9813 - val_rmse: 662.4431
# Epoch 80/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 410291.5625 - mean_absolute_error: 639.2185 - rmse: 640.5384 - val_loss: 441246.9375 - val_mean_absolute_error: 662.4553 - val_rmse: 664.2625
# Epoch 81/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 396818.3750 - mean_absolute_error: 628.5623 - rmse: 629.9334 - val_loss: 423957.6562 - val_mean_absolute_error: 649.5171 - val_rmse: 651.1185
# Epoch 82/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 383382.0625 - mean_absolute_error: 617.9006 - rmse: 619.1767 - val_loss: 403292.5625 - val_mean_absolute_error: 632.9578 - val_rmse: 635.0514
# Epoch 83/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 370400.1562 - mean_absolute_error: 607.2277 - rmse: 608.6031 - val_loss: 376537.1875 - val_mean_absolute_error: 611.8917 - val_rmse: 613.6244
# Epoch 84/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 357522.2500 - mean_absolute_error: 596.5746 - rmse: 597.9297 - val_loss: 376017.9062 - val_mean_absolute_error: 610.9426 - val_rmse: 613.2011
# Epoch 85/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 344876.4688 - mean_absolute_error: 585.9451 - rmse: 587.2598 - val_loss: 355846.4688 - val_mean_absolute_error: 594.7182 - val_rmse: 596.5267
# Epoch 86/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 332363.8750 - mean_absolute_error: 575.3205 - rmse: 576.5080 - val_loss: 355158.4688 - val_mean_absolute_error: 594.1005 - val_rmse: 595.9498
# Epoch 87/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 320543.2188 - mean_absolute_error: 564.7324 - rmse: 566.1633 - val_loss: 352134.9062 - val_mean_absolute_error: 590.6874 - val_rmse: 593.4075
# Epoch 88/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 308830.6875 - mean_absolute_error: 554.1493 - rmse: 555.7233 - val_loss: 320084.7188 - val_mean_absolute_error: 563.6684 - val_rmse: 565.7582
# Epoch 89/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 296949.7500 - mean_absolute_error: 543.6080 - rmse: 544.9288 - val_loss: 299462.5938 - val_mean_absolute_error: 545.0298 - val_rmse: 547.2296
# Epoch 90/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 285885.9062 - mean_absolute_error: 533.1048 - rmse: 534.6807 - val_loss: 289525.0000 - val_mean_absolute_error: 536.2409 - val_rmse: 538.0730
# Epoch 91/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 274806.0000 - mean_absolute_error: 522.6218 - rmse: 524.2172 - val_loss: 288602.9062 - val_mean_absolute_error: 535.1910 - val_rmse: 537.2155
# Epoch 92/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 263682.9375 - mean_absolute_error: 512.1751 - rmse: 513.4982 - val_loss: 288672.9375 - val_mean_absolute_error: 535.2492 - val_rmse: 537.2806
# Epoch 93/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 253315.9375 - mean_absolute_error: 501.7806 - rmse: 503.3026 - val_loss: 272904.5938 - val_mean_absolute_error: 520.0219 - val_rmse: 522.4004
# Epoch 94/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 242983.9375 - mean_absolute_error: 491.4423 - rmse: 492.9315 - val_loss: 250320.0625 - val_mean_absolute_error: 498.1015 - val_rmse: 500.3175
# Epoch 95/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 233086.6250 - mean_absolute_error: 481.1477 - rmse: 482.7879 - val_loss: 242556.0469 - val_mean_absolute_error: 489.5224 - val_rmse: 492.4973
# Epoch 96/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 223352.7656 - mean_absolute_error: 470.9063 - rmse: 472.5995 - val_loss: 239048.2969 - val_mean_absolute_error: 486.6077 - val_rmse: 488.9231
# Epoch 97/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 213824.8594 - mean_absolute_error: 460.7150 - rmse: 462.4094 - val_loss: 230709.4062 - val_mean_absolute_error: 477.6752 - val_rmse: 480.3197
# Epoch 98/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 204521.3906 - mean_absolute_error: 450.5747 - rmse: 452.2377 - val_loss: 229408.6250 - val_mean_absolute_error: 476.8176 - val_rmse: 478.9636
# Epoch 99/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 195602.8750 - mean_absolute_error: 440.5114 - rmse: 442.2673 - val_loss: 217372.4688 - val_mean_absolute_error: 464.1595 - val_rmse: 466.2296
# Epoch 100/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 186788.4688 - mean_absolute_error: 430.5342 - rmse: 432.1874 - val_loss: 203623.6875 - val_mean_absolute_error: 448.9106 - val_rmse: 451.2440
# Epoch 101/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 178569.5156 - mean_absolute_error: 420.6310 - rmse: 422.5718 - val_loss: 193154.3125 - val_mean_absolute_error: 436.9262 - val_rmse: 439.4904
# Epoch 102/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 170258.4688 - mean_absolute_error: 410.7912 - rmse: 412.6208 - val_loss: 190095.8281 - val_mean_absolute_error: 433.5744 - val_rmse: 435.9969
# Epoch 103/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 162347.5938 - mean_absolute_error: 401.0277 - rmse: 402.9207 - val_loss: 173907.5625 - val_mean_absolute_error: 414.4055 - val_rmse: 417.0192
# Epoch 104/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 154673.3750 - mean_absolute_error: 391.3332 - rmse: 393.2821 - val_loss: 159874.8906 - val_mean_absolute_error: 397.2235 - val_rmse: 399.8404
# Epoch 105/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 147074.5312 - mean_absolute_error: 381.7375 - rmse: 383.4996 - val_loss: 151927.8594 - val_mean_absolute_error: 386.9851 - val_rmse: 389.7759
# Epoch 106/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 139897.1094 - mean_absolute_error: 372.2360 - rmse: 374.0248 - val_loss: 152099.5938 - val_mean_absolute_error: 387.5270 - val_rmse: 389.9962
# Epoch 107/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 133155.1250 - mean_absolute_error: 362.8220 - rmse: 364.9007 - val_loss: 142549.7969 - val_mean_absolute_error: 373.9512 - val_rmse: 377.5542
# Epoch 108/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 126651.7812 - mean_absolute_error: 353.5102 - rmse: 355.8780 - val_loss: 136374.9062 - val_mean_absolute_error: 366.1007 - val_rmse: 369.2862
# Epoch 109/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 119967.9688 - mean_absolute_error: 344.2893 - rmse: 346.3601 - val_loss: 131203.5156 - val_mean_absolute_error: 359.0932 - val_rmse: 362.2166
# Epoch 110/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 113786.4297 - mean_absolute_error: 335.1787 - rmse: 337.3185 - val_loss: 119660.0469 - val_mean_absolute_error: 342.8080 - val_rmse: 345.9153
# Epoch 111/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 107978.6953 - mean_absolute_error: 326.1907 - rmse: 328.5970 - val_loss: 106507.8203 - val_mean_absolute_error: 322.8395 - val_rmse: 326.3513
# Epoch 112/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 102098.5938 - mean_absolute_error: 317.2719 - rmse: 319.5245 - val_loss: 111169.7812 - val_mean_absolute_error: 329.3948 - val_rmse: 333.4173
# Epoch 113/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 96689.1172 - mean_absolute_error: 308.4773 - rmse: 310.9444 - val_loss: 107106.7969 - val_mean_absolute_error: 323.6905 - val_rmse: 327.2676
# Epoch 114/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 91273.7344 - mean_absolute_error: 299.7890 - rmse: 302.1109 - val_loss: 99837.1094 - val_mean_absolute_error: 312.2843 - val_rmse: 315.9658
# Epoch 115/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 86270.4375 - mean_absolute_error: 291.1975 - rmse: 293.7137 - val_loss: 94600.7188 - val_mean_absolute_error: 302.0770 - val_rmse: 307.5678
# Epoch 116/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 81389.6719 - mean_absolute_error: 282.7775 - rmse: 285.2839 - val_loss: 88001.6953 - val_mean_absolute_error: 293.2124 - val_rmse: 296.6461
# Epoch 117/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 76768.9062 - mean_absolute_error: 274.4634 - rmse: 277.0670 - val_loss: 89472.7031 - val_mean_absolute_error: 295.2866 - val_rmse: 299.1152
# Epoch 118/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 72209.7031 - mean_absolute_error: 266.2737 - rmse: 268.7134 - val_loss: 86429.9766 - val_mean_absolute_error: 290.3115 - val_rmse: 293.9850
# Epoch 119/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 67946.2500 - mean_absolute_error: 258.1930 - rmse: 260.6596 - val_loss: 78027.3906 - val_mean_absolute_error: 275.2816 - val_rmse: 279.3288
# Epoch 120/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 63904.6836 - mean_absolute_error: 250.2471 - rmse: 252.7882 - val_loss: 74755.9062 - val_mean_absolute_error: 269.1077 - val_rmse: 273.4101
# Epoch 121/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 60189.4023 - mean_absolute_error: 242.4414 - rmse: 245.3295 - val_loss: 67780.5234 - val_mean_absolute_error: 255.5289 - val_rmse: 260.3414
# Epoch 122/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 56349.4922 - mean_absolute_error: 234.7591 - rmse: 237.3745 - val_loss: 65788.2891 - val_mean_absolute_error: 251.5540 - val_rmse: 256.4867
# Epoch 123/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 52970.9727 - mean_absolute_error: 227.2113 - rmse: 230.1480 - val_loss: 66445.3906 - val_mean_absolute_error: 252.7340 - val_rmse: 257.7644
# Epoch 124/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 49678.1133 - mean_absolute_error: 219.8011 - rmse: 222.8794 - val_loss: 63634.1875 - val_mean_absolute_error: 246.8520 - val_rmse: 252.2524
# Epoch 125/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 46476.1172 - mean_absolute_error: 212.5116 - rmse: 215.5764 - val_loss: 59895.3867 - val_mean_absolute_error: 239.6494 - val_rmse: 244.7294
# Epoch 126/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 43429.9297 - mean_absolute_error: 205.3629 - rmse: 208.3915 - val_loss: 57458.9062 - val_mean_absolute_error: 234.9060 - val_rmse: 239.6998
# Epoch 127/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 40757.2070 - mean_absolute_error: 198.3863 - rmse: 201.8768 - val_loss: 56058.6133 - val_mean_absolute_error: 231.2402 - val_rmse: 236.7607
# Epoch 128/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 37991.1953 - mean_absolute_error: 191.5591 - rmse: 194.9056 - val_loss: 52093.6484 - val_mean_absolute_error: 223.1444 - val_rmse: 228.2337
# Epoch 129/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 35507.9023 - mean_absolute_error: 184.8406 - rmse: 188.4274 - val_loss: 49641.3672 - val_mean_absolute_error: 217.4246 - val_rmse: 222.7966
# Epoch 130/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 33144.0117 - mean_absolute_error: 178.2645 - rmse: 182.0465 - val_loss: 50861.3828 - val_mean_absolute_error: 219.7497 - val_rmse: 225.5179
# Epoch 131/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 31066.3027 - mean_absolute_error: 171.8437 - rmse: 176.2476 - val_loss: 44426.1289 - val_mean_absolute_error: 204.2965 - val_rmse: 210.7677
# Epoch 132/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28817.2578 - mean_absolute_error: 165.6008 - rmse: 169.7473 - val_loss: 42971.6172 - val_mean_absolute_error: 200.7990 - val_rmse: 207.2885
# Epoch 133/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26656.1621 - mean_absolute_error: 159.4516 - rmse: 163.2576 - val_loss: 41294.2930 - val_mean_absolute_error: 197.2786 - val_rmse: 203.2023
# Epoch 134/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25014.1719 - mean_absolute_error: 153.4529 - rmse: 158.1487 - val_loss: 35768.4062 - val_mean_absolute_error: 182.4879 - val_rmse: 189.1170
# Epoch 135/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23186.7422 - mean_absolute_error: 147.5936 - rmse: 152.2615 - val_loss: 36000.5391 - val_mean_absolute_error: 181.8162 - val_rmse: 189.7296
# Epoch 136/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21551.2773 - mean_absolute_error: 141.8677 - rmse: 146.7925 - val_loss: 31692.9492 - val_mean_absolute_error: 171.2181 - val_rmse: 178.0160
# Epoch 137/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19860.8516 - mean_absolute_error: 136.3043 - rmse: 140.9170 - val_loss: 28919.5020 - val_mean_absolute_error: 162.8385 - val_rmse: 170.0478
# Epoch 138/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18416.0664 - mean_absolute_error: 130.9103 - rmse: 135.6938 - val_loss: 30231.0078 - val_mean_absolute_error: 166.8801 - val_rmse: 173.8613
# Epoch 139/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17075.5332 - mean_absolute_error: 125.6737 - rmse: 130.6609 - val_loss: 27420.0996 - val_mean_absolute_error: 158.0763 - val_rmse: 165.5803
# Epoch 140/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15838.5879 - mean_absolute_error: 120.6101 - rmse: 125.8384 - val_loss: 22106.5098 - val_mean_absolute_error: 141.5350 - val_rmse: 148.6715
# Epoch 141/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14532.7500 - mean_absolute_error: 115.6020 - rmse: 120.5383 - val_loss: 17806.4863 - val_mean_absolute_error: 124.2187 - val_rmse: 133.4287
# Epoch 142/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13506.3682 - mean_absolute_error: 110.7542 - rmse: 116.2029 - val_loss: 21501.4785 - val_mean_absolute_error: 138.4189 - val_rmse: 146.6227
# Epoch 143/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12532.0068 - mean_absolute_error: 106.1615 - rmse: 111.9319 - val_loss: 19888.7344 - val_mean_absolute_error: 134.2663 - val_rmse: 141.0158
# Epoch 144/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11618.7832 - mean_absolute_error: 101.5600 - rmse: 107.7751 - val_loss: 18308.0078 - val_mean_absolute_error: 126.9441 - val_rmse: 135.2948
# Epoch 145/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10750.2812 - mean_absolute_error: 97.2100 - rmse: 103.6675 - val_loss: 18472.1172 - val_mean_absolute_error: 127.7601 - val_rmse: 135.8999
# Epoch 146/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10052.6436 - mean_absolute_error: 92.9416 - rmse: 100.2462 - val_loss: 16229.0186 - val_mean_absolute_error: 116.1955 - val_rmse: 127.3800
# Epoch 147/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9209.6846 - mean_absolute_error: 89.0566 - rmse: 95.9495 - val_loss: 17228.7363 - val_mean_absolute_error: 121.5660 - val_rmse: 131.2453
# Epoch 148/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8279.2119 - mean_absolute_error: 84.9167 - rmse: 90.9715 - val_loss: 17675.7480 - val_mean_absolute_error: 123.6904 - val_rmse: 132.9374
# Epoch 149/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7689.7197 - mean_absolute_error: 81.3548 - rmse: 87.6717 - val_loss: 14023.2129 - val_mean_absolute_error: 108.4199 - val_rmse: 118.4054
# Epoch 150/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7064.4927 - mean_absolute_error: 77.4594 - rmse: 84.0303 - val_loss: 13896.1113 - val_mean_absolute_error: 108.0063 - val_rmse: 117.8673
# Epoch 151/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6526.4814 - mean_absolute_error: 73.9476 - rmse: 80.7655 - val_loss: 14219.1494 - val_mean_absolute_error: 108.1659 - val_rmse: 119.2297
# Epoch 152/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6056.2119 - mean_absolute_error: 70.7039 - rmse: 77.7994 - val_loss: 11024.3789 - val_mean_absolute_error: 93.3092 - val_rmse: 104.9805
# Epoch 153/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5612.1636 - mean_absolute_error: 67.7327 - rmse: 74.8911 - val_loss: 10367.5430 - val_mean_absolute_error: 89.1477 - val_rmse: 101.8039
# Epoch 154/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5596.4692 - mean_absolute_error: 66.3900 - rmse: 74.7859 - val_loss: 7244.1533 - val_mean_absolute_error: 71.8333 - val_rmse: 85.0917
# Epoch 155/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4826.7773 - mean_absolute_error: 61.7801 - rmse: 69.4492 - val_loss: 8198.3086 - val_mean_absolute_error: 78.7683 - val_rmse: 90.5246
# Epoch 156/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4512.5171 - mean_absolute_error: 59.4267 - rmse: 67.1485 - val_loss: 9986.2871 - val_mean_absolute_error: 86.2317 - val_rmse: 99.9134
# Epoch 157/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4325.5098 - mean_absolute_error: 56.9002 - rmse: 65.7412 - val_loss: 7500.5093 - val_mean_absolute_error: 72.1661 - val_rmse: 86.5847
# Epoch 158/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3871.2959 - mean_absolute_error: 54.4459 - rmse: 62.1909 - val_loss: 7254.8984 - val_mean_absolute_error: 72.3623 - val_rmse: 85.1546
# Epoch 159/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3547.2300 - mean_absolute_error: 52.1477 - rmse: 59.5283 - val_loss: 7176.9307 - val_mean_absolute_error: 71.9842 - val_rmse: 84.6954
# Epoch 160/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3215.0398 - mean_absolute_error: 48.7154 - rmse: 56.6693 - val_loss: 8628.0020 - val_mean_absolute_error: 80.3302 - val_rmse: 92.8674
# Epoch 161/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2995.9802 - mean_absolute_error: 46.9100 - rmse: 54.7022 - val_loss: 8003.1313 - val_mean_absolute_error: 78.2562 - val_rmse: 89.4398
# Epoch 162/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2773.0535 - mean_absolute_error: 44.9255 - rmse: 52.6250 - val_loss: 7147.5967 - val_mean_absolute_error: 71.9643 - val_rmse: 84.5218
# Epoch 163/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2643.1104 - mean_absolute_error: 43.1259 - rmse: 51.3755 - val_loss: 5496.4487 - val_mean_absolute_error: 60.1520 - val_rmse: 74.1133
# Epoch 164/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2563.1465 - mean_absolute_error: 42.3393 - rmse: 50.5911 - val_loss: 6560.2217 - val_mean_absolute_error: 69.1783 - val_rmse: 80.9724
# Epoch 165/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2594.1736 - mean_absolute_error: 42.1213 - rmse: 50.8966 - val_loss: 5003.2148 - val_mean_absolute_error: 57.8339 - val_rmse: 70.7070
# Epoch 166/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2306.3030 - mean_absolute_error: 38.8603 - rmse: 47.9850 - val_loss: 5987.6675 - val_mean_absolute_error: 63.5492 - val_rmse: 77.3559
# Epoch 167/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2149.4258 - mean_absolute_error: 37.8334 - rmse: 46.3216 - val_loss: 4605.3608 - val_mean_absolute_error: 56.0614 - val_rmse: 67.8351
# Epoch 168/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1924.7369 - mean_absolute_error: 35.0920 - rmse: 43.8289 - val_loss: 4267.1714 - val_mean_absolute_error: 52.9102 - val_rmse: 65.2947
# Epoch 169/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1831.4584 - mean_absolute_error: 34.4123 - rmse: 42.7513 - val_loss: 5356.4209 - val_mean_absolute_error: 61.0227 - val_rmse: 73.1616
# Epoch 170/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2098.1147 - mean_absolute_error: 37.2458 - rmse: 45.7638 - val_loss: 4066.2620 - val_mean_absolute_error: 51.7861 - val_rmse: 63.7375
# Epoch 171/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1762.2404 - mean_absolute_error: 33.1548 - rmse: 41.9337 - val_loss: 3863.8169 - val_mean_absolute_error: 48.7530 - val_rmse: 62.1290
# Epoch 172/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1705.0924 - mean_absolute_error: 32.6115 - rmse: 41.2466 - val_loss: 4154.1528 - val_mean_absolute_error: 51.9704 - val_rmse: 64.4231
# Epoch 173/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1674.8815 - mean_absolute_error: 32.2331 - rmse: 40.8785 - val_loss: 4543.7915 - val_mean_absolute_error: 57.1520 - val_rmse: 67.3791
# Epoch 174/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1530.2043 - mean_absolute_error: 30.8252 - rmse: 39.0683 - val_loss: 4589.5737 - val_mean_absolute_error: 54.7595 - val_rmse: 67.7177
# Epoch 175/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1532.0067 - mean_absolute_error: 30.3794 - rmse: 39.0907 - val_loss: 4280.5342 - val_mean_absolute_error: 53.6802 - val_rmse: 65.3956
# Epoch 176/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1598.2567 - mean_absolute_error: 31.5582 - rmse: 39.9284 - val_loss: 4313.9038 - val_mean_absolute_error: 53.9262 - val_rmse: 65.6497
# Epoch 177/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1439.7606 - mean_absolute_error: 29.9053 - rmse: 37.8910 - val_loss: 5286.9854 - val_mean_absolute_error: 60.8775 - val_rmse: 72.6838
# Epoch 178/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1407.4216 - mean_absolute_error: 28.5901 - rmse: 37.4614 - val_loss: 4160.0078 - val_mean_absolute_error: 55.1068 - val_rmse: 64.4666
# Epoch 179/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1316.7549 - mean_absolute_error: 28.0246 - rmse: 36.2311 - val_loss: 4345.8682 - val_mean_absolute_error: 54.4537 - val_rmse: 65.8923
# Epoch 180/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1212.2546 - mean_absolute_error: 26.9556 - rmse: 34.7588 - val_loss: 5117.1895 - val_mean_absolute_error: 59.5341 - val_rmse: 71.5060
# Epoch 181/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1153.6726 - mean_absolute_error: 26.2749 - rmse: 33.9055 - val_loss: 4112.7710 - val_mean_absolute_error: 53.2481 - val_rmse: 64.0989
# Epoch 182/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1227.4332 - mean_absolute_error: 27.2012 - rmse: 34.9761 - val_loss: 3607.0894 - val_mean_absolute_error: 49.5386 - val_rmse: 60.0248
# Epoch 183/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1159.2059 - mean_absolute_error: 26.3223 - rmse: 33.9867 - val_loss: 4666.9204 - val_mean_absolute_error: 55.9031 - val_rmse: 68.2848
# Epoch 184/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1112.2516 - mean_absolute_error: 25.2431 - rmse: 33.2888 - val_loss: 6092.0063 - val_mean_absolute_error: 64.2377 - val_rmse: 78.0249
# Epoch 185/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1246.4227 - mean_absolute_error: 26.4112 - rmse: 35.2463 - val_loss: 3781.0051 - val_mean_absolute_error: 50.6740 - val_rmse: 61.4563
# Epoch 186/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1133.8416 - mean_absolute_error: 25.7293 - rmse: 33.6110 - val_loss: 4649.9380 - val_mean_absolute_error: 55.0139 - val_rmse: 68.1600
# Epoch 187/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1095.0822 - mean_absolute_error: 25.2840 - rmse: 33.0290 - val_loss: 4398.2651 - val_mean_absolute_error: 52.7701 - val_rmse: 66.2878
# Epoch 188/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1119.9650 - mean_absolute_error: 24.9841 - rmse: 33.4031 - val_loss: 5392.4492 - val_mean_absolute_error: 59.9139 - val_rmse: 73.4046
# Epoch 189/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1142.2207 - mean_absolute_error: 26.0132 - rmse: 33.7344 - val_loss: 5380.2339 - val_mean_absolute_error: 60.9714 - val_rmse: 73.3213
# Epoch 190/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1004.5546 - mean_absolute_error: 24.4276 - rmse: 31.6280 - val_loss: 4159.3062 - val_mean_absolute_error: 50.5693 - val_rmse: 64.4600
# Epoch 191/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1042.9240 - mean_absolute_error: 24.4385 - rmse: 32.2290 - val_loss: 3580.3523 - val_mean_absolute_error: 48.3683 - val_rmse: 59.8008
# Epoch 192/500
# ...
# Epoch 463/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 611.3082 - mean_absolute_error: 18.1256 - rmse: 24.5027 - val_loss: 2621.2534 - val_mean_absolute_error: 41.4081 - val_rmse: 51.0912
# Epoch 464/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 703.0485 - mean_absolute_error: 19.6052 - rmse: 26.3081 - val_loss: 2375.5571 - val_mean_absolute_error: 42.3656 - val_rmse: 48.6275
# Epoch 465/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 654.2901 - mean_absolute_error: 18.7384 - rmse: 25.3645 - val_loss: 2884.6299 - val_mean_absolute_error: 43.3971 - val_rmse: 53.6068
# Epoch 466/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 654.8343 - mean_absolute_error: 18.6787 - rmse: 25.3749 - val_loss: 2701.5083 - val_mean_absolute_error: 44.8692 - val_rmse: 51.8703
# Epoch 467/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 704.2824 - mean_absolute_error: 20.0110 - rmse: 26.3302 - val_loss: 2582.4146 - val_mean_absolute_error: 41.1474 - val_rmse: 50.7089
# Epoch 468/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 628.3461 - mean_absolute_error: 18.4108 - rmse: 24.8463 - val_loss: 2128.4348 - val_mean_absolute_error: 36.9048 - val_rmse: 46.0155
# Epoch 469/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 634.2104 - mean_absolute_error: 19.1356 - rmse: 24.9639 - val_loss: 2339.6570 - val_mean_absolute_error: 37.3793 - val_rmse: 48.2562
# Epoch 470/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 781.3980 - mean_absolute_error: 20.9377 - rmse: 27.7562 - val_loss: 2729.3069 - val_mean_absolute_error: 39.9978 - val_rmse: 52.1373
# Epoch 471/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 648.9799 - mean_absolute_error: 19.0772 - rmse: 25.2580 - val_loss: 2552.3262 - val_mean_absolute_error: 40.5179 - val_rmse: 50.4111
# Epoch 472/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 619.2241 - mean_absolute_error: 18.9931 - rmse: 24.6601 - val_loss: 2392.2568 - val_mean_absolute_error: 38.9800 - val_rmse: 48.7967
# Epoch 473/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 658.7887 - mean_absolute_error: 18.9685 - rmse: 25.4490 - val_loss: 2154.6375 - val_mean_absolute_error: 36.8432 - val_rmse: 46.2983
# Epoch 474/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 668.4675 - mean_absolute_error: 19.3772 - rmse: 25.6396 - val_loss: 2663.6467 - val_mean_absolute_error: 41.0161 - val_rmse: 51.5029
# Epoch 475/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 667.0927 - mean_absolute_error: 19.0746 - rmse: 25.6127 - val_loss: 2398.5518 - val_mean_absolute_error: 37.8257 - val_rmse: 48.8616
# Epoch 476/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 697.1516 - mean_absolute_error: 19.9149 - rmse: 26.1926 - val_loss: 3062.1907 - val_mean_absolute_error: 44.2491 - val_rmse: 55.2366
# Epoch 477/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 731.9222 - mean_absolute_error: 20.0246 - rmse: 26.8475 - val_loss: 2458.0225 - val_mean_absolute_error: 37.8514 - val_rmse: 49.4658
# Epoch 478/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 590.2209 - mean_absolute_error: 18.2637 - rmse: 24.0637 - val_loss: 2665.9641 - val_mean_absolute_error: 41.1740 - val_rmse: 51.5245
# Epoch 479/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 678.8343 - mean_absolute_error: 19.4420 - rmse: 25.8389 - val_loss: 2577.6963 - val_mean_absolute_error: 40.9982 - val_rmse: 50.6609
# Epoch 480/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 804.7916 - mean_absolute_error: 21.3008 - rmse: 28.1711 - val_loss: 3167.9697 - val_mean_absolute_error: 44.1910 - val_rmse: 56.1850
# Epoch 481/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 953.6929 - mean_absolute_error: 22.5463 - rmse: 30.7000 - val_loss: 4004.4749 - val_mean_absolute_error: 47.2678 - val_rmse: 63.1927
# Epoch 482/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 739.4556 - mean_absolute_error: 20.3913 - rmse: 26.9866 - val_loss: 4260.2939 - val_mean_absolute_error: 42.7921 - val_rmse: 65.1851
# Epoch 483/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 649.8439 - mean_absolute_error: 18.7478 - rmse: 25.2711 - val_loss: 3203.6992 - val_mean_absolute_error: 42.0058 - val_rmse: 56.5019
# Epoch 484/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 758.8503 - mean_absolute_error: 20.3697 - rmse: 27.3420 - val_loss: 2694.3149 - val_mean_absolute_error: 39.9126 - val_rmse: 51.7979
# Epoch 485/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 784.1169 - mean_absolute_error: 21.2698 - rmse: 27.7993 - val_loss: 3345.6575 - val_mean_absolute_error: 44.6348 - val_rmse: 57.7437
# Epoch 486/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 696.8064 - mean_absolute_error: 20.1105 - rmse: 26.1812 - val_loss: 3114.5779 - val_mean_absolute_error: 42.3339 - val_rmse: 55.7064
# Epoch 487/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 762.4915 - mean_absolute_error: 20.6492 - rmse: 27.4065 - val_loss: 2360.2437 - val_mean_absolute_error: 36.4455 - val_rmse: 48.4651
# Epoch 488/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 776.1268 - mean_absolute_error: 20.8927 - rmse: 27.6541 - val_loss: 3336.8457 - val_mean_absolute_error: 41.1957 - val_rmse: 57.6667
# Epoch 489/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 682.1972 - mean_absolute_error: 19.4562 - rmse: 25.8993 - val_loss: 2921.3218 - val_mean_absolute_error: 38.4121 - val_rmse: 53.9432
# Epoch 490/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 669.7755 - mean_absolute_error: 19.2404 - rmse: 25.6571 - val_loss: 2938.3994 - val_mean_absolute_error: 40.6238 - val_rmse: 54.1007
# Epoch 491/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 733.7908 - mean_absolute_error: 20.1384 - rmse: 26.8749 - val_loss: 2703.1489 - val_mean_absolute_error: 41.1820 - val_rmse: 51.8805
# Epoch 492/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 677.3488 - mean_absolute_error: 19.5241 - rmse: 25.8024 - val_loss: 2310.3018 - val_mean_absolute_error: 37.4901 - val_rmse: 47.9447
# Epoch 493/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 733.7720 - mean_absolute_error: 20.4225 - rmse: 26.8739 - val_loss: 2365.3301 - val_mean_absolute_error: 37.9308 - val_rmse: 48.5158
# Epoch 494/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 849.2455 - mean_absolute_error: 21.4590 - rmse: 28.9420 - val_loss: 2185.4153 - val_mean_absolute_error: 37.1088 - val_rmse: 46.6234
# Epoch 495/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 875.8267 - mean_absolute_error: 22.1583 - rmse: 29.3962 - val_loss: 2378.6948 - val_mean_absolute_error: 41.7153 - val_rmse: 48.6517
# Epoch 496/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 723.0982 - mean_absolute_error: 20.1093 - rmse: 26.6710 - val_loss: 2431.6926 - val_mean_absolute_error: 37.8870 - val_rmse: 49.1924
# Epoch 497/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 709.9378 - mean_absolute_error: 20.1504 - rmse: 26.4222 - val_loss: 2105.2251 - val_mean_absolute_error: 37.7717 - val_rmse: 45.7538
# Epoch 498/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 649.7319 - mean_absolute_error: 19.1272 - rmse: 25.2566 - val_loss: 2261.1628 - val_mean_absolute_error: 39.1961 - val_rmse: 47.4269
# Epoch 499/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 695.6053 - mean_absolute_error: 19.5310 - rmse: 26.1486 - val_loss: 2055.7295 - val_mean_absolute_error: 37.2577 - val_rmse: 45.2091
# Epoch 500/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 779.1303 - mean_absolute_error: 20.5084 - rmse: 27.6995 - val_loss: 2136.3884 - val_mean_absolute_error: 38.5631 - val_rmse: 46.0925
# --- 모델 훈련 완료 ---
#
# --- 최종 모델 평가 (Test Set) ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2332.7776 - mean_absolute_error: 34.8642 - rmse: 48.1758
# loss: 2332.7776
# compile_metrics: 34.8642
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_52          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_53          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_54          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_55          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_56          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_58          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_59          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,642,824 (13.90 MB)
#  Trainable params: 1,213,762 (4.63 MB)
#  Non-trainable params: 1,536 (6.00 KB)
#  Optimizer params: 2,427,526 (9.26 MB)

# %%
LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_52          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_53          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_54          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_55          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_56          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_58          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_59          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,642,824 (13.90 MB)
#  Trainable params: 1,213,762 (4.63 MB)
#  Non-trainable params: 1,536 (6.00 KB)
#  Optimizer params: 2,427,526 (9.26 MB)
