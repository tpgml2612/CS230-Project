# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pathlib import Path
import matplotlib.pyplot as plt
import glob
import re
import warnings
from datetime import datetime
import os
import csv

# %%
def trim_and_flatten_data(haptic_df):
    # Haptic: 4, 5th columns (index 3, 4)
    # Robot: 9, 10, 11th columns (index 8, 9, 10)
    haptic_data = haptic_df.iloc[:, [3, 4]].values
    
    # Process NaN values by replacing them with zeros
    haptic_data = np.nan_to_num(haptic_data, nan=0.0)
    return haptic_data.flatten()

# %%
def load_all_data(data_base_path):
    base_path = Path(data_base_path) / "DATA"

    all_X_data = []
    all_y_data = []

    METHOD_MAP = {'HAPTICS': 'H', 'NOhaptics': 'NH'}
    TASK_MAP = {
        5: ('pp1', 'PAP'), 6: ('pp1', 'PAP'),
        7: ('pp2', 'PAPObstructed'), 8: ('pp2', 'PAPObstructed'),
        9: ('pp3', 'Camera'), 10: ('pp3', 'Camera')
    }

    for p_id in range(1, 27): # 1~26

        participant_str = f"Participant_{p_id}"
        results_file = base_path / "Haptic Data" / participant_str / f"{participant_str}_results.csv"
        
        results_lookup = {}
        try:
            results_df = pd.read_csv(results_file)
            for _, row in results_df.iterrows():
                try:
                    condition = row['Condition']
                    subcondition = row['Subcondition']
                    trial_str = str(row['Trial'])
                    trial = int(re.search(r'^\d+', trial_str).group())
                    output_1 = pd.to_numeric(row['Sensor1 Mean'], errors='coerce')
                    output_2 = pd.to_numeric(row['Sensor2 Mean'], errors='coerce')

                    if pd.isna(output_1) or pd.isna(output_2):
                        continue
                    key = (condition, subcondition, trial)
                    results_lookup[key] = (output_1, output_2)
                except Exception:
                    continue
        except Exception as e:
            print(f"Error in reading ({results_file}): {e}")
            continue
        haptic_files_glob = glob.glob(str(base_path / "Haptic Data" / participant_str / "*.csv"))

        for hfile_path in haptic_files_glob:
            file_name = Path(hfile_path).name
            match = re.match(r'(\d+)_.*?_(HAPTICS|NOhaptics)_(\d+)\.csv', file_name)
            
            if not match:
                continue

            try:
                task_num = int(match.group(1))
                method = match.group(2)
                trial = int(match.group(3))
                
                if task_num not in TASK_MAP:
                    continue

                scenario_num, result_condition = TASK_MAP[task_num]
                method_short = METHOD_MAP[method]

                output_key = (result_condition, method, trial)
                if output_key not in results_lookup:
                    continue

                haptic_df = pd.read_csv(hfile_path)

                flat_input_vector = trim_and_flatten_data(haptic_df)

                if flat_input_vector is not None:
                    output_1, output_2 = results_lookup[output_key]
                    output_vector = np.array([output_1, output_2])
                    all_X_data.append(flat_input_vector)
                    all_y_data.append(output_vector)
            
                print(f" Success: participant {p_id} task {task_num}, method {method}, trial {trial}")
            except Exception as e:
                print(f"  Error: {file_name} - {e}")

    max_len = max(len(x) for x in all_X_data)
    
    X_padded = np.array([np.pad(x, (0, max_len - len(x)), 'constant') for x in all_X_data])
    y_array = np.array(all_y_data)

    return X_padded, y_array

# %%
def split_data(X, y, test_size=0.2, dev_size=0.125, random_state=42):
    """
    데이터를 훈련, 개발, 테스트 세트로 분리합니다. (기본 70:10:20)
    """
    if X.shape[0] == 0:
        print("오류: 분리할 데이터가 없습니다.")
        return (np.array([]),)*6

    # 1차 분리: 훈련+개발 (80%) / 테스트 (20%)
    X_train_dev, X_test, y_train_dev, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    # 2차 분리: 훈련 (70%) / 개발 (10%)
    X_train, X_dev, y_train, y_dev = train_test_split(
        X_train_dev, y_train_dev, test_size=dev_size, random_state=random_state
    )

    print(f"데이터 분리 완료:")
    print(f"  훈련 (Train)  : {X_train.shape}, {y_train.shape}")
    print(f"  개발 (Dev)    : {X_dev.shape}, {y_dev.shape}")
    print(f"  테스트 (Test) : {X_test.shape}, {y_test.shape}")

    return X_train, X_dev, X_test, y_train, y_dev, y_test

# %%
def get_regularizer(config):
    reg_type = config.get('regularizer_type', None)
    l1_val = config.get('l1', 0.01)
    l2_val = config.get('l2', 0.01)

    if reg_type == 'l1': return regularizers.l1(l1_val)
    elif reg_type == 'l2': return regularizers.l2(l2_val)
    elif reg_type == 'l1_l2': return regularizers.l1_l2(l1=l1_val, l2=l2_val)
    else: return None

# %%
def build_model(input_shape, model_config):
    model = Sequential(name="Modular_DNN_Model")
    model.add(InputLayer(input_shape=input_shape))

    hidden_layers = model_config.get('hidden_layers', [64, 32])
    activation = model_config.get('activation', 'relu')
    reg_obj = get_regularizer(model_config)

    for units in hidden_layers:
        model.add(Dense(units, activation=activation, kernel_regularizer=reg_obj))
        if model_config.get('use_batch_norm', False):
            model.add(BatchNormalization())
        if model_config.get('dropout_rate', 0.0) > 0:
            model.add(Dropout(model_config['dropout_rate']))

    model.add(Dense(2, name='output')) # 2개 값 예측 (회귀)

    print("모델 구성 완료:")
    model.summary()
    return model

# %%
def compile_and_train_model(model, X_train, y_train, X_val, y_val, train_config):
    loss_function = train_config.get('loss', 'mean_squared_error')
    learning_rate = train_config.get('learning_rate', 0.001)
    optimizer = Adam(learning_rate=learning_rate)
    metrics_list = train_config.get('metrics', ['mean_absolute_error'])

    model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics_list)

    print("\n--- 모델 훈련 시작 ---")
    history = model.fit(
        X_train,
        y_train,
        epochs=train_config.get('epochs', 50),
        batch_size=train_config.get('batch_size', 32),
        validation_data=(X_val, y_val),
        verbose=1
    )
    print("--- 모델 훈련 완료 ---")

    return model, history

# %%
def evaluate_model(model, X_test, y_test):
    if X_test.shape[0] == 0:
        print("경고: 평가할 테스트 데이터가 없습니다.")
        return None

    print("\n--- 최종 모델 평가 (Test Set) ---")
    results = model.evaluate(X_test, y_test, verbose=1)
    metric_names = model.metrics_names
    for name, value in zip(metric_names, results):
        print(f"{name}: {value:.4f}")
    return results

# %%
def plot_training_history(history,filename=None):
    if not history:
        print("시각화할 훈련 기록(history)이 없습니다.")
        return

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    if filename is not None:
        plt.savefig(f"{filename}_loss.png")

    # Metric
    metric_keys = [k for k in history.history.keys() if k not in ['loss', 'val_loss', 'lr']]
    if metric_keys:
        train_metric = metric_keys[0]
        val_metric = f"val_{train_metric}"
        if val_metric in history.history:
            plt.subplot(1, 2, 2)
            plt.plot(history.history[train_metric], label=f'Train {train_metric}')
            plt.plot(history.history[val_metric], label=f'Validation {val_metric}')
            plt.title(f'Model Metric ({train_metric})')
            plt.xlabel('Epochs')
            plt.ylabel('Metric')
            plt.legend()
    plt.tight_layout()
    plt.show()
    if filename is not None:
        plt.savefig(f"{filename}_metric.png")

# %%
# --- 5. 평가 및 시각화 모듈 ---
# ... (evaluate_model, plot_training_history 함수는 여기에 있습니다) ...

def plot_predictions(y_true, y_pred,filename=None):
    """
    [수정된 함수]
    Validation set의 실제 값과 예측 값을
    하나의 산점도(scatterplot)에 오버레이하여 그립니다.
    """
    if y_true.shape[0] == 0:
        print("시각화할 검증 데이터가 없습니다.")
        return

    plt.figure(figsize=(8, 8)) # 정사각형 그래프로 변경

    # Output 1 (첫 번째 예측값) - 파란색
    plt.scatter(y_true[:, 0], y_pred[:, 0], 
                alpha=0.5, label='Output 1 Prediction (blue)')
    
    # Output 2 (두 번째 예측값) - 초록색
    plt.scatter(y_true[:, 1], y_pred[:, 1], 
                alpha=0.5, label='Output 2 Prediction (green)')

    plt.xlabel("Actual Values (True Values)")
    plt.ylabel("Predicted Values (Predictions)")
    plt.title("Prediction vs Actual (Overlay)")
    
    # y=x 선 (완벽한 예측)
    # 두 Output의 모든 값(true, pred)을 기준으로 min/max를 계산
    all_values = np.concatenate([y_true.flatten(), y_pred.flatten()])
    lims = [all_values.min() * 0.95, all_values.max() * 1.05] # 약간의 여백 추가
    
    plt.xlim(lims)
    plt.ylim(lims)
    plt.plot(lims, lims, 'r--', label='Perfect Prediction (y=x)')
    
    plt.legend() # 범례 표시
    plt.grid(True) # 그리드 추가
    plt.tight_layout()
    plt.show()
    if filename is not None:
        plt.savefig(f"{filename}_pred.png")

# %%
def capture_model_summary(model):
    """Keras 모델의 .summary() 출력을 문자열로 반환합니다."""
    stream = io.StringIO()
    with redirect_stdout(stream):
        model.summary()
    return stream.getvalue()


EXPERIMENT_FIELDNAMES = [
    "timestamp", "architecture", "hidden_layers", "activation", 
    "regularizer", "dropout", "batch_norm", "learning_rate", 
    "batch_size", "n_epochs", "optimizer", "loss_function",
    "train_size", "dev_size", "final_train_loss", "final_dev_loss",
    "best_dev_loss", "best_epoch", "notes"
]

def log_experiment(log_path, model, history, model_config, train_config, X_train, X_val):
    """
    [TensorFlow/Keras 버전]
    훈련 결과를 CSV 파일에 한 줄로 기록합니다.
    """
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    
    # Keras History 객체에서 Loss 값들을 안전하게 추출
    train_losses = history.history.get('loss', [0.0])
    val_losses = history.history.get('val_loss', [0.0])
    
    # 기록할 파라미터 딕셔너리 생성
    params = {
        "timestamp": timestamp,
        "architecture": capture_model_summary(model), # 모델 구조 요약
        "hidden_layers": str(model_config.get('hidden_layers', [])), # 리스트를 문자열로
        "activation": model_config.get('activation', ''),
        "regularizer": model_config.get('regularizer_type', 'None'),
        "dropout": model_config.get('dropout_rate', 0.0),
        "batch_norm": model_config.get('use_batch_norm', False),
        "learning_rate": train_config.get('learning_rate', 0.0),
        "batch_size": train_config.get('batch_size', 0),
        "n_epochs": train_config.get('epochs', 0),
        "optimizer": model.optimizer.__class__.__name__, # 'Adam' 등
        "loss_function": train_config.get('loss', ''),
        "train_size": len(X_train), # X_train의 크기
        "dev_size": len(X_val),   # X_val의 크기
        "final_train_loss": round(train_losses[-1], 6),
        "final_dev_loss": round(val_losses[-1], 6),
        "best_dev_loss": round(min(val_losses), 6),
        "best_epoch": int(np.argmin(val_losses) + 1), # (numpy as np 필요)
    }
    
    file_exists = os.path.exists(log_path)
    with open(log_path, mode='a', newline='', encoding='utf-8') as f:
        # DictWriter가 params에 없는 키는 'N/A'로, params에 fieldnames에 없는 키는 무시하도록 설정
        writer = csv.DictWriter(f, 
                              fieldnames=EXPERIMENT_FIELDNAMES, 
                              restval='N/A', 
                              extrasaction='ignore')
        
        if not file_exists:
            writer.writeheader() # 파일이 없으면 헤더 쓰기
            
        writer.writerow(params) # 파라미터 한 줄 쓰기

# %%
def save_final_model(save_dir, model, history, train_config):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    n_epochs = train_config.get('epochs', 0)
    
    val_losses = history.history.get('val_loss', [0.0])
    final_dev_loss = val_losses[-1] # PyTorch의 avg_dev_loss 대신 final_dev_loss 사용
    
    final_name = f"final_pressureRNN_{timestamp}_epoch{n_epochs}_loss{final_dev_loss:.4f}.weights.h5"
    final_path = os.path.join(save_dir, final_name)
    
    # 3. 모델 가중치 저장
    model.save_weights(final_path)

# %%
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

DATA_BASE_PATH_ROOT = r"G:/내 드라이브/CS230 Project"
PROCESSED_DATA_FILE = "processed_haptic_data.npy"

# 모델 아키텍처 설정
MODEL_CONFIG = {
    'hidden_layers': [128, 64, 64,32, 32],
    'activation': 'relu',
    'regularizer_type': 'l2',
    'l2': 0.001,
    'use_batch_norm': True,
    'dropout_rate': 0.
}

# 훈련 설정
TRAIN_CONFIG = {
    'learning_rate': 0.005,
    'epochs': 100, # 126개 샘플은 적으니 epoch를 100~200 정도로 늘려도 좋습니다.
    'batch_size': 16, # 샘플이 적으므로 배치 크기를 32보다 작게 (16) 조정
    'loss': 'mean_squared_error',
    'metrics': ['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(name='rmse')]
}
# ==========================

# 1. 데이터 로드 (검증된 함수 사용)
if os.path.exists(PROCESSED_DATA_FILE):
    data = np.load(PROCESSED_DATA_FILE, allow_pickle=True).item()
    X = data['X']
    y = data['y']
    
else:
    X, y = load_all_data(DATA_BASE_PATH_ROOT)
    data_to_save = {'X': X, 'y': y}
    np.save(PROCESSED_DATA_FILE, data_to_save, allow_pickle=True)

print(f"전체 데이터셋 크기: X={X.shape}, y={y.shape}")
print(f"샘플 예시 (첫 5개):")
for i in range(min(5, X.shape[0])):
    print(f" X[{i}]: {X[i][:10]}... , y[{i}]: {y[i]}")
    
# # 1-Extra. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# # 2. 데이터 분리
X_train, X_val, X_test, y_train, y_val, y_test = split_data(X_scaled, y,0.15,0.15)

# if X_train.shape[0] == 0:
#     print("데이터 분리에 실패했습니다. (샘플 부족) 프로그램을 종료합니다.")
#     return

# # 3. 모델 구축
input_shape = (X_train.shape[1],)
model = build_model(input_shape, MODEL_CONFIG)

# # 4. 모델 훈련
model, history = compile_and_train_model(
    model, X_train, y_train, X_val, y_val, TRAIN_CONFIG
)

# # 5. 모델 평가
evaluate_model(model, X_test, y_test)

# # 6. 결과 시각화
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
plot_filename = os.path.join("results", "plots", f"loss_curve_{timestamp}.png")

plot_training_history(history,filename=plot_filename)

y_pred_val = model.predict(X_val)
plot_predictions(y_val,y_pred_val)

LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# 전체 데이터셋 크기: X=(795, 9248), y=(795, 2)
# 샘플 예시 (첫 5개):
#  X[0]: [1093. 1093. 1093. 1093. 1093. 1093. 1092. 1093. 1092. 1093.]... , y[0]: [1229.37 1265.18]
#  X[1]: [1100. 1097. 1099. 1097. 1099. 1097. 1100. 1097. 1100. 1097.]... , y[1]: [1212.33 1262.6 ]
#  X[2]: [1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097.]... , y[2]: [1229.8  1261.45]
#  X[3]: [1098. 1097. 1098. 1097. 1098. 1097. 1098. 1097. 1097. 1096.]... , y[3]: [1111.96 1117.9 ]
#  X[4]: [1090. 1092. 1090. 1092. 1090. 1093. 1090. 1093. 1091. 1092.]... , y[4]: [1220.12 1238.38]
# 데이터 분리 완료:
#   훈련 (Train)  : (573, 9248), (573, 2)
#   개발 (Dev)    : (102, 9248), (102, 2)
#   테스트 (Test) : (120, 9248), (120, 2)
# 모델 구성 완료:
# c:\Users\sehui\.conda\envs\CS230\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,200,770 (4.58 MB)
#  Trainable params: 1,200,130 (4.58 MB)
#  Non-trainable params: 640 (2.50 KB)
# --- 모델 훈련 시작 ---
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1407189.7500 - mean_absolute_error: 1184.9615 - rmse: 1186.2498 - val_loss: 1368951.5000 - val_mean_absolute_error: 1168.6909 - val_rmse: 1170.0214
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1397684.6250 - mean_absolute_error: 1181.0590 - rmse: 1182.2363 - val_loss: 1309697.1250 - val_mean_absolute_error: 1143.1100 - val_rmse: 1144.4192
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1377217.5000 - mean_absolute_error: 1172.4034 - rmse: 1173.5482 - val_loss: 1219012.3750 - val_mean_absolute_error: 1101.7556 - val_rmse: 1104.0879
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1344186.1250 - mean_absolute_error: 1158.2936 - rmse: 1159.3893 - val_loss: 1188277.7500 - val_mean_absolute_error: 1087.7969 - val_rmse: 1090.0802
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1298764.7500 - mean_absolute_error: 1138.5461 - rmse: 1139.6322 - val_loss: 1199505.7500 - val_mean_absolute_error: 1093.8184 - val_rmse: 1095.2180
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1241913.2500 - mean_absolute_error: 1113.2982 - rmse: 1114.4102 - val_loss: 1140083.3750 - val_mean_absolute_error: 1065.7693 - val_rmse: 1067.7450
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1174657.0000 - mean_absolute_error: 1082.8042 - rmse: 1083.8140 - val_loss: 1060535.2500 - val_mean_absolute_error: 1028.3715 - val_rmse: 1029.8208
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1099168.6250 - mean_absolute_error: 1047.3552 - rmse: 1048.4102 - val_loss: 1005712.5000 - val_mean_absolute_error: 1001.3912 - val_rmse: 1002.8497
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1016818.6250 - mean_absolute_error: 1007.3685 - rmse: 1008.3716 - val_loss: 944037.0000 - val_mean_absolute_error: 970.2430 - val_rmse: 971.6128
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 929968.0000 - mean_absolute_error: 963.2665 - rmse: 964.3455 - val_loss: 863790.5625 - val_mean_absolute_error: 928.0472 - val_rmse: 929.4000
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 840118.0000 - mean_absolute_error: 915.4741 - rmse: 916.5760 - val_loss: 773678.4375 - val_mean_absolute_error: 878.0508 - val_rmse: 879.5861
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 749236.4375 - mean_absolute_error: 864.5187 - rmse: 865.5805 - val_loss: 678510.1250 - val_mean_absolute_error: 822.2158 - val_rmse: 823.7126
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 659836.1250 - mean_absolute_error: 811.0406 - rmse: 812.2982 - val_loss: 617854.3750 - val_mean_absolute_error: 784.1280 - val_rmse: 786.0320
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 572912.6250 - mean_absolute_error: 755.5137 - rmse: 756.9044 - val_loss: 559415.5000 - val_mean_absolute_error: 746.1830 - val_rmse: 747.9351
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 490243.3438 - mean_absolute_error: 698.7525 - rmse: 700.1675 - val_loss: 436833.9062 - val_mean_absolute_error: 659.0066 - val_rmse: 660.9274
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 413062.5625 - mean_absolute_error: 641.1630 - rmse: 642.6923 - val_loss: 375459.9688 - val_mean_absolute_error: 610.5969 - val_rmse: 612.7402
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 342574.2812 - mean_absolute_error: 583.5497 - rmse: 585.2903 - val_loss: 318900.2500 - val_mean_absolute_error: 562.4219 - val_rmse: 564.7040
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 279331.2188 - mean_absolute_error: 526.4852 - rmse: 528.5086 - val_loss: 246092.4375 - val_mean_absolute_error: 493.2602 - val_rmse: 496.0667
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 223586.5312 - mean_absolute_error: 470.9400 - rmse: 472.8380 - val_loss: 212403.2969 - val_mean_absolute_error: 457.7654 - val_rmse: 460.8603
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 175973.7812 - mean_absolute_error: 417.1804 - rmse: 419.4789 - val_loss: 156592.3594 - val_mean_absolute_error: 392.1809 - val_rmse: 395.7032
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 135754.2500 - mean_absolute_error: 365.8839 - rmse: 368.4329 - val_loss: 127093.0781 - val_mean_absolute_error: 352.6941 - val_rmse: 356.4849
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 102583.8047 - mean_absolute_error: 317.7353 - rmse: 320.2688 - val_loss: 90296.7422 - val_mean_absolute_error: 296.2693 - val_rmse: 300.4742
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 76100.1641 - mean_absolute_error: 272.9670 - rmse: 275.8402 - val_loss: 70836.9453 - val_mean_absolute_error: 261.5253 - val_rmse: 266.1284
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 55393.1523 - mean_absolute_error: 231.8805 - rmse: 235.3304 - val_loss: 53754.4805 - val_mean_absolute_error: 226.1587 - val_rmse: 231.8223
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39679.3359 - mean_absolute_error: 195.0475 - rmse: 199.1639 - val_loss: 40621.3906 - val_mean_absolute_error: 194.8749 - val_rmse: 201.5142
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27904.7461 - mean_absolute_error: 162.1061 - rmse: 167.0066 - val_loss: 28593.2148 - val_mean_absolute_error: 160.8594 - val_rmse: 169.0547
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19304.4199 - mean_absolute_error: 133.2306 - rmse: 138.8898 - val_loss: 16104.9697 - val_mean_absolute_error: 114.4605 - val_rmse: 126.8490
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13417.1455 - mean_absolute_error: 108.7101 - rmse: 115.7696 - val_loss: 11307.1201 - val_mean_absolute_error: 91.7030 - val_rmse: 106.2656
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9259.7275 - mean_absolute_error: 87.6875 - rmse: 96.1501 - val_loss: 8378.1719 - val_mean_absolute_error: 77.5363 - val_rmse: 91.4495
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6304.1982 - mean_absolute_error: 70.7287 - rmse: 79.3022 - val_loss: 6818.3823 - val_mean_absolute_error: 69.0020 - val_rmse: 82.4794
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4485.1919 - mean_absolute_error: 57.2808 - rmse: 66.8565 - val_loss: 4607.6128 - val_mean_absolute_error: 55.1848 - val_rmse: 67.7668
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3371.8914 - mean_absolute_error: 48.3616 - rmse: 57.9347 - val_loss: 4632.6885 - val_mean_absolute_error: 54.9690 - val_rmse: 67.9477
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2601.6316 - mean_absolute_error: 41.7881 - rmse: 50.8474 - val_loss: 4266.2661 - val_mean_absolute_error: 54.7035 - val_rmse: 65.1904
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2142.9741 - mean_absolute_error: 36.8126 - rmse: 46.1116 - val_loss: 3710.1331 - val_mean_absolute_error: 50.7746 - val_rmse: 60.7711
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1824.6615 - mean_absolute_error: 33.3693 - rmse: 42.5159 - val_loss: 3132.7700 - val_mean_absolute_error: 46.3662 - val_rmse: 55.8171
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1607.6067 - mean_absolute_error: 31.1071 - rmse: 39.8754 - val_loss: 3116.1938 - val_mean_absolute_error: 46.8813 - val_rmse: 55.6637
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1507.3230 - mean_absolute_error: 30.0105 - rmse: 38.5953 - val_loss: 3383.0339 - val_mean_absolute_error: 48.7850 - val_rmse: 58.0111
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1426.2826 - mean_absolute_error: 28.9856 - rmse: 37.5291 - val_loss: 3189.6125 - val_mean_absolute_error: 47.8615 - val_rmse: 56.3175
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1444.4524 - mean_absolute_error: 29.4035 - rmse: 37.7659 - val_loss: 2937.4836 - val_mean_absolute_error: 45.2181 - val_rmse: 54.0279
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1491.9127 - mean_absolute_error: 29.6754 - rmse: 38.3832 - val_loss: 2644.5615 - val_mean_absolute_error: 43.6838 - val_rmse: 51.2415
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1417.0089 - mean_absolute_error: 29.1476 - rmse: 37.3904 - val_loss: 2662.5994 - val_mean_absolute_error: 43.3916 - val_rmse: 51.4160
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1419.4254 - mean_absolute_error: 28.7952 - rmse: 37.4178 - val_loss: 2450.6562 - val_mean_absolute_error: 43.2586 - val_rmse: 49.3037
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1403.5774 - mean_absolute_error: 28.9462 - rmse: 37.1967 - val_loss: 2945.2009 - val_mean_absolute_error: 45.6719 - val_rmse: 54.0814
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1452.5790 - mean_absolute_error: 29.5517 - rmse: 37.8408 - val_loss: 2518.1912 - val_mean_absolute_error: 43.0759 - val_rmse: 49.9742
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1425.9200 - mean_absolute_error: 29.1274 - rmse: 37.4825 - val_loss: 2601.7334 - val_mean_absolute_error: 44.0280 - val_rmse: 50.7997
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1199.6163 - mean_absolute_error: 26.5203 - rmse: 34.3277 - val_loss: 3000.0771 - val_mean_absolute_error: 45.2659 - val_rmse: 54.5768
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1563.3792 - mean_absolute_error: 30.5795 - rmse: 39.2654 - val_loss: 2774.8618 - val_mean_absolute_error: 46.3395 - val_rmse: 52.4687
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1641.4680 - mean_absolute_error: 31.5424 - rmse: 40.2408 - val_loss: 2624.6406 - val_mean_absolute_error: 44.5901 - val_rmse: 51.0119
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1533.2863 - mean_absolute_error: 29.9107 - rmse: 38.8668 - val_loss: 3170.5754 - val_mean_absolute_error: 47.0163 - val_rmse: 56.1037
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1397.0436 - mean_absolute_error: 28.7492 - rmse: 37.0680 - val_loss: 2615.2441 - val_mean_absolute_error: 42.5634 - val_rmse: 50.9131
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1377.1307 - mean_absolute_error: 28.2260 - rmse: 36.7968 - val_loss: 2705.1138 - val_mean_absolute_error: 44.8811 - val_rmse: 51.7879
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1342.5897 - mean_absolute_error: 27.5659 - rmse: 36.3209 - val_loss: 2631.5144 - val_mean_absolute_error: 44.2558 - val_rmse: 51.0682
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1403.4830 - mean_absolute_error: 29.1929 - rmse: 37.1454 - val_loss: 2659.4666 - val_mean_absolute_error: 43.2301 - val_rmse: 51.3394
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1445.0159 - mean_absolute_error: 29.1115 - rmse: 37.7004 - val_loss: 2783.4065 - val_mean_absolute_error: 45.4167 - val_rmse: 52.5343
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1293.3695 - mean_absolute_error: 27.8259 - rmse: 35.6324 - val_loss: 2984.0396 - val_mean_absolute_error: 45.4490 - val_rmse: 54.4080
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1260.8708 - mean_absolute_error: 26.7662 - rmse: 35.1704 - val_loss: 2672.6738 - val_mean_absolute_error: 43.3552 - val_rmse: 51.4655
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1234.8673 - mean_absolute_error: 26.6654 - rmse: 34.7970 - val_loss: 2592.2549 - val_mean_absolute_error: 42.4023 - val_rmse: 50.6775
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1603.3921 - mean_absolute_error: 30.6363 - rmse: 39.7399 - val_loss: 2677.6919 - val_mean_absolute_error: 43.9138 - val_rmse: 51.5114
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1318.2378 - mean_absolute_error: 27.6998 - rmse: 35.9700 - val_loss: 2548.1667 - val_mean_absolute_error: 43.8194 - val_rmse: 50.2370
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1392.6255 - mean_absolute_error: 28.5966 - rmse: 36.9877 - val_loss: 2759.5249 - val_mean_absolute_error: 45.1293 - val_rmse: 52.2962
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1154.7147 - mean_absolute_error: 25.9872 - rmse: 33.6159 - val_loss: 3338.5818 - val_mean_absolute_error: 48.5565 - val_rmse: 57.5654
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1390.8510 - mean_absolute_error: 28.3894 - rmse: 36.9554 - val_loss: 2477.6609 - val_mean_absolute_error: 43.1341 - val_rmse: 49.5199
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1138.6854 - mean_absolute_error: 25.3636 - rmse: 33.3644 - val_loss: 2986.7219 - val_mean_absolute_error: 46.7078 - val_rmse: 54.4147
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1150.4556 - mean_absolute_error: 25.6464 - rmse: 33.5351 - val_loss: 2547.3601 - val_mean_absolute_error: 43.8472 - val_rmse: 50.2143
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1247.0084 - mean_absolute_error: 26.7180 - rmse: 34.9421 - val_loss: 2935.1458 - val_mean_absolute_error: 47.2703 - val_rmse: 53.9345
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1244.3953 - mean_absolute_error: 26.7898 - rmse: 34.8984 - val_loss: 2978.4155 - val_mean_absolute_error: 47.8228 - val_rmse: 54.3274
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1072.6445 - mean_absolute_error: 24.5682 - rmse: 32.3363 - val_loss: 2790.7949 - val_mean_absolute_error: 45.1242 - val_rmse: 52.5715
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1151.1276 - mean_absolute_error: 25.6399 - rmse: 33.5236 - val_loss: 2539.9749 - val_mean_absolute_error: 43.4657 - val_rmse: 50.1219
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1280.5052 - mean_absolute_error: 26.8604 - rmse: 35.3924 - val_loss: 2575.3955 - val_mean_absolute_error: 43.1559 - val_rmse: 50.4707
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1192.6777 - mean_absolute_error: 26.1042 - rmse: 34.1265 - val_loss: 2693.7354 - val_mean_absolute_error: 45.0366 - val_rmse: 51.6294
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1053.4967 - mean_absolute_error: 24.3940 - rmse: 32.0192 - val_loss: 2755.1274 - val_mean_absolute_error: 45.0362 - val_rmse: 52.2182
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1089.6007 - mean_absolute_error: 24.7223 - rmse: 32.5750 - val_loss: 2960.2427 - val_mean_absolute_error: 46.4969 - val_rmse: 54.1456
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1250.1486 - mean_absolute_error: 26.6964 - rmse: 34.9488 - val_loss: 2811.1631 - val_mean_absolute_error: 44.7352 - val_rmse: 52.7458
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1269.2473 - mean_absolute_error: 27.1771 - rmse: 35.2121 - val_loss: 2395.0981 - val_mean_absolute_error: 41.6493 - val_rmse: 48.6368
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1171.7972 - mean_absolute_error: 25.9668 - rmse: 33.7984 - val_loss: 3209.8669 - val_mean_absolute_error: 47.1478 - val_rmse: 56.3968
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1096.9346 - mean_absolute_error: 25.0334 - rmse: 32.6745 - val_loss: 2846.1997 - val_mean_absolute_error: 45.2294 - val_rmse: 53.0737
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1126.1812 - mean_absolute_error: 25.3516 - rmse: 33.1144 - val_loss: 2431.7534 - val_mean_absolute_error: 41.1725 - val_rmse: 49.0110
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1060.8901 - mean_absolute_error: 24.3025 - rmse: 32.1142 - val_loss: 2884.0945 - val_mean_absolute_error: 45.7879 - val_rmse: 53.4290
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1070.2853 - mean_absolute_error: 24.5401 - rmse: 32.2619 - val_loss: 2821.9070 - val_mean_absolute_error: 45.6691 - val_rmse: 52.8436
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1036.2355 - mean_absolute_error: 24.0749 - rmse: 31.7290 - val_loss: 2725.8787 - val_mean_absolute_error: 44.1701 - val_rmse: 51.9265
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1183.9500 - mean_absolute_error: 25.8763 - rmse: 33.9744 - val_loss: 2745.9956 - val_mean_absolute_error: 44.0866 - val_rmse: 52.1166
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1093.8586 - mean_absolute_error: 24.9211 - rmse: 32.6190 - val_loss: 2775.8557 - val_mean_absolute_error: 44.8384 - val_rmse: 52.4019
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1080.7357 - mean_absolute_error: 24.9751 - rmse: 32.4165 - val_loss: 2838.3606 - val_mean_absolute_error: 45.8395 - val_rmse: 52.9934
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1157.4155 - mean_absolute_error: 25.7547 - rmse: 33.5704 - val_loss: 3018.4529 - val_mean_absolute_error: 45.6082 - val_rmse: 54.6605
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1200.9543 - mean_absolute_error: 25.7439 - rmse: 34.2098 - val_loss: 2582.2412 - val_mean_absolute_error: 42.3761 - val_rmse: 50.5125
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1155.1262 - mean_absolute_error: 25.4058 - rmse: 33.5298 - val_loss: 2606.9099 - val_mean_absolute_error: 43.2294 - val_rmse: 50.7525
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1134.2181 - mean_absolute_error: 25.0610 - rmse: 33.2117 - val_loss: 2805.4917 - val_mean_absolute_error: 44.6725 - val_rmse: 52.6713
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1046.2878 - mean_absolute_error: 24.4431 - rmse: 31.8606 - val_loss: 2919.8181 - val_mean_absolute_error: 45.2319 - val_rmse: 53.7453
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1152.4908 - mean_absolute_error: 25.5292 - rmse: 33.4825 - val_loss: 2950.2549 - val_mean_absolute_error: 46.7205 - val_rmse: 54.0224
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1187.2582 - mean_absolute_error: 25.8037 - rmse: 33.9865 - val_loss: 2755.2336 - val_mean_absolute_error: 45.4186 - val_rmse: 52.1816
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1131.4421 - mean_absolute_error: 25.0545 - rmse: 33.1506 - val_loss: 3154.4097 - val_mean_absolute_error: 47.7701 - val_rmse: 55.8733
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1170.1932 - mean_absolute_error: 25.2300 - rmse: 33.7257 - val_loss: 2971.0073 - val_mean_absolute_error: 45.0845 - val_rmse: 54.2030
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1058.3596 - mean_absolute_error: 24.5469 - rmse: 32.0187 - val_loss: 2822.7573 - val_mean_absolute_error: 42.9568 - val_rmse: 52.8165
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 995.1152 - mean_absolute_error: 23.6469 - rmse: 31.0134 - val_loss: 3025.0176 - val_mean_absolute_error: 46.6484 - val_rmse: 54.6939
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1127.5913 - mean_absolute_error: 25.3502 - rmse: 33.0719 - val_loss: 2419.8030 - val_mean_absolute_error: 39.2207 - val_rmse: 48.8453
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1019.3510 - mean_absolute_error: 24.1445 - rmse: 31.3899 - val_loss: 2687.9829 - val_mean_absolute_error: 41.2276 - val_rmse: 51.5169
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1059.2469 - mean_absolute_error: 24.1946 - rmse: 32.0198 - val_loss: 2725.1750 - val_mean_absolute_error: 43.0540 - val_rmse: 51.8768
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 969.0342 - mean_absolute_error: 23.1283 - rmse: 30.5772 - val_loss: 2507.4614 - val_mean_absolute_error: 41.6100 - val_rmse: 49.7322
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 965.7723 - mean_absolute_error: 23.5524 - rmse: 30.5229 - val_loss: 2580.1194 - val_mean_absolute_error: 42.3238 - val_rmse: 50.4559
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 978.4372 - mean_absolute_error: 23.1653 - rmse: 30.7237 - val_loss: 2634.5959 - val_mean_absolute_error: 41.8617 - val_rmse: 50.9914
# --- 모델 훈련 완료 ---
#
# --- 최종 모델 평가 (Test Set) ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2167.4839 - mean_absolute_error: 38.3976 - rmse: 46.1845
# loss: 2167.4839
# compile_metrics: 38.3976
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 75
#      72 plot_predictions(y_val,y_pred_val)
#      74 LOG_FILE = os.path.join("results", "experiment_logs.csv")
# ---> 75 log_experiment(
#      76         log_path=LOG_FILE,
#      77         model=model,
#      78         history=history,
#      79         model_config=MODEL_CONFIG,
#      80         train_config=TRAIN_CONFIG,
#      81         X_train=X_train,
#      82         X_val=X_val,
#      83     )
#      85 save_final_model("results/weights", model, history, TRAIN_CONFIG)
#
# Cell In[22], line 31, in log_experiment(log_path, model, history, model_config, train_config, X_train, X_val)
#      26 val_losses = history.history.get('val_loss', [0.0])
#      28 # 기록할 파라미터 딕셔너리 생성
#      29 params = {
#      30     "timestamp": timestamp,
# ---> 31     "architecture": capture_model_summary(model), # 모델 구조 요약
#      32     "hidden_layers": str(model_config.get('hidden_layers', [])), # 리스트를 문자열로
#      33     "activation": model_config.get('activation', ''),
#      34     "regularizer": model_config.get('regularizer_type', 'None'),
#      35     "dropout": model_config.get('dropout_rate', 0.0),
#      36     "batch_norm": model_config.get('use_batch_norm', False),
#      37     "learning_rate": train_config.get('learning_rate', 0.0),
#      38     "batch_size": train_config.get('batch_size', 0),
#      39     "n_epochs": train_config.get('epochs', 0),
#      40     "optimizer": model.optimizer.__class__.__name__, # 'Adam' 등
#      41     "loss_function": train_config.get('loss', ''),
#      42     "train_size": len(X_train), # X_train의 크기
#      43     "dev_size": len(X_val),   # X_val의 크기
#      44     "final_train_loss": round(train_losses[-1], 6),
#      45     "final_dev_loss": round(val_losses[-1], 6),
#      46     "best_dev_loss": round(min(val_losses), 6),
#      47     "best_epoch": int(np.argmin(val_losses) + 1), # (numpy as np 필요)
#      48 }
#      50 file_exists = os.path.exists(log_path)
#      51 with open(log_path, mode='a', newline='', encoding='utf-8') as f:
#      52     # DictWriter가 params에 없는 키는 'N/A'로, params에 fieldnames에 없는 키는 무시하도록 설정
#
# Cell In[22], line 3, in capture_model_summary(model)
#       1 def capture_model_summary(model):
#       2     """Keras 모델의 .summary() 출력을 문자열로 반환합니다."""
# ----> 3     stream = io.StringIO()
#       4     with redirect_stdout(stream):
#       5         model.summary()
#
# NameError: name 'io' is not defined
