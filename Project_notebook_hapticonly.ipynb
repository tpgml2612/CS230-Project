# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pathlib import Path
import matplotlib.pyplot as plt
import glob
import re
import warnings
from datetime import datetime
import os
import csv
import io                   # [추가] model.summary()를 캡처하기 위해
from contextlib import redirect_stdout

# %%
def trim_and_flatten_data(haptic_df):
    # Haptic: 4, 5th columns (index 3, 4)
    # Robot: 9, 10, 11th columns (index 8, 9, 10)
    haptic_data = haptic_df.iloc[:, [3, 4]].values
    
    # Process NaN values by replacing them with zeros
    haptic_data = np.nan_to_num(haptic_data, nan=0.0)
    return haptic_data.flatten()

# %%
def load_all_data(data_base_path):
    base_path = Path(data_base_path) / "DATA"

    all_X_data = []
    all_y_data = []

    METHOD_MAP = {'HAPTICS': 'H', 'NOhaptics': 'NH'}
    TASK_MAP = {
        5: ('pp1', 'PAP'), 6: ('pp1', 'PAP'),
        7: ('pp2', 'PAPObstructed'), 8: ('pp2', 'PAPObstructed'),
        9: ('pp3', 'Camera'), 10: ('pp3', 'Camera')
    }

    for p_id in range(1, 27): # 1~26

        participant_str = f"Participant_{p_id}"
        results_file = base_path / "Haptic Data" / participant_str / f"{participant_str}_results.csv"
        
        results_lookup = {}
        try:
            results_df = pd.read_csv(results_file)
            for _, row in results_df.iterrows():
                try:
                    condition = row['Condition']
                    subcondition = row['Subcondition']
                    trial_str = str(row['Trial'])
                    trial = int(re.search(r'^\d+', trial_str).group())
                    output_1 = pd.to_numeric(row['Sensor1 Mean'], errors='coerce')
                    output_2 = pd.to_numeric(row['Sensor2 Mean'], errors='coerce')

                    if pd.isna(output_1) or pd.isna(output_2):
                        continue
                    key = (condition, subcondition, trial)
                    results_lookup[key] = (output_1, output_2)
                except Exception:
                    continue
        except Exception as e:
            print(f"Error in reading ({results_file}): {e}")
            continue
        haptic_files_glob = glob.glob(str(base_path / "Haptic Data" / participant_str / "*.csv"))

        for hfile_path in haptic_files_glob:
            file_name = Path(hfile_path).name
            match = re.match(r'(\d+)_.*?_(HAPTICS|NOhaptics)_(\d+)\.csv', file_name)
            
            if not match:
                continue

            try:
                task_num = int(match.group(1))
                method = match.group(2)
                trial = int(match.group(3))
                
                if task_num not in TASK_MAP:
                    continue

                scenario_num, result_condition = TASK_MAP[task_num]
                method_short = METHOD_MAP[method]

                output_key = (result_condition, method, trial)
                if output_key not in results_lookup:
                    continue

                haptic_df = pd.read_csv(hfile_path)

                flat_input_vector = trim_and_flatten_data(haptic_df)

                if flat_input_vector is not None:
                    output_1, output_2 = results_lookup[output_key]
                    output_vector = np.array([output_1, output_2])
                    all_X_data.append(flat_input_vector)
                    all_y_data.append(output_vector)
            
                print(f" Success: participant {p_id} task {task_num}, method {method}, trial {trial}")
            except Exception as e:
                print(f"  Error: {file_name} - {e}")

    max_len = max(len(x) for x in all_X_data)
    
    X_padded = np.array([np.pad(x, (0, max_len - len(x)), 'constant') for x in all_X_data])
    y_array = np.array(all_y_data)

    return X_padded, y_array

# %%
def split_data(X, y, test_size=0.2, dev_size=0.125, random_state=42):
    """
    데이터를 훈련, 개발, 테스트 세트로 분리합니다. (기본 70:10:20)
    """
    if X.shape[0] == 0:
        print("오류: 분리할 데이터가 없습니다.")
        return (np.array([]),)*6

    # 1차 분리: 훈련+개발 (80%) / 테스트 (20%)
    X_train_dev, X_test, y_train_dev, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    # 2차 분리: 훈련 (70%) / 개발 (10%)
    X_train, X_dev, y_train, y_dev = train_test_split(
        X_train_dev, y_train_dev, test_size=dev_size, random_state=random_state
    )

    print(f"데이터 분리 완료:")
    print(f"  훈련 (Train)  : {X_train.shape}, {y_train.shape}")
    print(f"  개발 (Dev)    : {X_dev.shape}, {y_dev.shape}")
    print(f"  테스트 (Test) : {X_test.shape}, {y_test.shape}")

    return X_train, X_dev, X_test, y_train, y_dev, y_test

# %%
def get_regularizer(config):
    reg_type = config.get('regularizer_type', None)
    l1_val = config.get('l1', 0.01)
    l2_val = config.get('l2', 0.01)

    if reg_type == 'l1': return regularizers.l1(l1_val)
    elif reg_type == 'l2': return regularizers.l2(l2_val)
    elif reg_type == 'l1_l2': return regularizers.l1_l2(l1=l1_val, l2=l2_val)
    else: return None

# %%
def build_model(input_shape, model_config):
    model = Sequential(name="Modular_DNN_Model")
    model.add(InputLayer(input_shape=input_shape))

    hidden_layers = model_config.get('hidden_layers', [64, 32])
    activation = model_config.get('activation', 'relu')
    reg_obj = get_regularizer(model_config)

    for units in hidden_layers:
        model.add(Dense(units, activation=activation, kernel_regularizer=reg_obj))
        if model_config.get('use_batch_norm', False):
            model.add(BatchNormalization())
        if model_config.get('dropout_rate', 0.0) > 0:
            model.add(Dropout(model_config['dropout_rate']))

    model.add(Dense(2, name='output')) # 2개 값 예측 (회귀)

    print("모델 구성 완료:")
    model.summary()
    return model

# %%
def compile_and_train_model(model, X_train, y_train, X_val, y_val, train_config):
    loss_function = train_config.get('loss', 'mean_squared_error')
    learning_rate = train_config.get('learning_rate', 0.001)
    optimizer = Adam(learning_rate=learning_rate)
    metrics_list = train_config.get('metrics', ['mean_absolute_error'])

    model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics_list)

    print("\n--- 모델 훈련 시작 ---")
    history = model.fit(
        X_train,
        y_train,
        epochs=train_config.get('epochs', 50),
        batch_size=train_config.get('batch_size', 32),
        validation_data=(X_val, y_val),
        verbose=1
    )
    print("--- 모델 훈련 완료 ---")

    return model, history

# %%
def evaluate_model(model, X_test, y_test):
    if X_test.shape[0] == 0:
        print("경고: 평가할 테스트 데이터가 없습니다.")
        return None

    print("\n--- 최종 모델 평가 (Test Set) ---")
    results = model.evaluate(X_test, y_test, verbose=1)
    metric_names = model.metrics_names
    for name, value in zip(metric_names, results):
        print(f"{name}: {value:.4f}")
    return results

# %%
def plot_training_history(history,filename=None):
    if not history:
        print("시각화할 훈련 기록(history)이 없습니다.")
        return

    plt.figure(figsize=(12, 5))

    # Loss
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    if filename is not None:
        plt.savefig(f"{filename}_loss.png")

    # Metric
    plt.figure(figsize=(12, 5))
    metric_keys = [k for k in history.history.keys() if k not in ['loss', 'val_loss', 'lr']]
    if metric_keys:
        train_metric = metric_keys[0]
        val_metric = f"val_{train_metric}"
        if val_metric in history.history:
            plt.plot(history.history[train_metric], label=f'Train {train_metric}')
            plt.plot(history.history[val_metric], label=f'Validation {val_metric}')
            plt.title(f'Model Metric ({train_metric})')
            plt.xlabel('Epochs')
            plt.ylabel('Metric')
            plt.legend()
    if filename is not None:
        plt.savefig(f"{filename}_metric.png")

# %%
# --- 5. 평가 및 시각화 모듈 ---
# ... (evaluate_model, plot_training_history 함수는 여기에 있습니다) ...

def plot_predictions(y_true, y_pred,filename=None):
    plt.figure(figsize=(8, 8)) # 정사각형 그래프로 변경

    # Output 1 (첫 번째 예측값) - 파란색
    plt.scatter(y_true[:, 0], y_pred[:, 0], 
                alpha=0.5, label='Output 1 Prediction (blue)')
    
    # Output 2 (두 번째 예측값) - 초록색
    plt.scatter(y_true[:, 1], y_pred[:, 1], 
                alpha=0.5, label='Output 2 Prediction (green)')

    plt.xlabel("Actual Values (True Values)")
    plt.ylabel("Predicted Values (Predictions)")
    plt.title("Prediction vs Actual (Overlay)")
    
    # y=x 선 (완벽한 예측)
    # 두 Output의 모든 값(true, pred)을 기준으로 min/max를 계산
    all_values = np.concatenate([y_true.flatten(), y_pred.flatten()])
    lims = [all_values.min() * 0.95, all_values.max() * 1.05] # 약간의 여백 추가
    
    plt.xlim(lims)
    plt.ylim(lims)
    plt.plot(lims, lims, 'r--', label='Perfect Prediction (y=x)')
    
    plt.legend() # 범례 표시
    plt.grid(True) # 그리드 추가
    if filename is not None:
        plt.savefig(f"{filename}_comparison.png")

# %%
def capture_model_summary(model):
    """Keras 모델의 .summary() 출력을 문자열로 반환합니다."""
    stream = io.StringIO()
    with redirect_stdout(stream):
        model.summary()
    return stream.getvalue()


EXPERIMENT_FIELDNAMES = [
    "timestamp", "architecture", "hidden_layers", "activation", 
    "regularizer", "dropout", "batch_norm", "learning_rate", 
    "batch_size", "n_epochs", "optimizer", "loss_function",
    "train_size", "dev_size", "final_train_loss", "final_dev_loss",
    "best_dev_loss", "best_epoch", "notes"
]

def log_experiment(log_path, model, history, model_config, train_config, X_train, X_val):
    """
    [TensorFlow/Keras 버전]
    훈련 결과를 CSV 파일에 한 줄로 기록합니다.
    """
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    
    # Keras History 객체에서 Loss 값들을 안전하게 추출
    train_losses = history.history.get('loss', [0.0])
    val_losses = history.history.get('val_loss', [0.0])
    
    # 기록할 파라미터 딕셔너리 생성
    params = {
        "timestamp": timestamp,
        "architecture": capture_model_summary(model), # 모델 구조 요약
        "hidden_layers": str(model_config.get('hidden_layers', [])), # 리스트를 문자열로
        "activation": model_config.get('activation', ''),
        "regularizer": model_config.get('regularizer_type', 'None'),
        "dropout": model_config.get('dropout_rate', 0.0),
        "batch_norm": model_config.get('use_batch_norm', False),
        "learning_rate": train_config.get('learning_rate', 0.0),
        "batch_size": train_config.get('batch_size', 0),
        "n_epochs": train_config.get('epochs', 0),
        "optimizer": model.optimizer.__class__.__name__, # 'Adam' 등
        "loss_function": train_config.get('loss', ''),
        "train_size": len(X_train), # X_train의 크기
        "dev_size": len(X_val),   # X_val의 크기
        "final_train_loss": round(train_losses[-1], 6),
        "final_dev_loss": round(val_losses[-1], 6),
        "best_dev_loss": round(min(val_losses), 6),
        "best_epoch": int(np.argmin(val_losses) + 1), # (numpy as np 필요)
    }
    
    file_exists = os.path.exists(log_path)
    with open(log_path, mode='a', newline='', encoding='utf-8') as f:
        # DictWriter가 params에 없는 키는 'N/A'로, params에 fieldnames에 없는 키는 무시하도록 설정
        writer = csv.DictWriter(f, 
                              fieldnames=EXPERIMENT_FIELDNAMES, 
                              restval='N/A', 
                              extrasaction='ignore')
        
        if not file_exists:
            writer.writeheader() # 파일이 없으면 헤더 쓰기
            
        writer.writerow(params) # 파라미터 한 줄 쓰기

# %%
def save_final_model(save_dir, model, history, train_config):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    n_epochs = train_config.get('epochs', 0)
    
    val_losses = history.history.get('val_loss', [0.0])
    final_dev_loss = val_losses[-1] # PyTorch의 avg_dev_loss 대신 final_dev_loss 사용
    
    final_name = f"final_pressureRNN_{timestamp}_epoch{n_epochs}_loss{final_dev_loss:.4f}.weights.h5"
    final_path = os.path.join(save_dir, final_name)
    
    # 3. 모델 가중치 저장
    model.save_weights(final_path)

# %%
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

DATA_BASE_PATH_ROOT = r"G:/내 드라이브/CS230 Project"
PROCESSED_DATA_FILE = "processed_haptic_data.npy"

# 모델 아키텍처 설정
MODEL_CONFIG = {
    'hidden_layers': [128, 64, 64,32, 32],
    'activation': 'relu',
    'regularizer_type': 'l2',
    'l2': 0.001,
    'use_batch_norm': True,
    'dropout_rate': 0.
}

# 훈련 설정
TRAIN_CONFIG = {
    'learning_rate': 0.005,
    'epochs': 100, # 126개 샘플은 적으니 epoch를 100~200 정도로 늘려도 좋습니다.
    'batch_size': 16, # 샘플이 적으므로 배치 크기를 32보다 작게 (16) 조정
    'loss': 'mean_squared_error',
    'metrics': ['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(name='rmse')]
}
# ==========================

# 1. 데이터 로드 (검증된 함수 사용)
if os.path.exists(PROCESSED_DATA_FILE):
    data = np.load(PROCESSED_DATA_FILE, allow_pickle=True).item()
    X = data['X']
    y = data['y']
    
else:
    X, y = load_all_data(DATA_BASE_PATH_ROOT)
    data_to_save = {'X': X, 'y': y}
    np.save(PROCESSED_DATA_FILE, data_to_save, allow_pickle=True)

print(f"전체 데이터셋 크기: X={X.shape}, y={y.shape}")
print(f"샘플 예시 (첫 5개):")
for i in range(min(5, X.shape[0])):
    print(f" X[{i}]: {X[i][:10]}... , y[{i}]: {y[i]}")
    
# # 1-Extra. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# # 2. 데이터 분리
X_train, X_val, X_test, y_train, y_val, y_test = split_data(X_scaled, y,0.15,0.15)

# if X_train.shape[0] == 0:
#     print("데이터 분리에 실패했습니다. (샘플 부족) 프로그램을 종료합니다.")
#     return

# # 3. 모델 구축
input_shape = (X_train.shape[1],)
model = build_model(input_shape, MODEL_CONFIG)

# # 4. 모델 훈련
model, history = compile_and_train_model(
    model, X_train, y_train, X_val, y_val, TRAIN_CONFIG
)

# # 5. 모델 평가
evaluate_model(model, X_test, y_test)

# # 6. 결과 시각화
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
plot_filename = os.path.join("results", "plots", f"loss_curve_{timestamp}.png")

plot_training_history(history,filename=plot_filename)

y_pred_val = model.predict(X_val)
plot_predictions(y_val,y_pred_val)

LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# 전체 데이터셋 크기: X=(795, 9248), y=(795, 2)
# 샘플 예시 (첫 5개):
#  X[0]: [1093. 1093. 1093. 1093. 1093. 1093. 1092. 1093. 1092. 1093.]... , y[0]: [1229.37 1265.18]
#  X[1]: [1100. 1097. 1099. 1097. 1099. 1097. 1100. 1097. 1100. 1097.]... , y[1]: [1212.33 1262.6 ]
#  X[2]: [1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097.]... , y[2]: [1229.8  1261.45]
#  X[3]: [1098. 1097. 1098. 1097. 1098. 1097. 1098. 1097. 1097. 1096.]... , y[3]: [1111.96 1117.9 ]
#  X[4]: [1090. 1092. 1090. 1092. 1090. 1093. 1090. 1093. 1091. 1092.]... , y[4]: [1220.12 1238.38]
# 데이터 분리 완료:
#   훈련 (Train)  : (573, 9248), (573, 2)
#   개발 (Dev)    : (102, 9248), (102, 2)
#   테스트 (Test) : (120, 9248), (120, 2)
# c:\Users\sehui\.conda\envs\CS230\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 모델 구성 완료:
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,200,770 (4.58 MB)
#  Trainable params: 1,200,130 (4.58 MB)
#  Non-trainable params: 640 (2.50 KB)
# --- 모델 훈련 시작 ---
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1407153.8750 - mean_absolute_error: 1184.9401 - rmse: 1186.2346 - val_loss: 1418733.6250 - val_mean_absolute_error: 1189.7906 - val_rmse: 1191.1053
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1397613.7500 - mean_absolute_error: 1180.9950 - rmse: 1182.2063 - val_loss: 1384337.7500 - val_mean_absolute_error: 1175.3794 - val_rmse: 1176.5779
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1376855.1250 - mean_absolute_error: 1172.2936 - rmse: 1173.3938 - val_loss: 1360726.7500 - val_mean_absolute_error: 1165.2853 - val_rmse: 1166.5009
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1343987.6250 - mean_absolute_error: 1158.1261 - rmse: 1159.3036 - val_loss: 1251455.8750 - val_mean_absolute_error: 1116.5863 - val_rmse: 1118.6835
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1298301.7500 - mean_absolute_error: 1138.4032 - rmse: 1139.4290 - val_loss: 1208574.1250 - val_mean_absolute_error: 1098.0966 - val_rmse: 1099.3501
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1241574.1250 - mean_absolute_error: 1113.1421 - rmse: 1114.2576 - val_loss: 1182413.0000 - val_mean_absolute_error: 1085.9987 - val_rmse: 1087.3862
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1174351.2500 - mean_absolute_error: 1082.6156 - rmse: 1083.6729 - val_loss: 1168134.2500 - val_mean_absolute_error: 1079.4712 - val_rmse: 1080.8002
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1098903.6250 - mean_absolute_error: 1047.1132 - rmse: 1048.2833 - val_loss: 1065601.6250 - val_mean_absolute_error: 1030.8994 - val_rmse: 1032.2770
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1016480.9375 - mean_absolute_error: 1007.1517 - rmse: 1008.2037 - val_loss: 957447.5000 - val_mean_absolute_error: 976.6578 - val_rmse: 978.4891
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 929682.1875 - mean_absolute_error: 963.0001 - rmse: 964.1967 - val_loss: 826390.2500 - val_mean_absolute_error: 907.1548 - val_rmse: 909.0565
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 839851.1250 - mean_absolute_error: 915.2010 - rmse: 916.4302 - val_loss: 781497.8750 - val_mean_absolute_error: 882.2668 - val_rmse: 884.0197
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 749168.0000 - mean_absolute_error: 864.2844 - rmse: 865.5407 - val_loss: 691420.0000 - val_mean_absolute_error: 829.8132 - val_rmse: 831.5121
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 659647.8125 - mean_absolute_error: 810.7954 - rmse: 812.1823 - val_loss: 587712.8125 - val_mean_absolute_error: 764.4642 - val_rmse: 766.6190
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 572745.1250 - mean_absolute_error: 755.3570 - rmse: 756.7936 - val_loss: 528751.4375 - val_mean_absolute_error: 725.1050 - val_rmse: 727.1470
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 490224.3125 - mean_absolute_error: 698.4727 - rmse: 700.1537 - val_loss: 431287.0625 - val_mean_absolute_error: 654.5736 - val_rmse: 656.7173
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 412823.4688 - mean_absolute_error: 641.0056 - rmse: 642.5059 - val_loss: 351569.7188 - val_mean_absolute_error: 589.7285 - val_rmse: 592.9246
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 342511.3750 - mean_absolute_error: 583.4479 - rmse: 585.2359 - val_loss: 322411.6562 - val_mean_absolute_error: 565.4887 - val_rmse: 567.8038
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 279249.7812 - mean_absolute_error: 526.4932 - rmse: 528.4307 - val_loss: 271639.1875 - val_mean_absolute_error: 518.5507 - val_rmse: 521.1795
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 223742.3281 - mean_absolute_error: 470.7332 - rmse: 473.0022 - val_loss: 208648.1562 - val_mean_absolute_error: 453.2056 - val_rmse: 456.7678
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 175815.9375 - mean_absolute_error: 417.0733 - rmse: 419.2902 - val_loss: 155733.2344 - val_mean_absolute_error: 391.4746 - val_rmse: 394.6152
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 135611.2500 - mean_absolute_error: 365.7668 - rmse: 368.2377 - val_loss: 113022.8828 - val_mean_absolute_error: 331.7107 - val_rmse: 336.1701
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 102779.7891 - mean_absolute_error: 317.5371 - rmse: 320.5730 - val_loss: 82945.5625 - val_mean_absolute_error: 282.8821 - val_rmse: 287.9803
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 76358.1953 - mean_absolute_error: 272.7517 - rmse: 276.3059 - val_loss: 66456.7969 - val_mean_absolute_error: 253.1973 - val_rmse: 257.7659
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 55525.7148 - mean_absolute_error: 231.7461 - rmse: 235.6098 - val_loss: 51232.9102 - val_mean_absolute_error: 220.3645 - val_rmse: 226.3165
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39848.2227 - mean_absolute_error: 194.9192 - rmse: 199.5858 - val_loss: 34362.1289 - val_mean_absolute_error: 177.6203 - val_rmse: 185.3329
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27973.9863 - mean_absolute_error: 162.1239 - rmse: 167.2129 - val_loss: 24090.4023 - val_mean_absolute_error: 145.1137 - val_rmse: 155.1657
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19555.6973 - mean_absolute_error: 133.4283 - rmse: 139.7907 - val_loss: 16076.3672 - val_mean_absolute_error: 115.1112 - val_rmse: 126.7353
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13362.8418 - mean_absolute_error: 108.5744 - rmse: 115.5341 - val_loss: 10625.1582 - val_mean_absolute_error: 89.0121 - val_rmse: 103.0062
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9176.3799 - mean_absolute_error: 87.7816 - rmse: 95.7145 - val_loss: 7250.6426 - val_mean_absolute_error: 70.4522 - val_rmse: 85.0601
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6438.7695 - mean_absolute_error: 70.5395 - rmse: 80.1440 - val_loss: 7276.9780 - val_mean_absolute_error: 72.4113 - val_rmse: 85.2124
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4689.9106 - mean_absolute_error: 58.4130 - rmse: 68.3658 - val_loss: 5248.9551 - val_mean_absolute_error: 59.5946 - val_rmse: 72.3377
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3321.3416 - mean_absolute_error: 48.2843 - rmse: 57.4888 - val_loss: 3837.2966 - val_mean_absolute_error: 51.7725 - val_rmse: 61.8130
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2633.5488 - mean_absolute_error: 41.9975 - rmse: 51.1569 - val_loss: 3484.1650 - val_mean_absolute_error: 49.8313 - val_rmse: 58.8861
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2182.2031 - mean_absolute_error: 36.9674 - rmse: 46.5340 - val_loss: 3150.0503 - val_mean_absolute_error: 48.7757 - val_rmse: 55.9735
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1965.3453 - mean_absolute_error: 35.5021 - rmse: 44.1394 - val_loss: 2926.9087 - val_mean_absolute_error: 46.0911 - val_rmse: 53.9419
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1579.9734 - mean_absolute_error: 31.1268 - rmse: 39.5295 - val_loss: 3154.6506 - val_mean_absolute_error: 47.9503 - val_rmse: 56.0102
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1674.9833 - mean_absolute_error: 31.6290 - rmse: 40.7117 - val_loss: 3772.8738 - val_mean_absolute_error: 51.8243 - val_rmse: 61.2801
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1499.7828 - mean_absolute_error: 30.4327 - rmse: 38.4984 - val_loss: 3360.4907 - val_mean_absolute_error: 48.5060 - val_rmse: 57.8154
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1543.1425 - mean_absolute_error: 30.4819 - rmse: 39.0539 - val_loss: 2935.6987 - val_mean_absolute_error: 45.7560 - val_rmse: 54.0155
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1424.0746 - mean_absolute_error: 29.2845 - rmse: 37.4965 - val_loss: 3508.9246 - val_mean_absolute_error: 49.1266 - val_rmse: 59.0840
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1510.2358 - mean_absolute_error: 30.0631 - rmse: 38.6257 - val_loss: 2839.0720 - val_mean_absolute_error: 47.0426 - val_rmse: 53.1086
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1547.3080 - mean_absolute_error: 30.5676 - rmse: 39.0988 - val_loss: 2436.5676 - val_mean_absolute_error: 42.6851 - val_rmse: 49.1726
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1518.0872 - mean_absolute_error: 29.9960 - rmse: 38.7224 - val_loss: 2772.6514 - val_mean_absolute_error: 43.9126 - val_rmse: 52.4786
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1405.7638 - mean_absolute_error: 29.3916 - rmse: 37.2440 - val_loss: 3011.8174 - val_mean_absolute_error: 44.5464 - val_rmse: 54.7079
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1473.6993 - mean_absolute_error: 30.1975 - rmse: 38.1399 - val_loss: 2717.7480 - val_mean_absolute_error: 45.1423 - val_rmse: 51.9464
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1321.8854 - mean_absolute_error: 28.3508 - rmse: 36.0862 - val_loss: 3130.9312 - val_mean_absolute_error: 46.8099 - val_rmse: 55.7735
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1393.2283 - mean_absolute_error: 28.6542 - rmse: 37.0510 - val_loss: 3198.8669 - val_mean_absolute_error: 46.0307 - val_rmse: 56.3756
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1432.0861 - mean_absolute_error: 29.0271 - rmse: 37.5670 - val_loss: 2880.0781 - val_mean_absolute_error: 45.6320 - val_rmse: 53.4711
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1371.9448 - mean_absolute_error: 28.2614 - rmse: 36.7524 - val_loss: 3239.6575 - val_mean_absolute_error: 47.1637 - val_rmse: 56.7282
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1362.2130 - mean_absolute_error: 28.5310 - rmse: 36.6132 - val_loss: 2722.9758 - val_mean_absolute_error: 43.8846 - val_rmse: 51.9743
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1257.3350 - mean_absolute_error: 26.9016 - rmse: 35.1490 - val_loss: 2840.1887 - val_mean_absolute_error: 45.0900 - val_rmse: 53.0852
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1255.8301 - mean_absolute_error: 27.7941 - rmse: 35.1215 - val_loss: 2868.0996 - val_mean_absolute_error: 44.7027 - val_rmse: 53.3438
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1386.4965 - mean_absolute_error: 28.5928 - rmse: 36.9309 - val_loss: 2976.1709 - val_mean_absolute_error: 46.3359 - val_rmse: 54.3466
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1431.1873 - mean_absolute_error: 29.2177 - rmse: 37.5292 - val_loss: 3334.9041 - val_mean_absolute_error: 49.5911 - val_rmse: 57.5464
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1255.8071 - mean_absolute_error: 26.8290 - rmse: 35.1035 - val_loss: 2781.2827 - val_mean_absolute_error: 44.8213 - val_rmse: 52.5116
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1498.0789 - mean_absolute_error: 29.3489 - rmse: 38.3953 - val_loss: 3114.9863 - val_mean_absolute_error: 47.1078 - val_rmse: 55.5955
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1389.9624 - mean_absolute_error: 29.0885 - rmse: 36.9549 - val_loss: 3003.3159 - val_mean_absolute_error: 45.3965 - val_rmse: 54.5799
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1229.3015 - mean_absolute_error: 26.8684 - rmse: 34.7121 - val_loss: 3314.6025 - val_mean_absolute_error: 47.5124 - val_rmse: 57.3602
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1403.2303 - mean_absolute_error: 28.4328 - rmse: 37.1293 - val_loss: 2825.3542 - val_mean_absolute_error: 46.3989 - val_rmse: 52.9192
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1509.4109 - mean_absolute_error: 30.0942 - rmse: 38.5263 - val_loss: 3153.3789 - val_mean_absolute_error: 45.1959 - val_rmse: 55.9289
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1303.6866 - mean_absolute_error: 28.2018 - rmse: 35.7530 - val_loss: 3141.7432 - val_mean_absolute_error: 45.4892 - val_rmse: 55.8246
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1294.6960 - mean_absolute_error: 27.6248 - rmse: 35.6262 - val_loss: 3157.5488 - val_mean_absolute_error: 46.0530 - val_rmse: 55.9635
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1285.8545 - mean_absolute_error: 27.2029 - rmse: 35.5017 - val_loss: 2720.8813 - val_mean_absolute_error: 42.6804 - val_rmse: 51.9169
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1292.6704 - mean_absolute_error: 27.5357 - rmse: 35.5938 - val_loss: 2617.0737 - val_mean_absolute_error: 42.3340 - val_rmse: 50.9009
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1189.3824 - mean_absolute_error: 26.2297 - rmse: 34.1004 - val_loss: 2780.8044 - val_mean_absolute_error: 44.3270 - val_rmse: 52.4795
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1385.1511 - mean_absolute_error: 28.2694 - rmse: 36.8577 - val_loss: 2682.2971 - val_mean_absolute_error: 44.0451 - val_rmse: 51.5314
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1308.0433 - mean_absolute_error: 27.7071 - rmse: 35.7931 - val_loss: 2932.0356 - val_mean_absolute_error: 44.7250 - val_rmse: 53.8986
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1281.4745 - mean_absolute_error: 26.7353 - rmse: 35.4182 - val_loss: 3562.8452 - val_mean_absolute_error: 49.7000 - val_rmse: 59.4614
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1127.0271 - mean_absolute_error: 26.2600 - rmse: 33.1620 - val_loss: 3183.9966 - val_mean_absolute_error: 47.5127 - val_rmse: 56.1848
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1270.9546 - mean_absolute_error: 27.6221 - rmse: 35.2649 - val_loss: 2806.9688 - val_mean_absolute_error: 44.6736 - val_rmse: 52.7224
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1326.9515 - mean_absolute_error: 27.7891 - rmse: 36.0485 - val_loss: 3132.1362 - val_mean_absolute_error: 46.0748 - val_rmse: 55.7183
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1251.4515 - mean_absolute_error: 26.5726 - rmse: 34.9800 - val_loss: 3054.5530 - val_mean_absolute_error: 45.7230 - val_rmse: 55.0142
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1237.3424 - mean_absolute_error: 26.8005 - rmse: 34.7741 - val_loss: 3324.5093 - val_mean_absolute_error: 47.3415 - val_rmse: 57.4145
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1273.5814 - mean_absolute_error: 26.4884 - rmse: 35.2913 - val_loss: 3315.9084 - val_mean_absolute_error: 47.6134 - val_rmse: 57.3390
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1202.4598 - mean_absolute_error: 26.5825 - rmse: 34.2648 - val_loss: 2972.7527 - val_mean_absolute_error: 45.2169 - val_rmse: 54.2595
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1069.4153 - mean_absolute_error: 24.7502 - rmse: 32.2593 - val_loss: 3480.1033 - val_mean_absolute_error: 47.9113 - val_rmse: 58.7470
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1113.6450 - mean_absolute_error: 24.9739 - rmse: 32.9354 - val_loss: 3012.4521 - val_mean_absolute_error: 44.5235 - val_rmse: 54.6215
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1122.4089 - mean_absolute_error: 25.3342 - rmse: 33.0666 - val_loss: 2957.8867 - val_mean_absolute_error: 42.9771 - val_rmse: 54.1180
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1160.4913 - mean_absolute_error: 25.9403 - rmse: 33.6356 - val_loss: 3156.7898 - val_mean_absolute_error: 45.4826 - val_rmse: 55.9255
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1197.9904 - mean_absolute_error: 26.0850 - rmse: 34.1877 - val_loss: 2756.3352 - val_mean_absolute_error: 43.9736 - val_rmse: 52.2197
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1254.1055 - mean_absolute_error: 27.0225 - rmse: 34.9921 - val_loss: 2799.1912 - val_mean_absolute_error: 44.0846 - val_rmse: 52.6249
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1135.5502 - mean_absolute_error: 25.4330 - rmse: 33.2536 - val_loss: 2909.0032 - val_mean_absolute_error: 43.8720 - val_rmse: 53.6589
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1196.5238 - mean_absolute_error: 25.9999 - rmse: 34.1588 - val_loss: 2950.4170 - val_mean_absolute_error: 43.9773 - val_rmse: 54.0420
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1261.7219 - mean_absolute_error: 26.7941 - rmse: 35.0929 - val_loss: 2632.2231 - val_mean_absolute_error: 42.3902 - val_rmse: 51.0110
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1169.0618 - mean_absolute_error: 25.3569 - rmse: 33.7482 - val_loss: 3190.3242 - val_mean_absolute_error: 46.2921 - val_rmse: 56.2146
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1067.3850 - mean_absolute_error: 24.7173 - rmse: 32.2038 - val_loss: 3255.1619 - val_mean_absolute_error: 46.6245 - val_rmse: 56.7868
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1476.8120 - mean_absolute_error: 29.4514 - rmse: 38.0307 - val_loss: 3421.4163 - val_mean_absolute_error: 48.3449 - val_rmse: 58.2304
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1092.3462 - mean_absolute_error: 25.2230 - rmse: 32.5833 - val_loss: 2602.5483 - val_mean_absolute_error: 44.1984 - val_rmse: 50.7130
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1051.8201 - mean_absolute_error: 25.0468 - rmse: 31.9539 - val_loss: 2857.7563 - val_mean_absolute_error: 45.4082 - val_rmse: 53.1692
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 996.6473 - mean_absolute_error: 23.9395 - rmse: 31.0783 - val_loss: 2984.7825 - val_mean_absolute_error: 45.4326 - val_rmse: 54.3504
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1066.9269 - mean_absolute_error: 24.0437 - rmse: 32.1858 - val_loss: 2586.6936 - val_mean_absolute_error: 42.4830 - val_rmse: 50.5529
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1166.6490 - mean_absolute_error: 25.9243 - rmse: 33.6991 - val_loss: 2665.7605 - val_mean_absolute_error: 43.2196 - val_rmse: 51.3303
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1112.1030 - mean_absolute_error: 25.3278 - rmse: 32.8786 - val_loss: 2778.5039 - val_mean_absolute_error: 42.9901 - val_rmse: 52.4134
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1396.0875 - mean_absolute_error: 28.2710 - rmse: 36.9437 - val_loss: 2713.5898 - val_mean_absolute_error: 44.4164 - val_rmse: 51.7899
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1245.4893 - mean_absolute_error: 26.7087 - rmse: 34.8417 - val_loss: 2750.6648 - val_mean_absolute_error: 43.8070 - val_rmse: 52.1436
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 995.1398 - mean_absolute_error: 23.7575 - rmse: 31.0385 - val_loss: 3045.0193 - val_mean_absolute_error: 45.2018 - val_rmse: 54.8919
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1110.0341 - mean_absolute_error: 25.2895 - rmse: 32.8348 - val_loss: 2752.5903 - val_mean_absolute_error: 43.1267 - val_rmse: 52.1594
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1191.9810 - mean_absolute_error: 25.8052 - rmse: 34.0595 - val_loss: 2902.2896 - val_mean_absolute_error: 44.7673 - val_rmse: 53.5753
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1140.2828 - mean_absolute_error: 25.3997 - rmse: 33.2897 - val_loss: 2971.3406 - val_mean_absolute_error: 44.1017 - val_rmse: 54.2139
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1215.9766 - mean_absolute_error: 26.3196 - rmse: 34.4060 - val_loss: 2777.7896 - val_mean_absolute_error: 43.1086 - val_rmse: 52.3975
# --- 모델 훈련 완료 ---
#
# --- 최종 모델 평가 (Test Set) ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2118.2441 - mean_absolute_error: 37.0663 - rmse: 45.6723
# loss: 2118.2441
# compile_metrics: 37.0663
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,601,032 (13.74 MB)
#  Trainable params: 1,200,130 (4.58 MB)
#  Non-trainable params: 640 (2.50 KB)
#  Optimizer params: 2,400,262 (9.16 MB)

# %%
LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,601,032 (13.74 MB)
#  Trainable params: 1,200,130 (4.58 MB)
#  Non-trainable params: 640 (2.50 KB)
#  Optimizer params: 2,400,262 (9.16 MB)
