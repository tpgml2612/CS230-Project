# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pathlib import Path
import matplotlib.pyplot as plt
import glob
import re
import warnings
from datetime import datetime
import os
import csv
import io                   # [추가] model.summary()를 캡처하기 위해
from contextlib import redirect_stdout
import csv

# %%
def trim_and_flatten_data(haptic_df):
    # Haptic: 4, 5th columns (index 3, 4)
    # Robot: 9, 10, 11th columns (index 8, 9, 10)
    haptic_data = haptic_df.iloc[:, [3, 4]].values
    
    # Process NaN values by replacing them with zeros
    haptic_data = np.nan_to_num(haptic_data, nan=0.0)
    return haptic_data.flatten()

# %%
def load_all_data(data_base_path):
    base_path = Path(data_base_path) / "DATA"

    all_X_data = []
    all_y_data = []

    METHOD_MAP = {'HAPTICS': 'H', 'NOhaptics': 'NH'}
    TASK_MAP = {
        5: ('pp1', 'PAP'), 6: ('pp1', 'PAP'),
        7: ('pp2', 'PAPObstructed'), 8: ('pp2', 'PAPObstructed'),
        9: ('pp3', 'Camera'), 10: ('pp3', 'Camera')
    }

    for p_id in range(1, 27): # 1~26

        participant_str = f"Participant_{p_id}"
        results_file = base_path / "Haptic Data" / participant_str / f"{participant_str}_results.csv"
        
        results_lookup = {}
        try:
            results_df = pd.read_csv(results_file)
            for _, row in results_df.iterrows():
                try:
                    condition = row['Condition']
                    subcondition = row['Subcondition']
                    trial_str = str(row['Trial'])
                    trial = int(re.search(r'^\d+', trial_str).group())
                    output_1 = pd.to_numeric(row['Sensor1 Mean'], errors='coerce')
                    output_2 = pd.to_numeric(row['Sensor2 Mean'], errors='coerce')

                    if pd.isna(output_1) or pd.isna(output_2):
                        continue
                    key = (condition, subcondition, trial)
                    results_lookup[key] = (output_1, output_2)
                except Exception:
                    continue
        except Exception as e:
            print(f"Error in reading ({results_file}): {e}")
            continue
        haptic_files_glob = glob.glob(str(base_path / "Haptic Data" / participant_str / "*.csv"))

        for hfile_path in haptic_files_glob:
            file_name = Path(hfile_path).name
            match = re.match(r'(\d+)_.*?_(HAPTICS|NOhaptics)_(\d+)\.csv', file_name)
            
            if not match:
                continue

            try:
                task_num = int(match.group(1))
                method = match.group(2)
                trial = int(match.group(3))
                
                if task_num not in TASK_MAP:
                    continue

                scenario_num, result_condition = TASK_MAP[task_num]
                method_short = METHOD_MAP[method]

                output_key = (result_condition, method, trial)
                if output_key not in results_lookup:
                    continue

                haptic_df = pd.read_csv(hfile_path)

                flat_input_vector = trim_and_flatten_data(haptic_df)

                if flat_input_vector is not None:
                    output_1, output_2 = results_lookup[output_key]
                    output_vector = np.array([output_1, output_2])
                    all_X_data.append(flat_input_vector)
                    all_y_data.append(output_vector)
            
                print(f" Success: participant {p_id} task {task_num}, method {method}, trial {trial}")
            except Exception as e:
                print(f"  Error: {file_name} - {e}")

    max_len = max(len(x) for x in all_X_data)
    
    X_padded = np.array([np.pad(x, (0, max_len - len(x)), 'constant') for x in all_X_data])
    y_array = np.array(all_y_data)

    return X_padded, y_array

# %%
def split_data(X, y, test_size=0.2, dev_size=0.125, random_state=42):
    """
    데이터를 훈련, 개발, 테스트 세트로 분리합니다. (기본 70:10:20)
    """
    if X.shape[0] == 0:
        print("오류: 분리할 데이터가 없습니다.")
        return (np.array([]),)*6

    # 1차 분리: 훈련+개발 (80%) / 테스트 (20%)
    X_train_dev, X_test, y_train_dev, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    # 2차 분리: 훈련 (70%) / 개발 (10%)
    X_train, X_dev, y_train, y_dev = train_test_split(
        X_train_dev, y_train_dev, test_size=dev_size, random_state=random_state
    )

    print(f"데이터 분리 완료:")
    print(f"  훈련 (Train)  : {X_train.shape}, {y_train.shape}")
    print(f"  개발 (Dev)    : {X_dev.shape}, {y_dev.shape}")
    print(f"  테스트 (Test) : {X_test.shape}, {y_test.shape}")

    return X_train, X_dev, X_test, y_train, y_dev, y_test

# %%
def get_regularizer(config):
    reg_type = config.get('regularizer_type', None)
    l1_val = config.get('l1', 0.01)
    l2_val = config.get('l2', 0.01)

    if reg_type == 'l1': return regularizers.l1(l1_val)
    elif reg_type == 'l2': return regularizers.l2(l2_val)
    elif reg_type == 'l1_l2': return regularizers.l1_l2(l1=l1_val, l2=l2_val)
    else: return None

# %%
def build_model(input_shape, model_config):
    model = Sequential(name="Modular_DNN_Model")
    model.add(InputLayer(input_shape=input_shape))

    hidden_layers = model_config.get('hidden_layers', [64, 32])
    activation = model_config.get('activation', 'relu')
    reg_obj = get_regularizer(model_config)

    for units in hidden_layers:
        model.add(Dense(units, activation=activation, kernel_regularizer=reg_obj))
        if model_config.get('use_batch_norm', False):
            model.add(BatchNormalization())
        if model_config.get('dropout_rate', 0.0) > 0:
            model.add(Dropout(model_config['dropout_rate']))

    model.add(Dense(2, name='output')) # 2개 값 예측 (회귀)

    print("모델 구성 완료:")
    model.summary()
    return model

# %%
def compile_and_train_model(model, X_train, y_train, X_val, y_val, train_config):
    loss_function = train_config.get('loss', 'mean_squared_error')
    learning_rate = train_config.get('learning_rate', 0.001)
    optimizer = Adam(learning_rate=learning_rate)
    metrics_list = train_config.get('metrics', ['mean_absolute_error'])

    model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics_list)

    callbacks_list = []
    patience = train_config.get('early_stopping_patience', None)
    
    if patience and patience > 0:
        early_stop = EarlyStopping(
            monitor='val_loss', 
            patience=patience,  
            verbose=1,          
            restore_best_weights=True
        )
        callbacks_list.append(early_stop)

    print("\n--- 모델 훈련 시작 ---")
    history = model.fit(
        X_train,
        y_train,
        epochs=train_config.get('epochs', 50),
        batch_size=train_config.get('batch_size', 32),
        validation_data=(X_val, y_val),
        verbose=1
    )
    print("--- 모델 훈련 완료 ---")

    return model, history

# %%
def evaluate_model(model, X_test, y_test):
    if X_test.shape[0] == 0:
        print("경고: 평가할 테스트 데이터가 없습니다.")
        return None

    print("\n--- 최종 모델 평가 (Test Set) ---")
    results = model.evaluate(X_test, y_test, verbose=1)
    metric_names = model.metrics_names
    for name, value in zip(metric_names, results):
        print(f"{name}: {value:.4f}")
    return results

# %%
def plot_training_history(history,filename=None):
    if not history:
        print("시각화할 훈련 기록(history)이 없습니다.")
        return

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    if filename is not None:
        plt.savefig(f"{filename}_loss.png")

    # Metric
    plt.figure(figsize=(12, 5))
    metric_keys = [k for k in history.history.keys() if k not in ['loss', 'val_loss', 'lr']]
    if metric_keys:
        train_metric = metric_keys[0]
        val_metric = f"val_{train_metric}"
        if val_metric in history.history:
            plt.subplot(1, 2, 2)
            plt.plot(history.history[train_metric], label=f'Train {train_metric}')
            plt.plot(history.history[val_metric], label=f'Validation {val_metric}')
            plt.title(f'Model Metric ({train_metric})')
            plt.xlabel('Epochs')
            plt.ylabel('Metric')
            plt.legend()
    plt.tight_layout()
    plt.show()
    if filename is not None:
        plt.savefig(f"{filename}_metric.png")

# %%
# --- 5. 평가 및 시각화 모듈 ---
# ... (evaluate_model, plot_training_history 함수는 여기에 있습니다) ...

def plot_predictions(y_true, y_pred,filename=None):
    """
    [수정된 함수]
    Validation set의 실제 값과 예측 값을
    하나의 산점도(scatterplot)에 오버레이하여 그립니다.
    """
    if y_true.shape[0] == 0:
        print("시각화할 검증 데이터가 없습니다.")
        return

    plt.figure(figsize=(8, 8)) # 정사각형 그래프로 변경

    # Output 1 (첫 번째 예측값) - 파란색
    plt.scatter(y_true[:, 0], y_pred[:, 0], 
                alpha=0.5, label='Output 1 Prediction (blue)')
    
    # Output 2 (두 번째 예측값) - 초록색
    plt.scatter(y_true[:, 1], y_pred[:, 1], 
                alpha=0.5, label='Output 2 Prediction (green)')

    plt.xlabel("Actual Values (True Values)")
    plt.ylabel("Predicted Values (Predictions)")
    plt.title("Prediction vs Actual (Overlay)")
    
    # y=x 선 (완벽한 예측)
    # 두 Output의 모든 값(true, pred)을 기준으로 min/max를 계산
    all_values = np.concatenate([y_true.flatten(), y_pred.flatten()])
    lims = [all_values.min() * 0.95, all_values.max() * 1.05] # 약간의 여백 추가
    
    plt.xlim(lims)
    plt.ylim(lims)
    plt.plot(lims, lims, 'r--', label='Perfect Prediction (y=x)')
    
    plt.legend() # 범례 표시
    plt.grid(True) # 그리드 추가
    if filename is not None:
        plt.savefig(f"{filename}_comparison.png")
    plt.tight_layout()
    plt.show()
    if filename is not None:
        plt.savefig(f"{filename}_pred.png")

# %%
def capture_model_summary(model):
    """Keras 모델의 .summary() 출력을 문자열로 반환합니다."""
    stream = io.StringIO()
    with redirect_stdout(stream):
        model.summary()
    return stream.getvalue()


EXPERIMENT_FIELDNAMES = [
    "timestamp", "architecture", "hidden_layers", "activation", 
    "regularizer", "dropout", "batch_norm", "learning_rate", 
    "batch_size", "n_epochs", "optimizer", "loss_function",
    "train_size", "dev_size", "final_train_loss", "final_dev_loss",
    "best_dev_loss", "best_epoch", "notes"
]

def log_experiment(log_path, model, history, model_config, train_config, X_train, X_val):
    """
    [TensorFlow/Keras 버전]
    훈련 결과를 CSV 파일에 한 줄로 기록합니다.
    """
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    
    # Keras History 객체에서 Loss 값들을 안전하게 추출
    train_losses = history.history.get('loss', [0.0])
    val_losses = history.history.get('val_loss', [0.0])
    
    # 기록할 파라미터 딕셔너리 생성
    params = {
        "timestamp": timestamp,
        "architecture": capture_model_summary(model), # 모델 구조 요약
        "hidden_layers": str(model_config.get('hidden_layers', [])), # 리스트를 문자열로
        "activation": model_config.get('activation', ''),
        "regularizer": model_config.get('regularizer_type', 'None'),
        "dropout": model_config.get('dropout_rate', 0.0),
        "batch_norm": model_config.get('use_batch_norm', False),
        "learning_rate": train_config.get('learning_rate', 0.0),
        "batch_size": train_config.get('batch_size', 0),
        "n_epochs": train_config.get('epochs', 0),
        "optimizer": model.optimizer.__class__.__name__, # 'Adam' 등
        "loss_function": train_config.get('loss', ''),
        "train_size": len(X_train), # X_train의 크기
        "dev_size": len(X_val),   # X_val의 크기
        "final_train_loss": round(train_losses[-1], 6),
        "final_dev_loss": round(val_losses[-1], 6),
        "best_dev_loss": round(min(val_losses), 6),
        "best_epoch": int(np.argmin(val_losses) + 1), # (numpy as np 필요)
    }
    
    file_exists = os.path.exists(log_path)
    with open(log_path, mode='a', newline='', encoding='utf-8') as f:
        # DictWriter가 params에 없는 키는 'N/A'로, params에 fieldnames에 없는 키는 무시하도록 설정
        writer = csv.DictWriter(f, 
                              fieldnames=EXPERIMENT_FIELDNAMES, 
                              restval='N/A', 
                              extrasaction='ignore')
        
        if not file_exists:
            writer.writeheader() # 파일이 없으면 헤더 쓰기
            
        writer.writerow(params) # 파라미터 한 줄 쓰기

# %%
def save_final_model(save_dir, model, history, train_config):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    n_epochs = train_config.get('epochs', 0)
    
    val_losses = history.history.get('val_loss', [0.0])
    final_dev_loss = val_losses[-1] # PyTorch의 avg_dev_loss 대신 final_dev_loss 사용
    
    final_name = f"final_pressureRNN_{timestamp}_epoch{n_epochs}_loss{final_dev_loss:.4f}.weights.h5"
    final_path = os.path.join(save_dir, final_name)
    
    # 3. 모델 가중치 저장
    model.save_weights(final_path)

# %%
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

DATA_BASE_PATH_ROOT = r"G:/내 드라이브/CS230 Project"
PROCESSED_DATA_FILE = "processed_haptic_data.npy"

# 모델 아키텍처 설정
MODEL_CONFIG = {
    'hidden_layers': [128, 64, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32],
    'activation': 'relu',
    'regularizer_type': 'l2',
    'l2': 0.001,
    'use_batch_norm': True,
    'dropout_rate': 0.
}

# 훈련 설정
TRAIN_CONFIG = {
    'learning_rate': 0.002,
    'epochs': 500,
    'batch_size': 32, # 샘플이 적으므로 배치 크기를 32보다 작게 (16) 조정
    'loss': 'mean_squared_error',
    'metrics': ['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(name='rmse')],
    'early_stopping_patience': 30
}
# ==========================

# 1. 데이터 로드 (검증된 함수 사용)
if os.path.exists(PROCESSED_DATA_FILE):
    data = np.load(PROCESSED_DATA_FILE, allow_pickle=True).item()
    X = data['X']
    y = data['y']
    
else:
    X, y = load_all_data(DATA_BASE_PATH_ROOT)
    data_to_save = {'X': X, 'y': y}
    np.save(PROCESSED_DATA_FILE, data_to_save, allow_pickle=True)

print(f"전체 데이터셋 크기: X={X.shape}, y={y.shape}")
print(f"샘플 예시 (첫 5개):")
for i in range(min(5, X.shape[0])):
    print(f" X[{i}]: {X[i][:10]}... , y[{i}]: {y[i]}")
    
# # 1-Extra. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# # 2. 데이터 분리
X_train, X_val, X_test, y_train, y_val, y_test = split_data(X_scaled, y,0.15,0.15)

# if X_train.shape[0] == 0:
#     print("데이터 분리에 실패했습니다. (샘플 부족) 프로그램을 종료합니다.")
#     return

# # 3. 모델 구축
input_shape = (X_train.shape[1],)
model = build_model(input_shape, MODEL_CONFIG)

# # 4. 모델 훈련
model, history = compile_and_train_model(
    model, X_train, y_train, X_val, y_val, TRAIN_CONFIG
)

# # 5. 모델 평가
evaluate_model(model, X_test, y_test)

# # 6. 결과 시각화
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
plot_filename = os.path.join("results", "plots", f"loss_curve_{timestamp}.png")

plot_training_history(history,filename=plot_filename)

y_pred_val = model.predict(X_val)
plot_predictions(y_val,y_pred_val)

LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# 전체 데이터셋 크기: X=(795, 9248), y=(795, 2)
# 샘플 예시 (첫 5개):
#  X[0]: [1093. 1093. 1093. 1093. 1093. 1093. 1092. 1093. 1092. 1093.]... , y[0]: [1229.37 1265.18]
#  X[1]: [1100. 1097. 1099. 1097. 1099. 1097. 1100. 1097. 1100. 1097.]... , y[1]: [1212.33 1262.6 ]
#  X[2]: [1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097. 1091. 1097.]... , y[2]: [1229.8  1261.45]
#  X[3]: [1098. 1097. 1098. 1097. 1098. 1097. 1098. 1097. 1097. 1096.]... , y[3]: [1111.96 1117.9 ]
#  X[4]: [1090. 1092. 1090. 1092. 1090. 1093. 1090. 1093. 1091. 1092.]... , y[4]: [1220.12 1238.38]
# 데이터 분리 완료:
#   훈련 (Train)  : (573, 9248), (573, 2)
#   개발 (Dev)    : (102, 9248), (102, 2)
#   테스트 (Test) : (120, 9248), (120, 2)
# c:\Users\sehui\.conda\envs\CS230\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 모델 구성 완료:
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_60 (Dense)                │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_60          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_61          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_62          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_63          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_64          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_65          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_66          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_67          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_68          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_69          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_70          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_71          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_72          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_74          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_75          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_76          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_77          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_78          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_79          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,215,298 (4.64 MB)
#  Trainable params: 1,213,762 (4.63 MB)
#  Non-trainable params: 1,536 (6.00 KB)
# --- 모델 훈련 시작 ---
# Epoch 1/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 1408859.2500 - mean_absolute_error: 1185.6353 - rmse: 1186.9535 - val_loss: 1421906.2500 - val_mean_absolute_error: 1191.0684 - val_rmse: 1192.4369
# Epoch 2/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1408267.6250 - mean_absolute_error: 1185.3822 - rmse: 1186.7041 - val_loss: 1421160.5000 - val_mean_absolute_error: 1190.7548 - val_rmse: 1192.1239
# Epoch 3/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1407337.6250 - mean_absolute_error: 1184.9915 - rmse: 1186.3123 - val_loss: 1420059.8750 - val_mean_absolute_error: 1190.2914 - val_rmse: 1191.6622
# Epoch 4/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1406005.2500 - mean_absolute_error: 1184.4257 - rmse: 1185.7506 - val_loss: 1417867.1250 - val_mean_absolute_error: 1189.3699 - val_rmse: 1190.7418
# Epoch 5/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1404178.2500 - mean_absolute_error: 1183.6621 - rmse: 1184.9799 - val_loss: 1415617.2500 - val_mean_absolute_error: 1188.4242 - val_rmse: 1189.7968
# Epoch 6/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1401862.2500 - mean_absolute_error: 1182.6860 - rmse: 1184.0022 - val_loss: 1413741.5000 - val_mean_absolute_error: 1187.6337 - val_rmse: 1189.0082
# Epoch 7/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1399034.7500 - mean_absolute_error: 1181.4911 - rmse: 1182.8075 - val_loss: 1411509.1250 - val_mean_absolute_error: 1186.6934 - val_rmse: 1188.0691
# Epoch 8/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1395682.1250 - mean_absolute_error: 1180.0715 - rmse: 1181.3894 - val_loss: 1407121.1250 - val_mean_absolute_error: 1184.8416 - val_rmse: 1186.2209
# Epoch 9/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1391775.2500 - mean_absolute_error: 1178.4281 - rmse: 1179.7347 - val_loss: 1401490.3750 - val_mean_absolute_error: 1182.4626 - val_rmse: 1183.8451
# Epoch 10/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1387415.2500 - mean_absolute_error: 1176.5576 - rmse: 1177.8855 - val_loss: 1397718.1250 - val_mean_absolute_error: 1180.8666 - val_rmse: 1182.2507
# Epoch 11/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1382458.6250 - mean_absolute_error: 1174.4626 - rmse: 1175.7794 - val_loss: 1392211.1250 - val_mean_absolute_error: 1178.5273 - val_rmse: 1179.9194
# Epoch 12/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1376998.7500 - mean_absolute_error: 1172.1407 - rmse: 1173.4556 - val_loss: 1383717.7500 - val_mean_absolute_error: 1174.9320 - val_rmse: 1176.3149
# Epoch 13/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1371009.7500 - mean_absolute_error: 1169.5938 - rmse: 1170.9008 - val_loss: 1375159.3750 - val_mean_absolute_error: 1171.2258 - val_rmse: 1172.6714
# Epoch 14/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1364581.5000 - mean_absolute_error: 1166.8252 - rmse: 1168.1525 - val_loss: 1385008.3750 - val_mean_absolute_error: 1175.3628 - val_rmse: 1176.8632
# Epoch 15/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1357521.5000 - mean_absolute_error: 1163.8386 - rmse: 1165.1267 - val_loss: 1382890.5000 - val_mean_absolute_error: 1174.4590 - val_rmse: 1175.9631
# Epoch 16/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1350031.1250 - mean_absolute_error: 1160.6317 - rmse: 1161.9078 - val_loss: 1377918.6250 - val_mean_absolute_error: 1172.4530 - val_rmse: 1173.8473
# Epoch 17/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1342101.1250 - mean_absolute_error: 1157.2089 - rmse: 1158.4902 - val_loss: 1365266.8750 - val_mean_absolute_error: 1166.8525 - val_rmse: 1168.4458
# Epoch 18/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1333664.3750 - mean_absolute_error: 1153.5735 - rmse: 1154.8434 - val_loss: 1341501.0000 - val_mean_absolute_error: 1156.8927 - val_rmse: 1158.2313
# Epoch 19/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1324733.3750 - mean_absolute_error: 1149.7273 - rmse: 1150.9701 - val_loss: 1341422.8750 - val_mean_absolute_error: 1156.7775 - val_rmse: 1158.1976
# Epoch 20/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1315293.8750 - mean_absolute_error: 1145.6715 - rmse: 1146.8621 - val_loss: 1341470.3750 - val_mean_absolute_error: 1156.6753 - val_rmse: 1158.2181
# Epoch 21/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1305563.2500 - mean_absolute_error: 1141.4093 - rmse: 1142.6118 - val_loss: 1331131.1250 - val_mean_absolute_error: 1152.4301 - val_rmse: 1153.7460
# Epoch 22/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1295426.2500 - mean_absolute_error: 1136.9456 - rmse: 1138.1674 - val_loss: 1345525.7500 - val_mean_absolute_error: 1158.4888 - val_rmse: 1159.9674
# Epoch 23/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1284742.6250 - mean_absolute_error: 1132.2861 - rmse: 1133.4644 - val_loss: 1324326.3750 - val_mean_absolute_error: 1149.4611 - val_rmse: 1150.7932
# Epoch 24/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1273734.8750 - mean_absolute_error: 1127.4261 - rmse: 1128.5981 - val_loss: 1317669.6250 - val_mean_absolute_error: 1146.0566 - val_rmse: 1147.8973
# Epoch 25/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1262329.6250 - mean_absolute_error: 1122.3694 - rmse: 1123.5338 - val_loss: 1270235.8750 - val_mean_absolute_error: 1125.7346 - val_rmse: 1127.0468
# Epoch 26/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1250494.2500 - mean_absolute_error: 1117.1259 - rmse: 1118.2544 - val_loss: 1228326.3750 - val_mean_absolute_error: 1106.7321 - val_rmse: 1108.2982
# Epoch 27/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1238360.3750 - mean_absolute_error: 1111.6987 - rmse: 1112.8158 - val_loss: 1263531.5000 - val_mean_absolute_error: 1122.5830 - val_rmse: 1124.0686
# Epoch 28/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1225793.0000 - mean_absolute_error: 1106.0801 - rmse: 1107.1548 - val_loss: 1324238.7500 - val_mean_absolute_error: 1146.9133 - val_rmse: 1150.7551
# Epoch 29/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1213527.7500 - mean_absolute_error: 1100.2771 - rmse: 1101.6018 - val_loss: 1270444.3750 - val_mean_absolute_error: 1124.3198 - val_rmse: 1127.1393
# Epoch 30/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1200231.3750 - mean_absolute_error: 1094.3032 - rmse: 1095.5500 - val_loss: 1199033.6250 - val_mean_absolute_error: 1092.9945 - val_rmse: 1095.0033
# Epoch 31/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1186847.2500 - mean_absolute_error: 1088.1477 - rmse: 1089.4246 - val_loss: 1238290.2500 - val_mean_absolute_error: 1110.5927 - val_rmse: 1112.7842
# Epoch 32/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1172959.5000 - mean_absolute_error: 1081.8221 - rmse: 1083.0319 - val_loss: 1257907.6250 - val_mean_absolute_error: 1119.4202 - val_rmse: 1121.5642
# Epoch 33/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1158924.1250 - mean_absolute_error: 1075.3241 - rmse: 1076.5328 - val_loss: 1160505.7500 - val_mean_absolute_error: 1075.2478 - val_rmse: 1077.2670
# Epoch 34/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1144586.0000 - mean_absolute_error: 1068.6603 - rmse: 1069.8527 - val_loss: 1134363.6250 - val_mean_absolute_error: 1063.4203 - val_rmse: 1065.0645
# Epoch 35/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1129934.2500 - mean_absolute_error: 1061.8289 - rmse: 1062.9829 - val_loss: 1142148.6250 - val_mean_absolute_error: 1066.9150 - val_rmse: 1068.7128
# Epoch 36/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1115236.5000 - mean_absolute_error: 1054.8402 - rmse: 1056.0468 - val_loss: 1129564.5000 - val_mean_absolute_error: 1060.3812 - val_rmse: 1062.8090
# Epoch 37/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1100148.7500 - mean_absolute_error: 1047.6952 - rmse: 1048.8790 - val_loss: 1155249.2500 - val_mean_absolute_error: 1072.3094 - val_rmse: 1074.8245
# Epoch 38/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1084729.1250 - mean_absolute_error: 1040.3975 - rmse: 1041.5027 - val_loss: 1129767.7500 - val_mean_absolute_error: 1060.7557 - val_rmse: 1062.9045
# Epoch 39/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1069188.2500 - mean_absolute_error: 1032.9449 - rmse: 1034.0148 - val_loss: 1124581.3750 - val_mean_absolute_error: 1058.3434 - val_rmse: 1060.4620
# Epoch 40/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1053588.0000 - mean_absolute_error: 1025.3478 - rmse: 1026.4436 - val_loss: 1117166.2500 - val_mean_absolute_error: 1055.2477 - val_rmse: 1056.9601
# Epoch 41/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1037742.3750 - mean_absolute_error: 1017.5986 - rmse: 1018.6954 - val_loss: 1094108.0000 - val_mean_absolute_error: 1044.5857 - val_rmse: 1045.9954
# Epoch 42/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1021759.5625 - mean_absolute_error: 1009.7167 - rmse: 1010.8203 - val_loss: 1052189.0000 - val_mean_absolute_error: 1024.3866 - val_rmse: 1025.7620
# Epoch 43/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1005373.8750 - mean_absolute_error: 1001.6976 - rmse: 1002.6824 - val_loss: 1035506.2500 - val_mean_absolute_error: 1016.2881 - val_rmse: 1017.5974
# Epoch 44/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 989155.8750 - mean_absolute_error: 993.5396 - rmse: 994.5622 - val_loss: 1029539.1875 - val_mean_absolute_error: 1013.3555 - val_rmse: 1014.6611
# Epoch 45/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 972761.2500 - mean_absolute_error: 985.2460 - rmse: 986.2856 - val_loss: 1023667.9375 - val_mean_absolute_error: 1010.4197 - val_rmse: 1011.7637
# Epoch 46/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 956389.0625 - mean_absolute_error: 976.8278 - rmse: 977.9504 - val_loss: 1022104.8750 - val_mean_absolute_error: 1009.6164 - val_rmse: 1010.9910
# Epoch 47/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 939591.8125 - mean_absolute_error: 968.2941 - rmse: 969.3244 - val_loss: 1011370.5000 - val_mean_absolute_error: 1004.3915 - val_rmse: 1005.6682
# Epoch 48/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 922795.0625 - mean_absolute_error: 959.6353 - rmse: 960.6212 - val_loss: 1005670.1875 - val_mean_absolute_error: 1001.4856 - val_rmse: 1002.8301
# Epoch 49/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 906140.0625 - mean_absolute_error: 950.8604 - rmse: 951.9128 - val_loss: 974360.1875 - val_mean_absolute_error: 985.8291 - val_rmse: 987.0958
# Epoch 50/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 889404.9375 - mean_absolute_error: 941.9686 - rmse: 943.0816 - val_loss: 951554.5000 - val_mean_absolute_error: 974.0937 - val_rmse: 975.4755
# Epoch 51/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 872405.0000 - mean_absolute_error: 932.9678 - rmse: 934.0251 - val_loss: 947879.5000 - val_mean_absolute_error: 972.0390 - val_rmse: 973.5900
# Epoch 52/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 855621.0000 - mean_absolute_error: 923.8610 - rmse: 924.9967 - val_loss: 908808.9375 - val_mean_absolute_error: 951.9381 - val_rmse: 953.3136
# Epoch 53/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 838616.4375 - mean_absolute_error: 914.6519 - rmse: 915.7589 - val_loss: 904290.8750 - val_mean_absolute_error: 949.3406 - val_rmse: 950.9410
# Epoch 54/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 821523.8125 - mean_absolute_error: 905.3348 - rmse: 906.3784 - val_loss: 869093.3125 - val_mean_absolute_error: 930.3578 - val_rmse: 932.2507
# Epoch 55/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 804438.3125 - mean_absolute_error: 895.9244 - rmse: 896.9036 - val_loss: 875340.0625 - val_mean_absolute_error: 933.8908 - val_rmse: 935.5950
# Epoch 56/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 787778.3125 - mean_absolute_error: 886.4155 - rmse: 887.5676 - val_loss: 826710.6875 - val_mean_absolute_error: 907.5775 - val_rmse: 909.2352
# Epoch 57/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 770700.3125 - mean_absolute_error: 876.8273 - rmse: 877.8942 - val_loss: 823406.8750 - val_mean_absolute_error: 905.9290 - val_rmse: 907.4166
# Epoch 58/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 753870.4375 - mean_absolute_error: 867.1472 - rmse: 868.2559 - val_loss: 815853.1875 - val_mean_absolute_error: 901.8552 - val_rmse: 903.2447
# Epoch 59/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 737085.5000 - mean_absolute_error: 857.3768 - rmse: 858.5356 - val_loss: 800704.6875 - val_mean_absolute_error: 893.1292 - val_rmse: 894.8198
# Epoch 60/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 720344.6875 - mean_absolute_error: 847.5284 - rmse: 848.7299 - val_loss: 782849.0000 - val_mean_absolute_error: 883.2154 - val_rmse: 884.7863
# Epoch 61/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 703592.8750 - mean_absolute_error: 837.6128 - rmse: 838.8031 - val_loss: 770034.8750 - val_mean_absolute_error: 875.8703 - val_rmse: 877.5151
# Epoch 62/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 686923.5625 - mean_absolute_error: 827.6252 - rmse: 828.8073 - val_loss: 760387.1875 - val_mean_absolute_error: 870.2964 - val_rmse: 872.0007
# Epoch 63/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 670200.6250 - mean_absolute_error: 817.5711 - rmse: 818.6565 - val_loss: 735953.1250 - val_mean_absolute_error: 856.2145 - val_rmse: 857.8759
# Epoch 64/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 653847.1250 - mean_absolute_error: 807.4410 - rmse: 808.6068 - val_loss: 714018.4375 - val_mean_absolute_error: 843.2867 - val_rmse: 844.9948
# Epoch 65/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 637419.5000 - mean_absolute_error: 797.2563 - rmse: 798.3842 - val_loss: 698399.3750 - val_mean_absolute_error: 834.0323 - val_rmse: 835.7016
# Epoch 66/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 621296.3750 - mean_absolute_error: 787.0151 - rmse: 788.2222 - val_loss: 677495.1875 - val_mean_absolute_error: 821.2341 - val_rmse: 823.0996
# Epoch 67/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 605056.1250 - mean_absolute_error: 776.7108 - rmse: 777.8521 - val_loss: 658834.4375 - val_mean_absolute_error: 809.6772 - val_rmse: 811.6848
# Epoch 68/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 589044.7500 - mean_absolute_error: 766.3610 - rmse: 767.4911 - val_loss: 650692.1875 - val_mean_absolute_error: 804.6171 - val_rmse: 806.6536
# Epoch 69/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 573184.1250 - mean_absolute_error: 755.9606 - rmse: 757.0876 - val_loss: 625509.2500 - val_mean_absolute_error: 789.2115 - val_rmse: 790.8900
# Epoch 70/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 557447.3125 - mean_absolute_error: 745.5191 - rmse: 746.6225 - val_loss: 607182.0000 - val_mean_absolute_error: 777.5953 - val_rmse: 779.2174
# Epoch 71/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 541960.1250 - mean_absolute_error: 735.0475 - rmse: 736.1779 - val_loss: 602465.2500 - val_mean_absolute_error: 774.1904 - val_rmse: 776.1849
# Epoch 72/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 526630.0625 - mean_absolute_error: 724.5387 - rmse: 725.6913 - val_loss: 590613.6250 - val_mean_absolute_error: 766.8195 - val_rmse: 768.5125
# Epoch 73/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 511522.9688 - mean_absolute_error: 713.9813 - rmse: 715.2069 - val_loss: 569745.5625 - val_mean_absolute_error: 753.1118 - val_rmse: 754.8134
# Epoch 74/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 496458.6250 - mean_absolute_error: 703.4158 - rmse: 704.5966 - val_loss: 558149.2500 - val_mean_absolute_error: 745.4180 - val_rmse: 747.0923
# Epoch 75/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 481678.9688 - mean_absolute_error: 692.8101 - rmse: 694.0294 - val_loss: 542009.1875 - val_mean_absolute_error: 734.4456 - val_rmse: 736.2112
# Epoch 76/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 467035.1875 - mean_absolute_error: 682.1936 - rmse: 683.3982 - val_loss: 519238.5938 - val_mean_absolute_error: 718.8949 - val_rmse: 720.5806
# Epoch 77/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 452725.6250 - mean_absolute_error: 671.5571 - rmse: 672.8473 - val_loss: 501658.0938 - val_mean_absolute_error: 706.6024 - val_rmse: 708.2767
# Epoch 78/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 438376.6562 - mean_absolute_error: 660.9008 - rmse: 662.0985 - val_loss: 490951.7188 - val_mean_absolute_error: 698.8857 - val_rmse: 700.6779
# Epoch 79/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 424389.0625 - mean_absolute_error: 650.2391 - rmse: 651.4498 - val_loss: 469489.9688 - val_mean_absolute_error: 683.2155 - val_rmse: 685.1917
# Epoch 80/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 410703.0625 - mean_absolute_error: 639.5813 - rmse: 640.8595 - val_loss: 453196.6250 - val_mean_absolute_error: 671.3239 - val_rmse: 673.1971
# Epoch 81/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 397104.4688 - mean_absolute_error: 628.9094 - rmse: 630.1605 - val_loss: 421861.4375 - val_mean_absolute_error: 647.3800 - val_rmse: 649.5070
# Epoch 82/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 383897.0000 - mean_absolute_error: 618.2411 - rmse: 619.5924 - val_loss: 404349.6875 - val_mean_absolute_error: 633.6995 - val_rmse: 635.8832
# Epoch 83/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 370723.1562 - mean_absolute_error: 607.5839 - rmse: 608.8685 - val_loss: 395179.4062 - val_mean_absolute_error: 626.5045 - val_rmse: 628.6312
# Epoch 84/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 357969.3125 - mean_absolute_error: 596.9266 - rmse: 598.3034 - val_loss: 384138.5938 - val_mean_absolute_error: 617.1075 - val_rmse: 619.7874
# Epoch 85/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 345439.6875 - mean_absolute_error: 586.3120 - rmse: 587.7393 - val_loss: 381182.8125 - val_mean_absolute_error: 615.1318 - val_rmse: 617.3982
# Epoch 86/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 333016.2812 - mean_absolute_error: 575.6890 - rmse: 577.0737 - val_loss: 358483.6562 - val_mean_absolute_error: 596.4893 - val_rmse: 598.7332
# Epoch 87/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 320893.0312 - mean_absolute_error: 565.0786 - rmse: 566.4722 - val_loss: 359206.0312 - val_mean_absolute_error: 597.3171 - val_rmse: 599.3361
# Epoch 88/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 309178.6250 - mean_absolute_error: 554.4996 - rmse: 556.0363 - val_loss: 353959.4375 - val_mean_absolute_error: 592.9675 - val_rmse: 594.9429
# Epoch 89/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 297485.3750 - mean_absolute_error: 543.9308 - rmse: 545.4202 - val_loss: 359803.2500 - val_mean_absolute_error: 597.2426 - val_rmse: 599.8341
# Epoch 90/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 286279.2188 - mean_absolute_error: 533.4138 - rmse: 535.0485 - val_loss: 331090.0000 - val_mean_absolute_error: 572.9787 - val_rmse: 575.4022
# Epoch 91/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 275056.0000 - mean_absolute_error: 522.9444 - rmse: 524.4556 - val_loss: 308424.9062 - val_mean_absolute_error: 553.1670 - val_rmse: 555.3581
# Epoch 92/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 264285.6250 - mean_absolute_error: 512.5220 - rmse: 514.0849 - val_loss: 289933.8750 - val_mean_absolute_error: 535.9110 - val_rmse: 538.4529
# Epoch 93/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 253681.3125 - mean_absolute_error: 502.1140 - rmse: 503.6655 - val_loss: 292192.6562 - val_mean_absolute_error: 538.2292 - val_rmse: 540.5463
# Epoch 94/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 243323.3906 - mean_absolute_error: 491.7530 - rmse: 493.2758 - val_loss: 294225.2500 - val_mean_absolute_error: 539.6029 - val_rmse: 542.4232
# Epoch 95/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 233638.5469 - mean_absolute_error: 481.4462 - rmse: 483.3592 - val_loss: 275742.6562 - val_mean_absolute_error: 522.6575 - val_rmse: 525.1098
# Epoch 96/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 223718.8906 - mean_absolute_error: 471.2073 - rmse: 472.9868 - val_loss: 259789.0156 - val_mean_absolute_error: 507.4704 - val_rmse: 509.6927
# Epoch 97/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 214164.5000 - mean_absolute_error: 461.0245 - rmse: 462.7765 - val_loss: 254589.8594 - val_mean_absolute_error: 501.6751 - val_rmse: 504.5666
# Epoch 98/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 204910.6250 - mean_absolute_error: 450.8970 - rmse: 452.6678 - val_loss: 248281.7188 - val_mean_absolute_error: 495.6266 - val_rmse: 498.2763
# Epoch 99/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 195974.4844 - mean_absolute_error: 440.8436 - rmse: 442.6873 - val_loss: 231570.7188 - val_mean_absolute_error: 478.1844 - val_rmse: 481.2154
# Epoch 100/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 187207.2812 - mean_absolute_error: 430.8174 - rmse: 432.6717 - val_loss: 227053.0781 - val_mean_absolute_error: 473.8353 - val_rmse: 476.4982
# Epoch 101/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 178763.1875 - mean_absolute_error: 420.9117 - rmse: 422.8010 - val_loss: 216567.2031 - val_mean_absolute_error: 462.5713 - val_rmse: 465.3651
# Epoch 102/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 170461.5781 - mean_absolute_error: 411.0642 - rmse: 412.8669 - val_loss: 202844.7500 - val_mean_absolute_error: 446.9030 - val_rmse: 450.3801
# Epoch 103/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 162537.4375 - mean_absolute_error: 401.2908 - rmse: 403.1562 - val_loss: 210054.7188 - val_mean_absolute_error: 455.3660 - val_rmse: 458.3145
# Epoch 104/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 154954.1250 - mean_absolute_error: 391.6255 - rmse: 393.6388 - val_loss: 188999.7969 - val_mean_absolute_error: 431.0631 - val_rmse: 434.7381
# Epoch 105/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 147597.3594 - mean_absolute_error: 382.0242 - rmse: 384.1806 - val_loss: 173095.4531 - val_mean_absolute_error: 412.0103 - val_rmse: 416.0442
# Epoch 106/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 140459.9531 - mean_absolute_error: 372.5027 - rmse: 374.7763 - val_loss: 167304.8438 - val_mean_absolute_error: 404.6300 - val_rmse: 409.0258
# Epoch 107/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 133516.9531 - mean_absolute_error: 363.1034 - rmse: 365.3960 - val_loss: 162475.0156 - val_mean_absolute_error: 399.1265 - val_rmse: 403.0786
# Epoch 108/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 126754.2734 - mean_absolute_error: 353.7880 - rmse: 356.0219 - val_loss: 156223.6250 - val_mean_absolute_error: 391.2018 - val_rmse: 395.2479
# Epoch 109/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 120374.3906 - mean_absolute_error: 344.5671 - rmse: 346.9462 - val_loss: 151751.0781 - val_mean_absolute_error: 385.7297 - val_rmse: 389.5489
# Epoch 110/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 113935.0781 - mean_absolute_error: 335.4356 - rmse: 337.5387 - val_loss: 145339.6406 - val_mean_absolute_error: 377.3566 - val_rmse: 381.2308
# Epoch 111/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 108016.9141 - mean_absolute_error: 326.4246 - rmse: 328.6551 - val_loss: 129070.9219 - val_mean_absolute_error: 355.8946 - val_rmse: 359.2606
# Epoch 112/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 102304.8750 - mean_absolute_error: 317.5265 - rmse: 319.8470 - val_loss: 134230.0625 - val_mean_absolute_error: 362.3158 - val_rmse: 366.3705
# Epoch 113/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 96892.6562 - mean_absolute_error: 308.7302 - rmse: 311.2714 - val_loss: 123490.3125 - val_mean_absolute_error: 347.5701 - val_rmse: 351.4080
# Epoch 114/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 91381.1953 - mean_absolute_error: 300.0460 - rmse: 302.2887 - val_loss: 116676.8750 - val_mean_absolute_error: 337.6218 - val_rmse: 341.5759
# Epoch 115/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 86356.2344 - mean_absolute_error: 291.4916 - rmse: 293.8596 - val_loss: 114996.1016 - val_mean_absolute_error: 335.2021 - val_rmse: 339.1067
# Epoch 116/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 81526.8125 - mean_absolute_error: 283.0309 - rmse: 285.5242 - val_loss: 108437.6250 - val_mean_absolute_error: 325.1429 - val_rmse: 329.2945
# Epoch 117/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 76873.0781 - mean_absolute_error: 274.7092 - rmse: 277.2550 - val_loss: 103378.5625 - val_mean_absolute_error: 317.5329 - val_rmse: 321.5210
# Epoch 118/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 72568.6406 - mean_absolute_error: 266.5100 - rmse: 269.3805 - val_loss: 98856.6797 - val_mean_absolute_error: 310.3026 - val_rmse: 314.4104
# Epoch 119/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 68276.3984 - mean_absolute_error: 258.4453 - rmse: 261.2922 - val_loss: 92156.1250 - val_mean_absolute_error: 299.4562 - val_rmse: 303.5677
# Epoch 120/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 64157.3203 - mean_absolute_error: 250.4812 - rmse: 253.2874 - val_loss: 90398.6641 - val_mean_absolute_error: 295.9088 - val_rmse: 300.6590
# Epoch 121/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 60250.5352 - mean_absolute_error: 242.6644 - rmse: 245.4541 - val_loss: 82545.5312 - val_mean_absolute_error: 282.8118 - val_rmse: 287.3025
# Epoch 122/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 56643.8320 - mean_absolute_error: 234.9794 - rmse: 237.9937 - val_loss: 76525.5938 - val_mean_absolute_error: 272.1397 - val_rmse: 276.6275
# Epoch 123/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 53039.6562 - mean_absolute_error: 227.4335 - rmse: 230.2972 - val_loss: 72158.9844 - val_mean_absolute_error: 264.0531 - val_rmse: 268.6189
# Epoch 124/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 49767.7461 - mean_absolute_error: 220.0205 - rmse: 223.0804 - val_loss: 64800.4805 - val_mean_absolute_error: 250.1071 - val_rmse: 254.5537
# Epoch 125/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 46622.1445 - mean_absolute_error: 212.7533 - rmse: 215.9148 - val_loss: 58365.9297 - val_mean_absolute_error: 236.6335 - val_rmse: 241.5843
# Epoch 126/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 43568.8242 - mean_absolute_error: 205.6091 - rmse: 208.7243 - val_loss: 61363.9961 - val_mean_absolute_error: 242.7461 - val_rmse: 247.7115
# Epoch 127/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 40798.4531 - mean_absolute_error: 198.6128 - rmse: 201.9789 - val_loss: 58557.9414 - val_mean_absolute_error: 236.3874 - val_rmse: 241.9813
# Epoch 128/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 37996.6211 - mean_absolute_error: 191.7548 - rmse: 194.9195 - val_loss: 51809.6289 - val_mean_absolute_error: 221.5794 - val_rmse: 227.6107
# Epoch 129/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 35594.0820 - mean_absolute_error: 185.0378 - rmse: 188.6559 - val_loss: 53608.0703 - val_mean_absolute_error: 225.2791 - val_rmse: 231.5276
# Epoch 130/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 33245.7305 - mean_absolute_error: 178.4544 - rmse: 182.3258 - val_loss: 50449.6953 - val_mean_absolute_error: 218.3993 - val_rmse: 224.6033
# Epoch 131/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30829.3789 - mean_absolute_error: 172.0052 - rmse: 175.5743 - val_loss: 50406.7344 - val_mean_absolute_error: 218.5844 - val_rmse: 224.5077
# Epoch 132/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 28773.7988 - mean_absolute_error: 165.7139 - rmse: 169.6194 - val_loss: 46259.7461 - val_mean_absolute_error: 209.4515 - val_rmse: 215.0737
# Epoch 133/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26763.5488 - mean_absolute_error: 159.6254 - rmse: 163.5864 - val_loss: 44473.8828 - val_mean_absolute_error: 205.0061 - val_rmse: 210.8811
# Epoch 134/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24875.1641 - mean_absolute_error: 153.6528 - rmse: 157.7089 - val_loss: 40241.6836 - val_mean_absolute_error: 193.0367 - val_rmse: 200.5957
# Epoch 135/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23009.1562 - mean_absolute_error: 147.7697 - rmse: 151.6776 - val_loss: 40300.0547 - val_mean_absolute_error: 193.6710 - val_rmse: 200.7411
# Epoch 136/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21583.4277 - mean_absolute_error: 142.0586 - rmse: 146.9025 - val_loss: 36843.3281 - val_mean_absolute_error: 185.6996 - val_rmse: 191.9381
# Epoch 137/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19843.1445 - mean_absolute_error: 136.5114 - rmse: 140.8546 - val_loss: 34975.4453 - val_mean_absolute_error: 179.9027 - val_rmse: 187.0089
# Epoch 138/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18580.9551 - mean_absolute_error: 131.1326 - rmse: 136.3005 - val_loss: 30519.3750 - val_mean_absolute_error: 167.4270 - val_rmse: 174.6889
# Epoch 139/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17304.9414 - mean_absolute_error: 125.7981 - rmse: 131.5362 - val_loss: 29642.2188 - val_mean_absolute_error: 164.8317 - val_rmse: 172.1599
# Epoch 140/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15758.8115 - mean_absolute_error: 120.6994 - rmse: 125.5215 - val_loss: 28464.3164 - val_mean_absolute_error: 161.0992 - val_rmse: 168.7043
# Epoch 141/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14635.8926 - mean_absolute_error: 115.7147 - rmse: 120.9658 - val_loss: 27635.9688 - val_mean_absolute_error: 158.2214 - val_rmse: 166.2311
# Epoch 142/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13541.6387 - mean_absolute_error: 110.8496 - rmse: 116.3549 - val_loss: 24079.0566 - val_mean_absolute_error: 146.7976 - val_rmse: 155.1640
# Epoch 143/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12461.8965 - mean_absolute_error: 106.1842 - rmse: 111.6185 - val_loss: 24494.6152 - val_mean_absolute_error: 148.2976 - val_rmse: 156.4973
# Epoch 144/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11601.5049 - mean_absolute_error: 101.6948 - rmse: 107.6953 - val_loss: 20903.3379 - val_mean_absolute_error: 135.9982 - val_rmse: 144.5687
# Epoch 145/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10618.6602 - mean_absolute_error: 97.2327 - rmse: 103.0312 - val_loss: 20050.6191 - val_mean_absolute_error: 132.7036 - val_rmse: 141.5888
# Epoch 146/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9917.7842 - mean_absolute_error: 93.1879 - rmse: 99.5717 - val_loss: 18734.9082 - val_mean_absolute_error: 126.9278 - val_rmse: 136.8636
# Epoch 147/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9053.4531 - mean_absolute_error: 88.8347 - rmse: 95.1324 - val_loss: 15825.7803 - val_mean_absolute_error: 115.8772 - val_rmse: 125.7875
# Epoch 148/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8297.2754 - mean_absolute_error: 84.9029 - rmse: 91.0712 - val_loss: 20776.5742 - val_mean_absolute_error: 134.3814 - val_rmse: 144.1292
# Epoch 149/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7911.3281 - mean_absolute_error: 81.2993 - rmse: 88.9269 - val_loss: 14560.6045 - val_mean_absolute_error: 110.2087 - val_rmse: 120.6534
# Epoch 150/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7306.4175 - mean_absolute_error: 77.7867 - rmse: 85.4578 - val_loss: 12680.1641 - val_mean_absolute_error: 102.1600 - val_rmse: 112.5911
# Epoch 151/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6562.4048 - mean_absolute_error: 73.9395 - rmse: 80.9876 - val_loss: 13325.0830 - val_mean_absolute_error: 104.2939 - val_rmse: 115.4195
# Epoch 152/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6024.7139 - mean_absolute_error: 70.5373 - rmse: 77.5969 - val_loss: 15001.3574 - val_mean_absolute_error: 111.4180 - val_rmse: 122.4660
# Epoch 153/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5615.6826 - mean_absolute_error: 67.5870 - rmse: 74.9149 - val_loss: 14436.6445 - val_mean_absolute_error: 108.9887 - val_rmse: 120.1382
# Epoch 154/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5279.3032 - mean_absolute_error: 64.9049 - rmse: 72.6350 - val_loss: 11850.4727 - val_mean_absolute_error: 97.6879 - val_rmse: 108.8439
# Epoch 155/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4751.0513 - mean_absolute_error: 61.6242 - rmse: 68.9026 - val_loss: 12074.0908 - val_mean_absolute_error: 98.0941 - val_rmse: 109.8663
# Epoch 156/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4398.3188 - mean_absolute_error: 58.7635 - rmse: 66.2934 - val_loss: 13359.8896 - val_mean_absolute_error: 104.2753 - val_rmse: 115.5698
# Epoch 157/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4164.1250 - mean_absolute_error: 57.3068 - rmse: 64.5028 - val_loss: 12357.3955 - val_mean_absolute_error: 99.5688 - val_rmse: 111.1480
# Epoch 158/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3779.1885 - mean_absolute_error: 54.2298 - rmse: 61.4465 - val_loss: 12429.8428 - val_mean_absolute_error: 98.9565 - val_rmse: 111.4734
# Epoch 159/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3381.2634 - mean_absolute_error: 50.5914 - rmse: 58.1183 - val_loss: 12731.8936 - val_mean_absolute_error: 101.5625 - val_rmse: 112.8200
# Epoch 160/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3323.6455 - mean_absolute_error: 49.6021 - rmse: 57.6203 - val_loss: 11253.3115 - val_mean_absolute_error: 92.2053 - val_rmse: 106.0649
# Epoch 161/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2943.3750 - mean_absolute_error: 46.9555 - rmse: 54.2201 - val_loss: 9689.2217 - val_mean_absolute_error: 87.7729 - val_rmse: 98.4158
# Epoch 162/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2793.7090 - mean_absolute_error: 45.0808 - rmse: 52.8219 - val_loss: 10031.5234 - val_mean_absolute_error: 86.7573 - val_rmse: 100.1397
# Epoch 163/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2613.8647 - mean_absolute_error: 43.2781 - rmse: 51.0909 - val_loss: 9570.0029 - val_mean_absolute_error: 85.5282 - val_rmse: 97.8080
# Epoch 164/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2475.9353 - mean_absolute_error: 42.1664 - rmse: 49.7226 - val_loss: 8997.4648 - val_mean_absolute_error: 83.1380 - val_rmse: 94.8360
# Epoch 165/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2333.7412 - mean_absolute_error: 39.7281 - rmse: 48.2714 - val_loss: 8422.3477 - val_mean_absolute_error: 77.7131 - val_rmse: 91.7536
# Epoch 166/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2168.5227 - mean_absolute_error: 37.8843 - rmse: 46.5285 - val_loss: 9394.5234 - val_mean_absolute_error: 81.5140 - val_rmse: 96.9065
# Epoch 167/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2340.2986 - mean_absolute_error: 39.1888 - rmse: 48.3388 - val_loss: 9174.6387 - val_mean_absolute_error: 81.4164 - val_rmse: 95.7651
# Epoch 168/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2039.8165 - mean_absolute_error: 35.8755 - rmse: 45.1233 - val_loss: 8539.0850 - val_mean_absolute_error: 78.9406 - val_rmse: 92.3871
# Epoch 169/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1899.4299 - mean_absolute_error: 35.3161 - rmse: 43.5399 - val_loss: 8244.1123 - val_mean_absolute_error: 77.4721 - val_rmse: 90.7767
# Epoch 170/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2008.3883 - mean_absolute_error: 35.9763 - rmse: 44.7736 - val_loss: 5127.1206 - val_mean_absolute_error: 60.1932 - val_rmse: 71.5779
# Epoch 171/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1766.5647 - mean_absolute_error: 33.3796 - rmse: 41.9862 - val_loss: 6217.1147 - val_mean_absolute_error: 64.6833 - val_rmse: 78.8250
# Epoch 172/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1683.7931 - mean_absolute_error: 32.6361 - rmse: 40.9883 - val_loss: 6457.5005 - val_mean_absolute_error: 66.6324 - val_rmse: 80.3351
# Epoch 173/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1413.4972 - mean_absolute_error: 29.9925 - rmse: 37.5460 - val_loss: 6705.2593 - val_mean_absolute_error: 68.4363 - val_rmse: 81.8624
# Epoch 174/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1380.1857 - mean_absolute_error: 29.7066 - rmse: 37.0995 - val_loss: 6082.3398 - val_mean_absolute_error: 64.9167 - val_rmse: 77.9648
# Epoch 175/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1353.8867 - mean_absolute_error: 28.7407 - rmse: 36.7431 - val_loss: 5651.8911 - val_mean_absolute_error: 60.1814 - val_rmse: 75.1535
# Epoch 176/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1452.8064 - mean_absolute_error: 30.1787 - rmse: 38.0652 - val_loss: 5366.0918 - val_mean_absolute_error: 59.7139 - val_rmse: 73.2273
# Epoch 177/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1371.6102 - mean_absolute_error: 28.9020 - rmse: 36.9830 - val_loss: 5867.6328 - val_mean_absolute_error: 62.4530 - val_rmse: 76.5752
# Epoch 178/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1222.2793 - mean_absolute_error: 27.0415 - rmse: 34.9056 - val_loss: 6068.5039 - val_mean_absolute_error: 62.2978 - val_rmse: 77.8757
# Epoch 179/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1289.9146 - mean_absolute_error: 28.3475 - rmse: 35.8613 - val_loss: 5736.8726 - val_mean_absolute_error: 61.9001 - val_rmse: 75.7165
# Epoch 180/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1263.3751 - mean_absolute_error: 27.7422 - rmse: 35.4894 - val_loss: 5701.3540 - val_mean_absolute_error: 61.1248 - val_rmse: 75.4816
# Epoch 181/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1253.9216 - mean_absolute_error: 27.5645 - rmse: 35.3557 - val_loss: 6322.6187 - val_mean_absolute_error: 66.5344 - val_rmse: 79.4903
# Epoch 182/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1365.0878 - mean_absolute_error: 28.4709 - rmse: 36.8941 - val_loss: 5268.1675 - val_mean_absolute_error: 59.2007 - val_rmse: 72.5551
# Epoch 183/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1220.2812 - mean_absolute_error: 27.2771 - rmse: 34.8762 - val_loss: 5247.4761 - val_mean_absolute_error: 58.6255 - val_rmse: 72.4122
# Epoch 184/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1330.8534 - mean_absolute_error: 27.8853 - rmse: 36.4267 - val_loss: 4780.9561 - val_mean_absolute_error: 55.3700 - val_rmse: 69.1158
# Epoch 185/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1122.7543 - mean_absolute_error: 25.8669 - rmse: 33.4482 - val_loss: 5243.9995 - val_mean_absolute_error: 57.7901 - val_rmse: 72.3880
# Epoch 186/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1074.2638 - mean_absolute_error: 25.3012 - rmse: 32.7151 - val_loss: 5402.1660 - val_mean_absolute_error: 59.1046 - val_rmse: 73.4723
# Epoch 187/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1004.8466 - mean_absolute_error: 24.4193 - rmse: 31.6362 - val_loss: 5743.9414 - val_mean_absolute_error: 61.5897 - val_rmse: 75.7623
# Epoch 188/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1038.0123 - mean_absolute_error: 24.4604 - rmse: 32.1557 - val_loss: 4953.1621 - val_mean_absolute_error: 57.6556 - val_rmse: 70.3501
# Epoch 189/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1082.7059 - mean_absolute_error: 25.0563 - rmse: 32.8432 - val_loss: 3948.0554 - val_mean_absolute_error: 50.3100 - val_rmse: 62.8014
# Epoch 190/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 944.8885 - mean_absolute_error: 24.1035 - rmse: 30.6732 - val_loss: 5722.3745 - val_mean_absolute_error: 63.1312 - val_rmse: 75.6196
# Epoch 191/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1270.7655 - mean_absolute_error: 27.2715 - rmse: 35.5908 - val_loss: 5124.9980 - val_mean_absolute_error: 58.8719 - val_rmse: 71.5606
# Epoch 192/500
# ...
# Epoch 471/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 603.4871 - mean_absolute_error: 18.6447 - rmse: 24.3840 - val_loss: 1947.8070 - val_mean_absolute_error: 35.3768 - val_rmse: 44.0330
# Epoch 472/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 574.1094 - mean_absolute_error: 18.1944 - rmse: 23.7741 - val_loss: 2227.5254 - val_mean_absolute_error: 38.3586 - val_rmse: 47.1022
# Epoch 473/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 539.5447 - mean_absolute_error: 17.6093 - rmse: 23.0355 - val_loss: 2323.2473 - val_mean_absolute_error: 38.5347 - val_rmse: 48.1075
# Epoch 474/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 584.5897 - mean_absolute_error: 18.2061 - rmse: 23.9930 - val_loss: 2107.1328 - val_mean_absolute_error: 36.4420 - val_rmse: 45.8061
# Epoch 475/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 503.4107 - mean_absolute_error: 16.4194 - rmse: 22.2364 - val_loss: 2015.2273 - val_mean_absolute_error: 36.0165 - val_rmse: 44.7911
# Epoch 476/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 507.6222 - mean_absolute_error: 16.6996 - rmse: 22.3298 - val_loss: 2392.8591 - val_mean_absolute_error: 37.7872 - val_rmse: 48.8248
# Epoch 477/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 635.7581 - mean_absolute_error: 18.6513 - rmse: 25.0349 - val_loss: 2071.7563 - val_mean_absolute_error: 34.9223 - val_rmse: 45.4172
# Epoch 478/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 516.1702 - mean_absolute_error: 17.3067 - rmse: 22.5190 - val_loss: 2345.3826 - val_mean_absolute_error: 37.7616 - val_rmse: 48.3353
# Epoch 479/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 524.7344 - mean_absolute_error: 17.4149 - rmse: 22.7080 - val_loss: 1814.6831 - val_mean_absolute_error: 33.7162 - val_rmse: 42.4924
# Epoch 480/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 400.8436 - mean_absolute_error: 15.2061 - rmse: 19.7931 - val_loss: 1995.1858 - val_mean_absolute_error: 34.8977 - val_rmse: 44.5659
# Epoch 481/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 577.2773 - mean_absolute_error: 18.0087 - rmse: 23.8371 - val_loss: 2320.6858 - val_mean_absolute_error: 37.6957 - val_rmse: 48.0792
# Epoch 482/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 558.5156 - mean_absolute_error: 17.7941 - rmse: 23.4400 - val_loss: 2209.8044 - val_mean_absolute_error: 35.4829 - val_rmse: 46.9120
# Epoch 483/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 540.2728 - mean_absolute_error: 17.4130 - rmse: 23.0476 - val_loss: 2326.2876 - val_mean_absolute_error: 37.4937 - val_rmse: 48.1373
# Epoch 484/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 542.2212 - mean_absolute_error: 17.5208 - rmse: 23.0899 - val_loss: 2068.1565 - val_mean_absolute_error: 35.6161 - val_rmse: 45.3771
# Epoch 485/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 586.5625 - mean_absolute_error: 18.1074 - rmse: 24.0309 - val_loss: 2212.4863 - val_mean_absolute_error: 37.1146 - val_rmse: 46.9404
# Epoch 486/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 465.1299 - mean_absolute_error: 16.1860 - rmse: 21.3552 - val_loss: 2397.6160 - val_mean_absolute_error: 38.8990 - val_rmse: 48.8724
# Epoch 487/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 591.7086 - mean_absolute_error: 18.5393 - rmse: 24.1372 - val_loss: 2116.3157 - val_mean_absolute_error: 36.5522 - val_rmse: 45.9044
# Epoch 488/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 513.7698 - mean_absolute_error: 17.1938 - rmse: 22.4645 - val_loss: 2459.1199 - val_mean_absolute_error: 38.7724 - val_rmse: 49.4975
# Epoch 489/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 531.8265 - mean_absolute_error: 17.4568 - rmse: 22.8626 - val_loss: 2292.5793 - val_mean_absolute_error: 38.5837 - val_rmse: 47.7854
# Epoch 490/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 566.6116 - mean_absolute_error: 17.9255 - rmse: 23.6107 - val_loss: 2184.2534 - val_mean_absolute_error: 36.2622 - val_rmse: 46.6380
# Epoch 491/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 684.2280 - mean_absolute_error: 18.9066 - rmse: 25.9814 - val_loss: 2226.2678 - val_mean_absolute_error: 36.5900 - val_rmse: 47.0852
# Epoch 492/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 671.7487 - mean_absolute_error: 19.4235 - rmse: 25.7388 - val_loss: 2211.6882 - val_mean_absolute_error: 33.9797 - val_rmse: 46.9302
# Epoch 493/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 552.3332 - mean_absolute_error: 17.4003 - rmse: 23.3043 - val_loss: 2133.5508 - val_mean_absolute_error: 37.1644 - val_rmse: 46.0903
# Epoch 494/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 541.9418 - mean_absolute_error: 17.1058 - rmse: 23.0804 - val_loss: 2536.5403 - val_mean_absolute_error: 35.3844 - val_rmse: 50.2722
# Epoch 495/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 575.8361 - mean_absolute_error: 17.5887 - rmse: 23.8026 - val_loss: 3854.9487 - val_mean_absolute_error: 42.8317 - val_rmse: 62.0134
# Epoch 496/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 557.1739 - mean_absolute_error: 17.4339 - rmse: 23.4067 - val_loss: 2053.7075 - val_mean_absolute_error: 34.2066 - val_rmse: 45.2149
# Epoch 497/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 546.1273 - mean_absolute_error: 17.3037 - rmse: 23.1691 - val_loss: 2379.4980 - val_mean_absolute_error: 37.3363 - val_rmse: 48.6843
# Epoch 498/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 464.6833 - mean_absolute_error: 15.9076 - rmse: 21.3383 - val_loss: 2387.3306 - val_mean_absolute_error: 36.0700 - val_rmse: 48.7642
# Epoch 499/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 543.4968 - mean_absolute_error: 17.3652 - rmse: 23.1105 - val_loss: 2159.9924 - val_mean_absolute_error: 35.6170 - val_rmse: 46.3743
# Epoch 500/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 472.4153 - mean_absolute_error: 16.3414 - rmse: 21.5175 - val_loss: 2787.5051 - val_mean_absolute_error: 38.9198 - val_rmse: 52.7075
# --- 모델 훈련 완료 ---
#
# --- 최종 모델 평가 (Test Set) ---
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6271.7876 - mean_absolute_error: 42.8234 - rmse: 79.1351
# loss: 6271.7876
# compile_metrics: 42.8234
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000261BE63F9C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000261BE63F9C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_60 (Dense)                │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_60          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_61          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_62          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_63          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_64          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_65          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_66          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_67          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_68          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_69          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_70          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_71          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_72          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_74          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_75          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_76          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_77          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_78          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_79          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,642,824 (13.90 MB)
#  Trainable params: 1,213,762 (4.63 MB)
#  Non-trainable params: 1,536 (6.00 KB)
#  Optimizer params: 2,427,526 (9.26 MB)

# %%
LOG_FILE = os.path.join("results", "experiment_logs.csv")
log_experiment(
        log_path=LOG_FILE,
        model=model,
        history=history,
        model_config=MODEL_CONFIG,
        train_config=TRAIN_CONFIG,
        X_train=X_train,
        X_val=X_val,
    )

save_final_model("results/weights", model, history, TRAIN_CONFIG)
# Out:
# Model: "Modular_DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_60 (Dense)                │ (None, 128)            │     1,183,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_60          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_61          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_62          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_63          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_64          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_65          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_66          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_67          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_68          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_69          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_70          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_71          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_72          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_74          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_75          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_76          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_77          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_78          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_79          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,642,824 (13.90 MB)
#  Trainable params: 1,213,762 (4.63 MB)
#  Non-trainable params: 1,536 (6.00 KB)
#  Optimizer params: 2,427,526 (9.26 MB)
